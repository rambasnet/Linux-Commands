# %% [markdown]
# # I/O Redirection and Pipelines
#
# ## Standard Output Redirection
# - \> : redirect commands output to files
#     - create an output file if not exists
# - \>> : append to a file

# %%
! ls
# Out:
# Ch01-LearningShell.ipynb		    Ch09-UtilityCommands.ipynb
# Ch02-NavigationExploration.ipynb	    foo.txt
# Ch03-ManipulatingFilesAndDirectories.ipynb  README.md
# Ch04-FilesAndPermissions.ipynb		    resources
# Ch05-UserManagementEnvVariables.ipynb	    softfoolink
# Ch06-IORedirection-Pipelines.ipynb	    test1
# Ch07-ExpansionAndSubstitution.ipynb	    test2
# Ch08-JobsAndProcessControl.ipynb	    test.txt

# %%
# redirect ls commands ouptut to ls.txt
! ls > ls.txt

# %%
# see the new file created
! ls -l ls.txt
# Out:
# -rw-r--r-- 1 kali kali 369 Feb  9 13:31 ls.txt

# %%
# type the contents of the new file
! cat ls.txt
# Out:
# Ch01-LearningShell.ipynb
# Ch02-NavigationExploration.ipynb
# Ch03-ManipulatingFilesAndDirectories.ipynb
# Ch04-FilesAndPermissions.ipynb
# Ch05-UserManagementEnvVariables.ipynb
# Ch06-IORedirection-Pipelines.ipynb
# Ch07-ExpansionAndSubstitution.ipynb
# Ch08-JobsAndProcessControl.ipynb
# Ch09-UtilityCommands.ipynb
# foo.txt
# ls.txt
# README.md
# resources
# softfoolink
# test1
# test2
# test.txt

# %%
# append the results to ls.txt
! ls -al >> ls.txt

# %%
! cat ls.txt
# Out:
# Ch01-LearningShell.ipynb
# Ch02-NavigationExploration.ipynb
# Ch03-ManipulatingFilesAndDirectories.ipynb
# Ch04-FilesAndPermissions.ipynb
# Ch05-UserManagementEnvVariables.ipynb
# Ch06-IORedirection-Pipelines.ipynb
# Ch07-ExpansionAndSubstitution.ipynb
# Ch08-JobsAndProcessControl.ipynb
# Ch09-UtilityCommands.ipynb
# foo.txt
# ls.txt
# README.md
# resources
# softfoolink
# test1
# test2
# test.txt
# total 392
# drwxr-xr-x 7 kali kali   4096 Feb  9 13:31 .
# drwxr-xr-x 4 kali kali   4096 Feb  9 13:03 ..
# -rw-r--r-- 1 kali kali   4146 Feb  9 13:07 Ch01-LearningShell.ipynb
# -rw-r--r-- 1 kali kali  89211 Feb  9 13:12 Ch02-NavigationExploration.ipynb
# -rw-r--r-- 1 kali kali  27124 Feb  9 13:14 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 kali kali  20482 Feb  9 13:26 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 kali kali  25699 Feb  9 13:30 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 kali kali 134819 Feb  9 13:03 Ch06-IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 kali kali  13070 Feb  9 13:03 Ch07-ExpansionAndSubstitution.ipynb
# -rw-r--r-- 1 kali kali   3771 Feb  9 13:03 Ch08-JobsAndProcessControl.ipynb
# -rw-r--r-- 1 kali kali  24293 Feb  9 13:03 Ch09-UtilityCommands.ipynb
# -rwxr----- 1 user user      0 Feb  9 13:15 foo.txt
# drwxr-xr-x 8 kali kali   4096 Feb  9 13:03 .git
# -rw-r--r-- 1 kali kali     25 Feb  9 13:03 .gitignore
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:27 .ipynb_checkpoints
# -rw-r--r-- 1 kali kali    369 Feb  9 13:31 ls.txt
# -rw-r--r-- 1 kali kali    544 Feb  9 13:03 README.md
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:03 resources
# lrwxrwxrwx 1 kali kali      7 Feb  9 13:15 softfoolink -> foo.txt
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test1
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test2
# -rw-r--r-- 1 kali kali      0 Feb  9 13:13 test.txt

# %% [markdown]
# ## Standard Input
# - \< : read from a text file

# %%
! sort < ls.txt
# Out:
# Ch01-LearningShell.ipynb
# Ch02-NavigationExploration.ipynb
# Ch03-ManipulatingFilesAndDirectories.ipynb
# Ch04-FilesAndPermissions.ipynb
# Ch05-UserManagementEnvVariables.ipynb
# Ch06-IORedirection-Pipelines.ipynb
# Ch07-ExpansionAndSubstitution.ipynb
# Ch08-JobsAndProcessControl.ipynb
# Ch09-UtilityCommands.ipynb
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:03 resources
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test1
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test2
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:27 .ipynb_checkpoints
# drwxr-xr-x 4 kali kali   4096 Feb  9 13:03 ..
# drwxr-xr-x 7 kali kali   4096 Feb  9 13:31 .
# drwxr-xr-x 8 kali kali   4096 Feb  9 13:03 .git
# foo.txt
# lrwxrwxrwx 1 kali kali      7 Feb  9 13:15 softfoolink -> foo.txt
# ls.txt
# README.md
# resources
# -rw-r--r-- 1 kali kali      0 Feb  9 13:13 test.txt
# -rw-r--r-- 1 kali kali  13070 Feb  9 13:03 Ch07-ExpansionAndSubstitution.ipynb
# -rw-r--r-- 1 kali kali 134819 Feb  9 13:03 Ch06-IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 kali kali  20482 Feb  9 13:26 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 kali kali  24293 Feb  9 13:03 Ch09-UtilityCommands.ipynb
# -rw-r--r-- 1 kali kali  25699 Feb  9 13:30 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 kali kali     25 Feb  9 13:03 .gitignore
# -rw-r--r-- 1 kali kali  27124 Feb  9 13:14 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 kali kali    369 Feb  9 13:31 ls.txt
# -rw-r--r-- 1 kali kali   3771 Feb  9 13:03 Ch08-JobsAndProcessControl.ipynb
# -rw-r--r-- 1 kali kali   4146 Feb  9 13:07 Ch01-LearningShell.ipynb
# -rw-r--r-- 1 kali kali    544 Feb  9 13:03 README.md
# -rw-r--r-- 1 kali kali  89211 Feb  9 13:12 Ch02-NavigationExploration.ipynb
# -rwxr----- 1 user user      0 Feb  9 13:15 foo.txt
# softfoolink
# test1
# test2
# test.txt
# total 392

# %%
! sort < ls.txt > sortedls.txt

# %%
! cat sortedls.txt
# Out:
# Ch01-LearningShell.ipynb
# Ch02-NavigationExploration.ipynb
# Ch03-ManipulatingFilesAndDirectories.ipynb
# Ch04-FilesAndPermissions.ipynb
# Ch05-UserManagementEnvVariables.ipynb
# Ch06-IORedirection-Pipelines.ipynb
# Ch07-ExpansionAndSubstitution.ipynb
# Ch08-JobsAndProcessControl.ipynb
# Ch09-UtilityCommands.ipynb
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:03 resources
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test1
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test2
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:27 .ipynb_checkpoints
# drwxr-xr-x 4 kali kali   4096 Feb  9 13:03 ..
# drwxr-xr-x 7 kali kali   4096 Feb  9 13:31 .
# drwxr-xr-x 8 kali kali   4096 Feb  9 13:03 .git
# foo.txt
# lrwxrwxrwx 1 kali kali      7 Feb  9 13:15 softfoolink -> foo.txt
# ls.txt
# README.md
# resources
# -rw-r--r-- 1 kali kali      0 Feb  9 13:13 test.txt
# -rw-r--r-- 1 kali kali  13070 Feb  9 13:03 Ch07-ExpansionAndSubstitution.ipynb
# -rw-r--r-- 1 kali kali 134819 Feb  9 13:03 Ch06-IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 kali kali  20482 Feb  9 13:26 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 kali kali  24293 Feb  9 13:03 Ch09-UtilityCommands.ipynb
# -rw-r--r-- 1 kali kali  25699 Feb  9 13:30 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 kali kali     25 Feb  9 13:03 .gitignore
# -rw-r--r-- 1 kali kali  27124 Feb  9 13:14 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 kali kali    369 Feb  9 13:31 ls.txt
# -rw-r--r-- 1 kali kali   3771 Feb  9 13:03 Ch08-JobsAndProcessControl.ipynb
# -rw-r--r-- 1 kali kali   4146 Feb  9 13:07 Ch01-LearningShell.ipynb
# -rw-r--r-- 1 kali kali    544 Feb  9 13:03 README.md
# -rw-r--r-- 1 kali kali  89211 Feb  9 13:12 Ch02-NavigationExploration.ipynb
# -rwxr----- 1 user user      0 Feb  9 13:15 foo.txt
# softfoolink
# test1
# test2
# test.txt
# total 392

# %% [markdown]
# ## Pipelines
# - connect multiple commands together
# - feed output from one command as an input to another command

# %%
# sort based on 5th column in reverse order
! ls -l | sort -k5nr > sortedls.txt

# %%
! cat sortedls.txt
# Out:
# -rw-r--r-- 1 kali kali 134819 Feb  9 13:03 Ch06-IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 kali kali  89211 Feb  9 13:12 Ch02-NavigationExploration.ipynb
# -rw-r--r-- 1 kali kali  27124 Feb  9 13:14 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 kali kali  25699 Feb  9 13:30 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 kali kali  24293 Feb  9 13:03 Ch09-UtilityCommands.ipynb
# -rw-r--r-- 1 kali kali  20482 Feb  9 13:26 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 kali kali  13070 Feb  9 13:03 Ch07-ExpansionAndSubstitution.ipynb
# -rw-r--r-- 1 kali kali   4146 Feb  9 13:07 Ch01-LearningShell.ipynb
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:03 resources
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test1
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test2
# -rw-r--r-- 1 kali kali   3771 Feb  9 13:03 Ch08-JobsAndProcessControl.ipynb
# -rw-r--r-- 1 kali kali   1745 Feb  9 13:31 ls.txt
# -rw-r--r-- 1 kali kali    544 Feb  9 13:03 README.md
# lrwxrwxrwx 1 kali kali      7 Feb  9 13:15 softfoolink -> foo.txt
# -rw-r--r-- 1 kali kali      0 Feb  9 13:13 test.txt
# -rw-r--r-- 1 kali kali      0 Feb  9 13:31 sortedls.txt
# -rwxr----- 1 user user      0 Feb  9 13:15 foo.txt
# total 372

# %%
# find total number of files in the current directory and all of its sub directories
! find . -type f | wc -l
# Out:
# 46

# %% [markdown]
# ## Filters
# - piplines are often used to perform complex operations on data
# - commands used with pipelines are referred to as **filters**
# - filters take input, change it somehow and then output it
#
# ### sort
# - sort text files; can sort based on columns if file contains tabular data

# %% [markdown]
# ### uniq
# - report or omit repeated lines; used in conjunction with sort to remove duplicate lines

# %%
! ls /bin /usr/bin | sort | uniq
# Out:
# [
# 2to3-2.7
# 7z
# 7za
# 7zr
# aa-enabled
# aa-exec
# ab
# aclocal
# aclocal-1.16
# acyclic
# addpart
# addr2line
# agentxtrap
# aggregate_profile.pl
# aircrack-ng
# airdecap-ng
# airdecloak-ng
# airolib-ng
# amass
# appres
# apropos
# apt
# apt-cache
# apt-cdrom
# apt-config
# apt-extracttemplates
# apt-ftparchive
# apt-get
# apt-key
# apt-mark
# apt-sortpkgs
# apython
# ar
# arch
# aria_chk
# aria_dump_log
# aria_ftdump
# aria_pack
# aria_read_log
# arj
# arjdisp
# arj-register
# as
# asan_symbolize
# asan_symbolize-9
# ascii-xfr
# aspell
# aspell-import
# assistant
# atk6-address6
# atk6-alive6
# atk6-connect6
# atk6-connsplit6
# atk6-covert_send6
# atk6-covert_send6d
# atk6-denial6
# atk6-detect-new-ip6
# atk6-detect_sniffer6
# atk6-dnsdict6
# atk6-dnsrevenum6
# atk6-dnssecwalk
# atk6-dos-new-ip6
# atk6-dump_dhcp6
# atk6-dump_router6
# atk6-exploit6
# atk6-extract_hosts6
# atk6-extract_networks6
# atk6-fake_advertise6
# atk6-fake_dhcps6
# atk6-fake_dns6d
# atk6-fake_dnsupdate6
# atk6-fake_mipv6
# atk6-fake_mld26
# atk6-fake_mld6
# atk6-fake_mldrouter6
# atk6-fake_pim6
# atk6-fake_router26
# atk6-fake_router6
# atk6-fake_solicitate6
# atk6-firewall6
# atk6-flood_advertise6
# atk6-flood_dhcpc6
# atk6-flood_mld26
# atk6-flood_mld6
# atk6-flood_mldrouter6
# atk6-flood_redir6
# atk6-flood_router26
# atk6-flood_router6
# atk6-flood_rs6
# atk6-flood_solicitate6
# atk6-flood_unreach6
# atk6-four2six
# atk6-fragmentation6
# atk6-fragrouter6
# atk6-fuzz_dhcpc6
# atk6-fuzz_dhcps6
# atk6-fuzz_ip6
# atk6-implementation6
# atk6-implementation6d
# atk6-inject_alive6
# atk6-inverse_lookup6
# atk6-kill_router6
# atk6-ndpexhaust26
# atk6-ndpexhaust6
# atk6-node_query6
# atk6-parasite6
# atk6-passive_discovery6
# atk6-randicmp6
# atk6-redir6
# atk6-redirsniff6
# atk6-rsmurf6
# atk6-sendpees6
# atk6-sendpeesmp6
# atk6-smurf6
# atk6-thcping6
# atk6-thcsyn6
# atk6-toobig6
# atk6-toobigsniff6
# atk6-trace6
# atobm
# atril
# atril-previewer
# atril-thumbnailer
# attr
# autoconf
# autoexpect
# autogsdoc
# autoheader
# autom4te
# automake
# automake-1.16
# automat-visualize3
# autopasswd
# autopsy
# autoreconf
# autoscan
# autoupdate
# awk
# axel
# b2
# b2sum
# base32
# base64
# basename
# basenc
# bash
# bashbug
# bccmd
# bcomps
# bcp
# bdftopcf
# bdftruncate
# besside-ng-crawler
# /bin:
# binwalk
# bitmap
# bjam
# blkcalc
# blkcat
# blkls
# blkstat
# blueman-adapters
# blueman-applet
# blueman-assistant
# blueman-manager
# blueman-report
# blueman-sendto
# blueman-services
# blueman-tray
# bluemoon
# bluetoothctl
# bmtoa
# bootctl
# broadwayd
# btattach
# btmgmt
# btmon
# buddy-ng
# bugpoint-9
# bulk_extractor
# bully
# bundle
# bundle2.7
# bundler
# bundler2.7
# bunzip2
# burpsuite
# busctl
# busybox
# bwrap
# bzcat
# bzcmp
# bzdiff
# bzegrep
# bzexe
# bzfgrep
# bzgrep
# bzip2
# bzip2recover
# bzless
# bzmore
# c++
# c89
# c89-gcc
# c99
# c99-gcc
# cabextract
# cadaver
# cal
# calc_tickadj
# calendar
# canberra-gtk-play
# capinfos
# captoinfo
# captype
# cat
# catchsegv
# catfish
# catman
# cc
# ccache
# ccache2kirbi
# ccacheedit
# ccacheroast
# ccomps
# cct
# cd-create-profile
# cd-fix-profile
# cd-iccdump
# cd-it8
# cewl
# c++filt
# cftp3
# cgpt
# chacl
# chage
# chardet
# chardetect
# chattr
# chcon
# checkgid
# cherryd3
# cherrytree
# chfn
# chgrp
# chkfont
# chmod
# choom
# chown
# chromeos-tpm-recovery
# chrt
# chsh
# chvt
# cifscreds
# cifsdd
# cifsiostat
# ciptool
# circo
# cisco-decrypt
# citrix
# cjpeg
# ckbcomp
# ckeygen3
# cksum
# clang
# clang++
# clang++-9
# clang-9
# clang-cpp-9
# clear
# clear_console
# closed_source_web_server_fuzz
# cluster
# clusterdb
# cmedb
# cmp
# code
# codepage
# col
# colormgr
# colrm
# column
# comm
# commix
# compose
# compress
# conch3
# corelist
# count-9
# cp
# cpan
# cpan5.30-x86_64-linux-gnu
# cpio
# cpp
# cpp-10
# cpp-9
# crackmapexec
# cramfsswap
# createdb
# createlang
# createuser
# c_rehash
# crontab
# crossystem
# crunch
# cryptcat
# cryptdir
# cs2cs
# csplit
# ctstat
# curl
# curlftpfs
# cut
# cutycapt
# cvt
# cvtenc
# cvtsudoers
# cygdb3
# cython3
# dash
# date
# dave
# davtest
# dbd
# dbilogstrip
# dbiprof
# dbiproxy
# dbus-cleanup-sockets
# dbus-daemon
# dbus-monitor
# dbus-run-session
# dbus-send
# dbus-update-activation-environment
# dbus-uuidgen
# dbwrap_tool
# dccleancrw
# dceoversmb
# dcfujigreen
# dcfujiturn
# dcfujiturn16
# dcparse
# dcraw
# dd
# ddcmon
# deallocvt
# debconf
# debconf-apt-progress
# debconf-communicate
# debconf-copydb
# debconf-escape
# debconf-set-selections
# debconf-show
# deb-systemd-helper
# deb-systemd-invoke
# debtags
# debugapp
# decode-dimms
# decode-edid
# decode-vaio
# decryptdir
# defaults
# delaunay
# delpart
# delv
# derb
# designer
# desktop-file-edit
# desktop-file-install
# desktop-file-validate
# dev_debug_vboot
# df
# dh_autotools-dev_restoreconfig
# dh_autotools-dev_updateconfig
# dh_bash-completion
# dh_girepository
# dh_numpy3
# dh_perl_dbi
# dh_perl_openssl
# dh_python3-ply
# diff
# diff3
# diffimg
# dig
# dijkstra
# dir
# dirb
# dirb-gendict
# dirbuster
# dircolors
# dirmngr
# dirmngr-client
# dirname
# dislocate
# django-admin
# djpeg
# dltest
# dmesg
# dmitry
# dm-tool
# dns2tcpc
# dns2tcpd
# dnschef
# dnsdomainname
# dnsenum
# dns-rebind
# dnsrecon
# dnstap-read
# domainname
# do_post
# dos2unix
# dot
# dot2gxl
# dot_builtins
# dotlockfile
# dotty
# dpkg
# dpkg-architecture
# dpkg-buildflags
# dpkg-buildpackage
# dpkg-checkbuilddeps
# dpkg-deb
# dpkg-distaddfile
# dpkg-divert
# dpkg-genbuildinfo
# dpkg-genchanges
# dpkg-gencontrol
# dpkg-gensymbols
# dpkg-maintscript-helper
# dpkg-mergechangelogs
# dpkg-name
# dpkg-parsechangelog
# dpkg-query
# dpkg-realpath
# dpkg-scanpackages
# dpkg-scansources
# dpkg-shlibdeps
# dpkg-source
# dpkg-split
# dpkg-statoverride
# dpkg-trigger
# dpkg-vendor
# dpl4hydra
# dropdb
# droplang
# dropuser
# dsymutil-9
# du
# dumpcap
# dump_fmap
# dump_kernel_config
# dumpkeys
# dumpmscat
# dumpRSAPublicKey
# dupemap
# dwp
# echo
# edgepaint
# edit
# editcap
# editor
# editres
# efibootdump
# efibootmgr
# egrep
# eject
# elfedit
# enable_dev_usb_boot
# enc2xs
# encguess
# enchant-2
# enchant-lsmod-2
# encode_keychange
# engrampa
# enum4linux
# env
# envsubst
# eqn
# erb
# erb2.7
# ettercap
# ettercap-pkexec
# etterfilter
# etterlog
# ex
# exe2hex
# exifautotran
# exiv2
# exo-csource
# exo-desktop-item-edit
# exo-open
# exo-preferred-applications
# expand
# expect
# expect_autoexpect
# expect_autopasswd
# expect_cryptdir
# expect_decryptdir
# expect_dislocate
# expect_ftp-rfc
# expect_kibitz
# expect_lpunlock
# expect_mkpasswd
# expect_multixterm
# expect_passmass
# expect_rftp
# expect_rlogin-cwd
# expect_timed-read
# expect_timed-run
# expect_tknewsbiff
# expect_tkpasswd
# expect_unbuffer
# expect_weather
# expect_xkibitz
# expect_xpstat
# expiry
# exploitdb
# expr
# f2py3
# f2py3.9
# f77
# f95
# fab-cewl
# factor
# faillog
# fallocate
# false
# faraday
# faraday-client
# faraday-manage
# faraday-plugins
# faraday-searcher
# faraday-server
# fastjar
# fcat
# fc-cache
# fc-cat
# fc-conflist
# fcgistarter
# fc-list
# fc-match
# fc-pattern
# fc-query
# fc-scan
# fc-validate
# fdp
# fern-wifi-cracker
# ffind
# fgconsole
# fgrep
# fidentify
# fierce
# figlet
# figlet-figlet
# figlist
# filan
# file
# FileCheck-9
# fincore
# find
# findmnt
# findsmb
# finger
# firefox
# firefox-esr
# fiwalk
# fixproc
# flac
# flask
# flock
# fls
# fmt
# fold
# fonttosfnt
# fping
# fping6
# fplugin
# free
# fsstat
# ftp
# ftp-rfc
# funzip
# fuser
# fusermount
# fusermount3
# futility
# futurize
# g++
# g++-10
# galera_new_cluster
# galera_recovery
# gamma4scanimage
# gapplication
# gatttool
# gawk
# gbb_utility
# gc
# gcc
# gcc-10
# gcc-9
# gcc-ar
# gcc-ar-10
# gcc-ar-9
# gcc-nm
# gcc-nm-10
# gcc-nm-9
# gcc-ranlib
# gcc-ranlib-10
# gcc-ranlib-9
# gcore
# gcov
# gcov-10
# gcov-9
# gcov-dump
# gcov-dump-10
# gcov-dump-9
# gcov-tool
# gcov-tool-10
# gcov-tool-9
# gcr-viewer
# gdb
# gdb-add-index
# gdbserver
# gdbtui
# gdbus
# gdialog
# gdk-pixbuf-csource
# gdk-pixbuf-pixdata
# gdk-pixbuf-thumbnailer
# gdnc
# gdomap
# gem
# gem2.7
# genbrk
# gencat
# gencfu
# gencnval
# gendict
# generic_chunked
# generic_listen_tcp
# generic_send_tcp
# generic_send_udp
# generic_web_server_fuzz
# generic_web_server_fuzz2
# genrb
# geod
# geqn
# GET
# getcifsacl
# getconf
# get-edid
# getent
# getfacl
# getfattr
# getkeycodes
# getopt
# getS4U2proxy
# gettext
# gettext.sh
# getTGS
# getTGT
# gfortran
# gfortran-10
# gfortran-9
# gie
# gio
# gio-querymodules
# g-ir-annotation-tool
# g-ir-compiler
# g-ir-doc-tool
# g-ir-generate
# g-ir-inspect
# g-ir-scanner
# git
# git-receive-pack
# git-shell
# git-upload-archive
# git-upload-pack
# glib-compile-schemas
# gmake
# gml2gv
# gnome-keyring
# gnome-keyring-3
# gnome-keyring-daemon
# gnome-www-browser
# gold
# gopherd
# gpasswd
# gpg
# gpg-agent
# gpgcompose
# gpgconf
# gpg-connect-agent
# gpgparsemail
# gpgsm
# gpgsplit
# gpgtar
# gpgv
# gpg-wks-server
# gpg-zip
# gpic
# gpp-decrypt
# gprof
# graphml2gv
# grep
# grepjar
# gresource
# groff
# grog
# grops
# grotty
# groups
# grub-editenv
# grub-file
# grub-fstest
# grub-glue-efi
# grub-kbdcomp
# grub-menulst2cfg
# grub-mkfont
# grub-mkimage
# grub-mklayout
# grub-mknetdir
# grub-mkpasswd-pbkdf2
# grub-mkrelpath
# grub-mkrescue
# grub-mkstandalone
# grub-mount
# grub-render-label
# grub-script-check
# grub-syslinux2cfg
# gsettings
# gspath
# gtbl
# gtf
# gtk-builder-tool
# gtk-encode-symbolic-svg
# gtk-launch
# gtk-query-settings
# gtk-update-icon-cache
# gts2dxf
# gts2oogl
# gts2stl
# gts2xyz
# gtscheck
# gtscompare
# gts-config
# gtstemplate
# gunzip
# guymager
# gv2gml
# gv2gxl
# gvcolor
# gvgen
# gvmap
# gvmap.sh
# gvpack
# gvpr
# gxl2dot
# gxl2gv
# gzexe
# gzip
# h2ph
# h2xs
# halflife
# hashcat
# hashdeep
# hashid
# hash-identifier
# hciattach
# hciconfig
# hcidump
# hcitool
# hd
# head
# HEAD
# helpztags
# hex2hcd
# hexdump
# hexeditor
# hfind
# host
# hostid
# hostname
# hostnamectl
# hotpatcher
# htcacheclean
# htdbm
# htdigest
# html2dic
# html2markdown
# html2markdown.py3
# HTMLLinker
# htpasswd
# hupper3
# hwloc-annotate
# hwloc-bind
# hwloc-calc
# hwloc-compress-dir
# hwloc-diff
# hwloc-distrib
# hwloc-gather-cpuid
# hwloc-gather-topology
# hwloc-info
# hwloc-ls
# hwloc-patch
# hwloc-ps
# hydra
# hydra-wizard
# i386
# icalendar
# icat
# iceauth
# ico
# iconv
# icuinfo
# id
# ifind
# ifnames
# ike-scan
# ils
# img_cat
# img_stat
# impacket-addcomputer
# impacket-atexec
# impacket-dcomexec
# impacket-dpapi
# impacket-esentutl
# impacket-exchanger
# impacket-findDelegation
# impacket-GetADUsers
# impacket-getArch
# impacket-GetNPUsers
# impacket-getPac
# impacket-getST
# impacket-getTGT
# impacket-GetUserSPNs
# impacket-goldenPac
# impacket-karmaSMB
# impacket-kintercept
# impacket-lookupsid
# impacket-mimikatz
# impacket-mqtt_check
# impacket-mssqlclient
# impacket-mssqlinstance
# impacket-netview
# impacket-nmapAnswerMachine
# impacket-ntfs-read
# impacket-ntlmrelayx
# impacket-ping
# impacket-ping6
# impacket-psexec
# impacket-raiseChild
# impacket-rdp_check
# impacket-reg
# impacket-registry-read
# impacket-rpcdump
# impacket-rpcmap
# impacket-sambaPipe
# impacket-samrdump
# impacket-secretsdump
# impacket-services
# impacket-smbclient
# impacket-smbexec
# impacket-smbrelayx
# impacket-smbserver
# impacket-sniff
# impacket-sniffer
# impacket-split
# impacket-ticketConverter
# impacket-ticketer
# impacket-wmiexec
# impacket-wmipersist
# impacket-wmiquery
# inetsim
# infocmp
# infotocap
# innochecksum
# innotop
# inspect
# install
# instmodsh
# inv
# invgeod
# invoke
# invproj
# ionice
# iostat
# ip
# ipcmk
# ipcrm
# ipcs
# iptables-xml
# ipwhois_cli.py
# ipwhois_utils_cli.py
# ipython3
# irb
# irb2.7
# ischroot
# ispell-wrapper
# istat
# ivstools
# jar
# jardetector
# jarwrapper
# java
# jcat
# jexec
# jfr
# jjs
# jls
# join
# journalctl
# jpegexiforient
# jpeg_extract
# jpegtran
# json_pp
# jsonschema
# jupyter
# jupyter-bundlerextension
# jupyter-console
# jupyter-kernel
# jupyter-kernelspec
# jupyter-migrate
# jupyter-nbconvert
# jupyter-nbextension
# jupyter-notebook
# jupyter-run
# jupyter-serverextension
# jupyter-troubleshoot
# jupyter-trust
# kali-hidpi-mode
# kali-motd
# kali-setup
# kali-treecd
# kali-undercover
# kali-winexec
# kazam
# kbdinfo
# kbd_mode
# kbxutil
# kernel-install
# keyctl
# keytool
# kibitz
# kill
# killall
# kirbi2ccache
# kismet
# kismet_cap_freaklabs_zigbee
# kismet_cap_kismetdb
# kismet_cap_linux_bluetooth
# kismet_cap_linux_wifi
# kismet_cap_nrf_51822
# kismet_cap_nrf_mousejack
# kismet_cap_nxp_kw41z
# kismet_cap_pcapfile
# kismet_cap_sdr_rtl433
# kismet_cap_sdr_rtladsb
# kismet_cap_sdr_rtlamr
# kismet_cap_ti_cc_2531
# kismet_cap_ti_cc_2540
# kismet_cap_ubertooth_one
# kismetdb_clean
# kismetdb_dump_devices
# kismetdb_statistics
# kismetdb_strip_packets
# kismetdb_to_gpx
# kismetdb_to_kml
# kismetdb_to_pcap
# kismetdb_to_wiglecsv
# kismet_server
# kmod
# kstats
# l2ping
# l2test
# laptop-detect
# last
# lastb
# lastlog
# lbd
# lcf
# lconvert
# ld
# ldapadd
# ldapcompare
# ldapdelete
# ldapdomaindump
# ldapexop
# ldapmodify
# ldapmodrdn
# ldappasswd
# ldapsearch
# ldapurl
# ldapwhoami
# ld.bfd
# ldd
# ldd2bloodhound
# ldd2pretty
# ld.gold
# ldrdf
# lefty
# legion
# less
# lessecho
# lessfile
# lesskey
# lesspipe
# lexgrog
# libnetcfg
# libtoolize
# libwacom-list-local-devices
# lightdm-gtk-greeter-settings
# lightdm-gtk-greeter-settings-pkexec
# light-locker
# light-locker-command
# line_send_tcp
# linguist
# link
# linux32
# linux64
# linux-boot-prober
# linux-check-removal
# linux-update-symlinks
# linux-version
# listres
# llc-9
# lli-9
# lli-child-target-9
# llvm-addr2line-9
# llvm-ar-9
# llvm-as-9
# llvm-bcanalyzer-9
# llvm-cat-9
# llvm-cfi-verify-9
# llvm-config-9
# llvm-cov-9
# llvm-c-test-9
# llvm-cvtres-9
# llvm-cxxdump-9
# llvm-cxxfilt-9
# llvm-cxxmap-9
# llvm-diff-9
# llvm-dis-9
# llvm-dlltool-9
# llvm-dwarfdump-9
# llvm-dwp-9
# llvm-elfabi-9
# llvm-exegesis-9
# llvm-extract-9
# llvm-jitlink-9
# llvm-lib-9
# llvm-link-9
# llvm-lipo-9
# llvm-lto2-9
# llvm-lto-9
# llvm-mc-9
# llvm-mca-9
# llvm-modextract-9
# llvm-mt-9
# llvm-nm-9
# llvm-objcopy-9
# llvm-objdump-9
# llvm-opt-report-9
# llvm-pdbutil-9
# llvm-PerfectShuffle-9
# llvm-profdata-9
# llvm-ranlib-9
# llvm-rc-9
# llvm-readelf-9
# llvm-readobj-9
# llvm-rtdyld-9
# llvm-size-9
# llvm-split-9
# llvm-stress-9
# llvm-strings-9
# llvm-strip-9
# llvm-symbolizer-9
# llvm-tblgen-9
# llvm-undname-9
# llvm-xray-9
# ln
# lneato
# lnstat
# loadkeys
# loadunimap
# locale
# localectl
# localedef
# locate
# logger
# login
# loginctl
# logname
# logresolve
# look
# lowntfs-3g
# lpunlock
# lrelease
# ls
# lsar
# lsassy
# lsattr
# lsblk
# lsb_release
# lscpu
# lsinitramfs
# lsipc
# lslocks
# lslogins
# lsmem
# lsmod
# lsns
# lsof
# lspci
# lspgpot
# lstopo
# lstopo-no-graphics
# lsusb
# lto-dump-10
# luit
# lupdate
# lwp-download
# lwp-dump
# lwp-mirror
# lwp-request
# lzcat
# lzcmp
# lzdiff
# lzegrep
# lzfgrep
# lzgrep
# lzless
# lzma
# lzmainfo
# lzmore
# m4
# mac2unix
# macchanger
# mactime
# magicrescue
# magicsort
# mailmail3
# make
# makeconv
# make-first-existing-target
# makeivs-ng
# make_strings
# mako-render
# maltego
# man
# mandb
# manpath
# man-recode
# mapscrn
# mariadb
# mariadb-check
# mariadb-service-convert
# markdown_py
# masscan
# mate-calc
# mate-calc-cmd
# mate-calculator
# mate-terminal
# mate-terminal.wrapper
# mawk
# mcookie
# md5deep
# md5sum
# md5sum.textutils
# mdig
# mdsearch
# mech-dump
# medusa
# mergecap
# mesa-overlay-control.py
# mesg
# metaflac
# mibdump
# migrate-pubring-from-classic-gpg
# mimikatz
# mingle
# minicom
# minidump
# mitmdump
# mitmproxy
# mitmweb
# mkdir
# mkfifo
# mkfontdir
# mkfontscale
# mk_modmap
# mknod
# mkpasswd
# mksquashfs
# mktemp
# mlocate
# mm2gv
# mmcat
# mmcli
# mmdbresolve
# mmls
# mmstat
# moc
# monitor-sensor
# more
# mount
# mountpoint
# mousepad
# mp32
# mp3-decoder
# mp64
# mpg123
# mpg123-alsa
# mpg123.bin
# mpg123-id3dump
# mpg123-jack
# mpg123-nas
# mpg123-openal
# mpg123-oss
# mpg123-portaudio
# mpg123-pulse
# mpg123-strip
# mpic++
# mpicc
# mpiCC
# mpicc.openmpi
# mpiCC.openmpi
# mpic++.openmpi
# mpicxx
# mpicxx.openmpi
# mpiexec
# mpiexec.openmpi
# mpif77
# mpif77.openmpi
# mpif90
# mpif90.openmpi
# mpifort
# mpifort.openmpi
# mpijavac
# mpirun
# mpirun.openmpi
# mpris-proxy
# mpstat
# msfconsole
# msfd
# msfdb
# msf-egghunter
# msf-exe2vba
# msf-exe2vbs
# msf-find_badchars
# msf-halflm_second
# msf-hmac_sha1_crack
# msf-java_deserializer
# msf-jsobfu
# msf-makeiplist
# msf-md5_lookup
# msf-metasm_shell
# msf-msf_irb_shell
# msf-nasm_shell
# msf-pattern_create
# msf-pattern_offset
# msfpc
# msf-pdf2xdp
# msfrpc
# msfrpcd
# msfupdate
# msfvenom
# msf-virustotal
# msldap
# msql2mysql
# msrpcfuzz
# msrpcfuzz_udp
# mt
# mt-gnu
# mtrace
# multimac
# multixterm
# mv
# mvxattr
# myisamchk
# myisam_ftdump
# myisamlog
# myisampack
# my_print_defaults
# mysql
# mysqlaccess
# mysqladmin
# mysqlanalyze
# mysqlbinlog
# mysqlcheck
# mysql_convert_table_format
# mysqld_multi
# mysqld_safe
# mysqld_safe_helper
# mysqldump
# mysqldumpslow
# mysql_embedded
# mysql_find_rows
# mysql_fix_extensions
# mysqlhotcopy
# mysqlimport
# mysql_install_db
# mysqloptimize
# mysql_plugin
# mysqlrepair
# mysqlreport
# mysql_secure_installation
# mysql_setpermission
# mysqlshow
# mysqlslap
# mysql_tzinfo_to_sql
# mysql_upgrade
# mysql_waitpid
# mytop
# namei
# nano
# nasm
# nawk
# nbtscan
# nc
# ncal
# ncrack
# nc.traditional
# ncurses5-config
# ncurses6-config
# ncursesw5-config
# ncursesw6-config
# ndisasm
# neato
# neqn
# net
# netaddr
# netcat
# netkit-ftp
# netmask
# netsed
# net-server
# net-snmp-create-v3-user
# netstat
# networkctl
# newgrp
# ngettext
# ngrep
# nice
# nikto
# nisdomainname
# nl
# nm
# nmap
# nm-applet
# nmblookup
# nmcli
# nm-connection-editor
# nm-online
# nmtui
# nmtui-connect
# nmtui-edit
# nmtui-hostname
# nohup
# nokogiri
# nop
# not-9
# notify-send
# nping
# nproc
# nroff
# nsenter
# nslookup
# nstat
# nsupdate
# ntfs-3g
# ntfs-3g.probe
# ntfscat
# ntfscluster
# ntfscmp
# ntfsdecrypt
# ntfsfallocate
# ntfsfix
# ntfsinfo
# ntfsls
# ntfsmove
# ntfsrecover
# ntfssecaudit
# ntfstruncate
# ntfsusermap
# ntfswipe
# ntlm2
# ntlm_brute
# ntpdc
# ntpq
# ntpsweep
# ntptrace
# numfmt
# obexctl
# obj2yaml-9
# objcopy
# objdump
# oclock
# od
# odbcinst
# oLschema2ldif
# ompi-clean
# ompi_info
# ompi-server
# on_ac_power
# onesixtyone
# opalc++
# opalcc
# opal_wrapper
# openapp
# openfortivpn
# openssl
# opentool
# openvt
# ophcrack
# ophcrack-cli
# opt-9
# ortecc
# orte-clean
# orted
# orte-info
# orterun
# orte-server
# osage
# oshc++
# oshcc
# oshCC
# oshcxx
# oshfort
# oshmem_info
# oshrun
# os-prober
# out123
# owasp-zap
# p11-kit
# p7zip
# pacat
# pack200
# packetforge-ng
# pacmd
# pactl
# padsp
# pager
# pa-info
# pamon
# pandoc
# paperconf
# paplay
# parec
# parecord
# parole
# parse-edid
# partx
# passmass
# passwd
# paste
# paster3
# pasteurize
# pasuspender
# patator
# patch
# patchwork
# pathchk
# pathoc
# pathod
# pavucontrol
# pax11publish
# pcf2vpnc
# pcreate3
# pdb2
# pdb2.7
# pdb3
# pdb3.8
# pdb3.9
# pdbedit
# pdfid
# pdf-parser
# pdistreport3
# peekfd
# perf
# perl
# perl5.30.3
# perl5.30-x86_64-linux-gnu
# perlbug
# perldoc
# perlivp
# perlthanks
# perror
# pfc
# pftp
# pg_archivecleanup
# pg_basebackup
# pgbench
# pg_buildext
# pgcli
# pg_config
# pg_conftool
# pg_createcluster
# pg_ctlcluster
# pg_dropcluster
# pg_dump
# pg_dumpall
# pg_isready
# pg_lsclusters
# pg_receivewal
# pg_receivexlog
# pg_recvlogical
# pg_renamecluster
# pgrep
# pg_restore
# pg_upgradecluster
# pg_virtualenv
# phar
# phar7.4
# phar7.4.phar
# phar.phar
# phar.phar7.4
# photorec
# php
# php7.4
# pic
# pico
# piconv
# pidof
# pidstat
# pinentry
# pinentry-curses
# pinentry-gnome3
# pinentry-x11
# ping
# ping4
# ping6
# pinky
# pip
# pip3
# pipal
# pixeltool
# pixiewps
# pkaction
# pkcheck
# pkexec
# pkgdata
# pkill
# pkttyagent
# pl2link
# pl2pm
# pldd
# pldes
# plget
# plio
# plmerge
# plog
# plparse
# plser
# plugin_test
# plymouth
# pmap
# pmspike
# pod2html
# pod2man
# pod2text
# pod2usage
# podchecker
# podselect
# poff
# polenum
# pon
# POST
# post_fuzz
# post_spike
# powersploit
# pr
# precat
# preconv
# prequest3
# preunzip
# prezip
# prezip-bin
# print
# printenv
# printf
# prlimit
# procan
# profile2mat.pl
# profiles
# proj
# projinfo
# projsync
# proutes3
# prove
# proxychains
# proxychains4
# proxytunnel
# prtstat
# prune
# ps
# pserve3
# psfaddtable
# psfgettable
# psfstriptable
# psfxtable
# pshell3
# psk-crack
# pslog
# psql
# pstat
# pstree
# pstree.x11
# pt2to3
# ptar
# ptardiff
# ptargrep
# ptdump
# pth-curl
# pth-net
# pth-rpcclient
# pth-smbclient
# pth-smbget
# pth-sqsh
# pth-winexe
# pth-wmic
# pth-wmis
# ptrepack
# pttree
# ptweens3
# ptx
# pulseaudio
# pviews3
# pwd
# pwdx
# pwgen
# pw-inspector
# pwnat
# py3clean
# py3compile
# py3versions
# pybabel
# pybabel-python3
# pydoc2
# pydoc2.7
# pydoc3
# pydoc3.8
# pydoc3.9
# pyfiglet
# pygettext2
# pygettext2.7
# pygettext3
# pygettext3.8
# pygettext3.9
# pygmentize
# pyhtmlizer3
# pylupdate5
# pyppeteer-install
# pyproj
# pypykatz
# pyrcc5
# pyserial-miniterm
# pyserial-ports
# py.test-3
# pytest-3
# python
# python2
# python2.7
# python3
# python3.8
# python3.8-config
# python3.9
# python3.9-config
# python3-config
# python3-futurize
# python3-pasteurize
# python3-qr
# python3-tor-prompt
# python3-wsdump
# python-faraday
# pyuic5
# pyversions
# pywerview
# qcollectiongenerator
# qdbus
# qdbuscpp2xml
# qdbusviewer
# qdbusxml2cpp
# qdoc
# qdoc3
# qgltf
# qhelpconverter
# qhelpgenerator
# qlalr
# qmake
# qml
# qml1plugindump
# qmlbundle
# qmlcachegen
# qmleasing
# qmlimportscanner
# qmljs
# qmllint
# qmlmin
# qmlplugindump
# qmlprofiler
# qmlscene
# qmltestrunner
# qmlviewer
# qr
# qsslcaudit
# qt5ct
# qtattributionsscanner
# qtchooser
# qtconfig
# qtdiag
# qterminal
# qtpaths
# qtplugininfo
# quake
# quakeserver
# quickbook
# qvkgen
# r2
# r2agent
# r2pm
# rabin2
# racc2.7
# racc2y2.7
# radare2
# radiff2
# rafind2
# ragg2
# rahash2
# rake
# randpkt
# ranlib
# rarun2
# rasm2
# rawshark
# rax2
# rb
# rbash
# rcc
# rcp
# rctest
# rdesktop
# rdf2bin
# rdf2com
# rdf2ihx
# rdf2ith
# rdf2srec
# rdfdump
# rdflib
# rdjpgcom
# rdma
# rdoc
# rdoc2.7
# rdx
# readelf
# readlink
# realpath
# rearj
# reaver
# recon-cli
# recon-ng
# recon-web
# recordmydesktop
# reindexdb
# rendercheck
# renice
# reordercap
# repc
# replace
# replay.pl
# reset
# resizecons
# resizepart
# resolvectl
# resolveip
# resolve_stack_dump
# responder-BrowserListener
# responder-DHCP
# responder-FindSMB2UPTime
# responder-FindSQLSrv
# responder-Icmp-Redirect
# responder-MultiRelay
# responder-RunFinger
# rev
# rfcomm
# rgrep
# ri
# ri2.7
# ristretto
# rlogin
# rlogin-cwd
# rm
# rmdir
# rmid
# rmiregistry
# rnano
# ropper
# rotatelogs
# routef
# routel
# rpcclient
# rpcgen
# rpcinfo
# rq
# rqinfo
# rqworker
# rrsync
# rsh
# rsmangler
# rstart
# rstartd
# rsync
# rsync-ssl
# rtstat
# ruby
# ruby2.7
# runcon
# run-mailcap
# run-parts
# runscript
# run-with-aspell
# runxlrd
# ruptime
# rview
# rvim
# rwho
# rx
# rz
# rzsh
# sadf
# sakis3g
# samba-regedit
# samba-tool
# samdump2
# sane-find-scanner
# sanstats-9
# sar
# sar.sysstat
# savelog
# sb
# sbd
# scalpel
# scanimage
# scapy
# scapy3
# sccmap
# scp
# screen
# screendump
# script
# scriptlive
# scriptreplay
# sdiff
# sdptool
# searchsploit
# sed
# see
# select-default-iwrap
# select-editor
# sendemail
# sendEmail
# sendmsrpc
# sensible-browser
# sensible-editor
# sensible-pager
# seq
# sessreg
# setarch
# setcifsacl
# setfacl
# setfattr
# setfont
# setkeycodes
# setleds
# setlogcons
# setmetamode
# se-toolkit
# setoolkit
# setpci
# setpriv
# setsid
# setterm
# setupcon
# setvtrgb
# setxkbmap
# sfdp
# sfparse
# sftp
# sg
# sh
# sha1deep
# sha1sum
# sha224sum
# sha256deep
# sha256sum
# sha384sum
# sha512sum
# sharesec
# sharkd
# shasum
# shmemc++
# shmemcc
# shmemCC
# shmemcxx
# shmemfort
# shmemrun
# shodan
# showconsolefont
# showfigfonts
# showkey
# showrgb
# shred
# shuf
# sigfind
# size
# skill
# skipfish
# slabtop
# sleep
# slogin
# smb2-quota
# smbcacls
# smbclient
# smbcontrol
# smbcquotas
# smbget
# smbinfo
# smbmap
# smbpasswd
# smbspool
# smbstatus
# smbtar
# smbtree
# smproxy
# snice
# snmp-bridge-mib
# snmpbulkget
# snmpbulkwalk
# snmp-check
# snmpcheck
# snmpconf
# snmpdelta
# snmpdf
# snmpget
# snmpgetnext
# snmpinform
# snmpkey
# snmpnetstat
# snmpping
# snmpset
# snmpstatus
# snmptable
# snmptest
# snmptls
# snmptranslate
# snmptrap
# snmpusm
# snmpvacm
# snmpwalk
# socat
# soelim
# sort
# sorter
# sotruss
# sp32
# sp64
# spiderfoot
# spiderfoot-cli
# splain
# split
# splitfont
# spooftooph
# sprof
# sqldiff
# sqlite3
# sqlitebrowser
# sqlmap
# sqlmapapi
# sqsh
# srch_strings
# ss
# ssh
# ssh-add
# ssh-agent
# ssh-argv0
# ssh-copy-id
# ssh-keygen
# ssh-keyscan
# sslscan
# sslsplit
# sslyze
# ss_spike
# start-pulseaudio-x11
# startx
# startxfce4
# stat
# statd_spike
# stdbuf
# stl2gts
# strings
# strip
# stty
# stunnel
# stunnel3
# stunnel4
# su
# sudo
# sudoedit
# sudoreplay
# sum
# sunrpcfuzz
# svn
# svnadmin
# svnauthz
# svnauthz-validate
# svnbench
# svndumpfilter
# svnfsfs
# svnlook
# svnmucc
# svnrdump
# svnserve
# svnsync
# svnversion
# swaks
# swfparser
# sx
# symcryptrun
# sync
# systemctl
# systemd
# systemd-analyze
# systemd-ask-password
# systemd-cat
# systemd-cgls
# systemd-cgtop
# systemd-delta
# systemd-detect-virt
# systemd-escape
# systemd-hwdb
# systemd-id128
# systemd-inhibit
# systemd-machine-id-setup
# systemd-mount
# systemd-notify
# systemd-path
# systemd-resolve
# systemd-run
# systemd-socket-activate
# systemd-stdio-bridge
# systemd-sysusers
# systemd-tmpfiles
# systemd-tty-ask-password-agent
# systemd-umount
# sz
# tabs
# tabulate
# tac
# tail
# tapestat
# tar
# tasksel
# taskset
# tbl
# tclsh8.6
# tcpbridge
# tcpcapinfo
# tcpliveplay
# tcpprep
# tcpreplay
# tcpreplay-edit
# tcprewrite
# tdbbackup
# tdbbackup.tdbtools
# tdbdump
# tdbrestore
# tdbtool
# tee
# tempfile
# teredo-mire
# test
# testdisk
# testparm
# text2pcap
# tftp
# thc-pptp-bruter
# theharvester
# theHarvester
# thor
# thunar
# Thunar
# thunar-settings
# thunar-volman
# thunar-volman-settings
# tic
# tigerdeep
# tightvncconnect
# tightvncpasswd
# tightvncserver
# timedatectl
# timed-read
# timed-run
# timeout
# tjbench
# tkconch3
# tknewsbiff
# tkpasswd
# tload
# tmux
# toe
# top
# tor-prompt
# touch
# tpmc
# tpm-nvsize
# tput
# tqdm
# tr
# transform
# transset
# tred
# trial3
# troff
# true
# truncate
# trust
# tset
# tshark
# tsk_comparedir
# tsk_gettimes
# tsk_loaddb
# tsk_recover
# tsort
# tty
# twist3
# twistd3
# twopi
# tzselect
# ucf
# ucfq
# ucfr
# uconv
# ucs2any
# udevadm
# udisksctl
# udptunnel
# uic
# uic3
# ul
# umax_pp
# umount
# uname
# unar
# unbuffer
# uncompress
# uncompress.real
# unexpand
# unflatten
# unicode_start
# unicode_stop
# uniq
# unix2dos
# unix2mac
# unix-privesc-check
# unlink
# unlzma
# unmkinitramfs
# unpack200
# unshare
# unsquashfs
# unxz
# unzip
# unzipsfx
# update-alternatives
# updatedb
# updatedb.mlocate
# update-desktop-database
# update-leap
# update-mime-database
# upower
# uptime
# upx
# upx-ucl
# usb-devices
# usbhid-dump
# usbreset
# users
# usnjls
# /usr/bin:
# utmpdump
# vacuumdb
# vacuumlo
# vbutil_firmware
# vbutil_kernel
# vbutil_key
# vbutil_keyblock
# vdir
# verify-uselistorder-9
# VGAuthService
# vi
# view
# viewres
# vim
# vim.basic
# vimdiff
# vimdot
# vim.tiny
# vimtutor
# vmhgfs-fuse
# vmstat
# vm-support
# vmtoolsd
# vmware-checkvm
# vmwarectrl
# vmware-hgfsclient
# vmware-namespace-cmd
# vmware-rpctool
# vmware-toolbox-cmd
# vmware-user
# vmware-user-suid-wrapper
# vmware-vgauth-cmd
# vmware-vgauth-smoketest
# vmware-vmblock-fuse
# vmware-xferlogs
# vncconnect
# vncpasswd
# vncserver
# vncviewer
# voiphopper
# w
# wafw00f
# wall
# wapiti
# wapiti-getcookie
# wash
# watch
# watchgnupg
# wc
# wce
# wdctl
# webfuzz
# webshells
# weevely
# wfuzz
# wget
# whatis
# whatweb
# whereis
# which
# whiptail
# whirlpooldeep
# who
# whoami
# whois
# windows-binaries
# windows-resources
# winexe
# wireshark
# word-list-compress
# wordlists
# wpaclean
# wpa_passphrase
# w.procps
# wpscan
# write
# write.ul
# wrjpgcom
# wsdump
# wsrep_sst_common
# wsrep_sst_mariabackup
# wsrep_sst_mysqldump
# wsrep_sst_rsync
# wsrep_sst_rsync_wan
# X
# X11
# x11perf
# x11perfcomp
# x11_spike
# x86_64
# x86_64-linux-gnu-addr2line
# x86_64-linux-gnu-ar
# x86_64-linux-gnu-as
# x86_64-linux-gnu-c++filt
# x86_64-linux-gnu-cpp
# x86_64-linux-gnu-cpp-10
# x86_64-linux-gnu-cpp-9
# x86_64-linux-gnu-dwp
# x86_64-linux-gnu-elfedit
# x86_64-linux-gnu-g++
# x86_64-linux-gnu-g++-10
# x86_64-linux-gnu-gcc
# x86_64-linux-gnu-gcc-10
# x86_64-linux-gnu-gcc-9
# x86_64-linux-gnu-gcc-ar
# x86_64-linux-gnu-gcc-ar-10
# x86_64-linux-gnu-gcc-ar-9
# x86_64-linux-gnu-gcc-nm
# x86_64-linux-gnu-gcc-nm-10
# x86_64-linux-gnu-gcc-nm-9
# x86_64-linux-gnu-gcc-ranlib
# x86_64-linux-gnu-gcc-ranlib-10
# x86_64-linux-gnu-gcc-ranlib-9
# x86_64-linux-gnu-gcov
# x86_64-linux-gnu-gcov-10
# x86_64-linux-gnu-gcov-9
# x86_64-linux-gnu-gcov-dump
# x86_64-linux-gnu-gcov-dump-10
# x86_64-linux-gnu-gcov-dump-9
# x86_64-linux-gnu-gcov-tool
# x86_64-linux-gnu-gcov-tool-10
# x86_64-linux-gnu-gcov-tool-9
# x86_64-linux-gnu-gfortran
# x86_64-linux-gnu-gfortran-10
# x86_64-linux-gnu-gfortran-9
# x86_64-linux-gnu-gold
# x86_64-linux-gnu-gprof
# x86_64-linux-gnu-ld
# x86_64-linux-gnu-ld.bfd
# x86_64-linux-gnu-ld.gold
# x86_64-linux-gnu-lto-dump-10
# x86_64-linux-gnu-nm
# x86_64-linux-gnu-objcopy
# x86_64-linux-gnu-objdump
# x86_64-linux-gnu-python3.8-config
# x86_64-linux-gnu-python3.9-config
# x86_64-linux-gnu-python3-config
# x86_64-linux-gnu-ranlib
# x86_64-linux-gnu-readelf
# x86_64-linux-gnu-size
# x86_64-linux-gnu-strings
# x86_64-linux-gnu-strip
# xargs
# xauth
# xbiff
# xcalc
# xcape
# xclipboard
# xclock
# xcmsdb
# xconsole
# xcursorgen
# xcutsel
# xdg-dbus-proxy
# xdg-desktop-icon
# xdg-desktop-menu
# xdg-email
# xdg-icon-resource
# xdg-mime
# xdg-open
# xdg-screensaver
# xdg-settings
# xdg-user-dir
# xdg-user-dirs-gtk-update
# xdg-user-dirs-update
# xditview
# xdotool
# xdpyinfo
# xdriinfo
# xedit
# xev
# xeyes
# xfce4-about
# xfce4-accessibility-settings
# xfce4-appearance-settings
# xfce4-appfinder
# xfce4-clipman
# xfce4-clipman-history
# xfce4-clipman-settings
# xfce4-color-settings
# xfce4-display-settings
# xfce4-find-cursor
# xfce4-keyboard-settings
# xfce4-mime-settings
# xfce4-mouse-settings
# xfce4-notifyd-config
# xfce4-panel
# xfce4-popup-applicationsmenu
# xfce4-popup-clipman
# xfce4-popup-clipman-actions
# xfce4-popup-directorymenu
# xfce4-popup-places
# xfce4-popup-whiskermenu
# xfce4-popup-windowmenu
# xfce4-power-manager
# xfce4-power-manager-settings
# xfce4-screenshooter
# xfce4-sensors
# xfce4-session
# xfce4-session-logout
# xfce4-session-settings
# xfce4-settings-editor
# xfce4-settings-manager
# xfce4-taskmanager
# xfconf-query
# xfd
# xfdesktop
# xfdesktop-settings
# xfhelp4
# xflock4
# xfontsel
# xfreerdp
# xfrun4
# xfsettingsd
# xfwm4
# xfwm4-settings
# xfwm4-tweaks-settings
# xfwm4-workspace-settings
# xgamma
# xgc
# xhost
# xhydra
# xiccd
# xinit
# xkbbell
# xkbcomp
# xkbevd
# xkbprint
# xkbvleds
# xkbwatch
# xkeystone
# xkibitz
# xkill
# xload
# xlogo
# xlsatoms
# xlsclients
# xlsfonts
# xmag
# xman
# xmessage
# xminicom
# xmlcatalog
# xmllint
# xmlparse
# xmlpatterns
# xmlpatternsvalidator
# xmodmap
# xmore
# Xorg
# xprop
# xpstat
# xrandr
# xrdb
# xrefresh
# x-session-manager
# xset
# xsetmode
# xsetpointer
# xsetroot
# xsltproc
# xsm
# xstdcmap
# xsubpp
# x-terminal-emulator
# Xtightvnc
# xtightvncviewer
# Xvfb
# xvfb-run
# xvidtune
# xvinfo
# Xvnc
# xvncviewer
# xwd
# x-window-manager
# xwininfo
# xwud
# x-www-browser
# xxd
# xz
# xzcat
# xzcmp
# xzdiff
# xzegrep
# xzfgrep
# xzgrep
# xzless
# xzmore
# y2racc2.7
# yaml2obj-9
# yaml-bench-9
# yes
# ypdomainname
# zaproxy
# zcat
# zcmp
# zdiff
# zdump
# zegrep
# zenity
# zfgrep
# zforce
# zgrep
# zip
# zipcloak
# zipdetails
# zipgrep
# zipinfo
# zipnote
# zipsplit
# zless
# zmore
# znew
# zsh
# zsh5

# %% [markdown]
# ### wc
# - word count command is used to display the number of lines, words, and bytes contained in files

# %%
! wc sortedls.txt
# Out:
#   19  166 1177 sortedls.txt

# %%
# count lines
! wc -l sortedls.txt
# Out:
# 19 sortedls.txt

# %%
# count words
! wc -w sortedls.txt
# Out:
# 166 sortedls.txt

# %%
# count bytes/characters
! wc -c sortedls.txt
# Out:
# 1177 sortedls.txt

# %% [markdown]
# ### head/tail
# - print first/last 10 lines of files

# %%
! head sortedls.txt
# Out:
# -rw-r--r-- 1 kali kali 134819 Feb  9 13:03 Ch06-IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 kali kali  89211 Feb  9 13:12 Ch02-NavigationExploration.ipynb
# -rw-r--r-- 1 kali kali  27124 Feb  9 13:14 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 kali kali  25699 Feb  9 13:30 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 kali kali  24293 Feb  9 13:03 Ch09-UtilityCommands.ipynb
# -rw-r--r-- 1 kali kali  20482 Feb  9 13:26 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 kali kali  13070 Feb  9 13:03 Ch07-ExpansionAndSubstitution.ipynb
# -rw-r--r-- 1 kali kali   4146 Feb  9 13:07 Ch01-LearningShell.ipynb
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:03 resources
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test1

# %%
! tail sortedls.txt
# Out:
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test1
# drwxr-xr-x 2 kali kali   4096 Feb  9 13:12 test2
# -rw-r--r-- 1 kali kali   3771 Feb  9 13:03 Ch08-JobsAndProcessControl.ipynb
# -rw-r--r-- 1 kali kali   1745 Feb  9 13:31 ls.txt
# -rw-r--r-- 1 kali kali    544 Feb  9 13:03 README.md
# lrwxrwxrwx 1 kali kali      7 Feb  9 13:15 softfoolink -> foo.txt
# -rw-r--r-- 1 kali kali      0 Feb  9 13:13 test.txt
# -rw-r--r-- 1 kali kali      0 Feb  9 13:31 sortedls.txt
# -rwxr----- 1 user user      0 Feb  9 13:15 foo.txt
# total 372

# %%
# use -n n to display n lines
! head -n 5 sortedls.txt
# Out:
# -rw-r--r-- 1 kali kali 134819 Feb  9 13:03 Ch06-IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 kali kali  89211 Feb  9 13:12 Ch02-NavigationExploration.ipynb
# -rw-r--r-- 1 kali kali  27124 Feb  9 13:14 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 kali kali  25699 Feb  9 13:30 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 kali kali  24293 Feb  9 13:03 Ch09-UtilityCommands.ipynb

# %%
! tail -n 5 sortedls.txt
# Out:
# lrwxrwxrwx 1 kali kali      7 Feb  9 13:15 softfoolink -> foo.txt
# -rw-r--r-- 1 kali kali      0 Feb  9 13:13 test.txt
# -rw-r--r-- 1 kali kali      0 Feb  9 13:31 sortedls.txt
# -rwxr----- 1 user user      0 Feb  9 13:15 foo.txt
# total 372

# %%
! ls /usr/bin | tail -n 5
# Out:
# zless
# zmore
# znew
# zsh
# zsh5

# %%
# monitor a file with -f option
# when new messages/lines appened to a file being monitored they immidiately appear on the display
# contines until you enter Ctrl-c
! tail -f /var/log/messages
# Out:
# tail: cannot open '/var/log/messages' for reading: Permission denied
# tail: no files remaining

# %% [markdown]
# ### tee
# - read from stdin and output to stdout and files
# - similar to "T" fitting on pipes (plumbing)

# %%
! ls /usr/bin | tee ls.txt | grep zip
# Out:
# bunzip2
# bzip2
# bzip2recover
# funzip
# gpg-zip
# gunzip
# gzip
# p7zip
# preunzip
# prezip
# prezip-bin
# unzip
# unzipsfx
# zip
# zipcloak
# zipdetails
# zipgrep
# zipinfo
# zipnote
# zipsplit

# %%
! cat ls.txt
# Out:
# [
# 2to3-2.7
# 7z
# 7za
# 7zr
# aa-enabled
# aa-exec
# ab
# aclocal
# aclocal-1.16
# acyclic
# addpart
# addr2line
# agentxtrap
# aggregate_profile.pl
# aircrack-ng
# airdecap-ng
# airdecloak-ng
# airolib-ng
# amass
# appres
# apropos
# apt
# apt-cache
# apt-cdrom
# apt-config
# apt-extracttemplates
# apt-ftparchive
# apt-get
# apt-key
# apt-mark
# apt-sortpkgs
# apython
# ar
# arch
# aria_chk
# aria_dump_log
# aria_ftdump
# aria_pack
# aria_read_log
# arj
# arjdisp
# arj-register
# as
# asan_symbolize
# asan_symbolize-9
# ascii-xfr
# aspell
# aspell-import
# assistant
# atk6-address6
# atk6-alive6
# atk6-connect6
# atk6-connsplit6
# atk6-covert_send6
# atk6-covert_send6d
# atk6-denial6
# atk6-detect-new-ip6
# atk6-detect_sniffer6
# atk6-dnsdict6
# atk6-dnsrevenum6
# atk6-dnssecwalk
# atk6-dos-new-ip6
# atk6-dump_dhcp6
# atk6-dump_router6
# atk6-exploit6
# atk6-extract_hosts6
# atk6-extract_networks6
# atk6-fake_advertise6
# atk6-fake_dhcps6
# atk6-fake_dns6d
# atk6-fake_dnsupdate6
# atk6-fake_mipv6
# atk6-fake_mld26
# atk6-fake_mld6
# atk6-fake_mldrouter6
# atk6-fake_pim6
# atk6-fake_router26
# atk6-fake_router6
# atk6-fake_solicitate6
# atk6-firewall6
# atk6-flood_advertise6
# atk6-flood_dhcpc6
# atk6-flood_mld26
# atk6-flood_mld6
# atk6-flood_mldrouter6
# atk6-flood_redir6
# atk6-flood_router26
# atk6-flood_router6
# atk6-flood_rs6
# atk6-flood_solicitate6
# atk6-flood_unreach6
# atk6-four2six
# atk6-fragmentation6
# atk6-fragrouter6
# atk6-fuzz_dhcpc6
# atk6-fuzz_dhcps6
# atk6-fuzz_ip6
# atk6-implementation6
# atk6-implementation6d
# atk6-inject_alive6
# atk6-inverse_lookup6
# atk6-kill_router6
# atk6-ndpexhaust26
# atk6-ndpexhaust6
# atk6-node_query6
# atk6-parasite6
# atk6-passive_discovery6
# atk6-randicmp6
# atk6-redir6
# atk6-redirsniff6
# atk6-rsmurf6
# atk6-sendpees6
# atk6-sendpeesmp6
# atk6-smurf6
# atk6-thcping6
# atk6-thcsyn6
# atk6-toobig6
# atk6-toobigsniff6
# atk6-trace6
# atobm
# atril
# atril-previewer
# atril-thumbnailer
# attr
# autoconf
# autoexpect
# autogsdoc
# autoheader
# autom4te
# automake
# automake-1.16
# automat-visualize3
# autopasswd
# autopsy
# autoreconf
# autoscan
# autoupdate
# awk
# axel
# b2
# b2sum
# base32
# base64
# basename
# basenc
# bash
# bashbug
# bccmd
# bcomps
# bcp
# bdftopcf
# bdftruncate
# besside-ng-crawler
# binwalk
# bitmap
# bjam
# blkcalc
# blkcat
# blkls
# blkstat
# blueman-adapters
# blueman-applet
# blueman-assistant
# blueman-manager
# blueman-report
# blueman-sendto
# blueman-services
# blueman-tray
# bluemoon
# bluetoothctl
# bmtoa
# bootctl
# broadwayd
# btattach
# btmgmt
# btmon
# buddy-ng
# bugpoint-9
# bulk_extractor
# bully
# bundle
# bundle2.7
# bundler
# bundler2.7
# bunzip2
# burpsuite
# busctl
# busybox
# bwrap
# bzcat
# bzcmp
# bzdiff
# bzegrep
# bzexe
# bzfgrep
# bzgrep
# bzip2
# bzip2recover
# bzless
# bzmore
# c++
# c89
# c89-gcc
# c99
# c99-gcc
# cabextract
# cadaver
# cal
# calc_tickadj
# calendar
# canberra-gtk-play
# capinfos
# captoinfo
# captype
# cat
# catchsegv
# catfish
# catman
# cc
# ccache
# ccache2kirbi
# ccacheedit
# ccacheroast
# ccomps
# cct
# cd-create-profile
# cd-fix-profile
# cd-iccdump
# cd-it8
# cewl
# c++filt
# cftp3
# cgpt
# chacl
# chage
# chardet
# chardetect
# chattr
# chcon
# checkgid
# cherryd3
# cherrytree
# chfn
# chgrp
# chkfont
# chmod
# choom
# chown
# chromeos-tpm-recovery
# chrt
# chsh
# chvt
# cifscreds
# cifsdd
# cifsiostat
# ciptool
# circo
# cisco-decrypt
# citrix
# cjpeg
# ckbcomp
# ckeygen3
# cksum
# clang
# clang++
# clang++-9
# clang-9
# clang-cpp-9
# clear
# clear_console
# closed_source_web_server_fuzz
# cluster
# clusterdb
# cmedb
# cmp
# code
# codepage
# col
# colormgr
# colrm
# column
# comm
# commix
# compose
# compress
# conch3
# corelist
# count-9
# cp
# cpan
# cpan5.30-x86_64-linux-gnu
# cpio
# cpp
# cpp-10
# cpp-9
# crackmapexec
# cramfsswap
# createdb
# createlang
# createuser
# c_rehash
# crontab
# crossystem
# crunch
# cryptcat
# cryptdir
# cs2cs
# csplit
# ctstat
# curl
# curlftpfs
# cut
# cutycapt
# cvt
# cvtenc
# cvtsudoers
# cygdb3
# cython3
# dash
# date
# dave
# davtest
# dbd
# dbilogstrip
# dbiprof
# dbiproxy
# dbus-cleanup-sockets
# dbus-daemon
# dbus-monitor
# dbus-run-session
# dbus-send
# dbus-update-activation-environment
# dbus-uuidgen
# dbwrap_tool
# dccleancrw
# dceoversmb
# dcfujigreen
# dcfujiturn
# dcfujiturn16
# dcparse
# dcraw
# dd
# ddcmon
# deallocvt
# debconf
# debconf-apt-progress
# debconf-communicate
# debconf-copydb
# debconf-escape
# debconf-set-selections
# debconf-show
# deb-systemd-helper
# deb-systemd-invoke
# debtags
# debugapp
# decode-dimms
# decode-edid
# decode-vaio
# decryptdir
# defaults
# delaunay
# delpart
# delv
# derb
# designer
# desktop-file-edit
# desktop-file-install
# desktop-file-validate
# dev_debug_vboot
# df
# dh_autotools-dev_restoreconfig
# dh_autotools-dev_updateconfig
# dh_bash-completion
# dh_girepository
# dh_numpy3
# dh_perl_dbi
# dh_perl_openssl
# dh_python3-ply
# diff
# diff3
# diffimg
# dig
# dijkstra
# dir
# dirb
# dirb-gendict
# dirbuster
# dircolors
# dirmngr
# dirmngr-client
# dirname
# dislocate
# django-admin
# djpeg
# dltest
# dmesg
# dmitry
# dm-tool
# dns2tcpc
# dns2tcpd
# dnschef
# dnsdomainname
# dnsenum
# dns-rebind
# dnsrecon
# dnstap-read
# domainname
# do_post
# dos2unix
# dot
# dot2gxl
# dot_builtins
# dotlockfile
# dotty
# dpkg
# dpkg-architecture
# dpkg-buildflags
# dpkg-buildpackage
# dpkg-checkbuilddeps
# dpkg-deb
# dpkg-distaddfile
# dpkg-divert
# dpkg-genbuildinfo
# dpkg-genchanges
# dpkg-gencontrol
# dpkg-gensymbols
# dpkg-maintscript-helper
# dpkg-mergechangelogs
# dpkg-name
# dpkg-parsechangelog
# dpkg-query
# dpkg-realpath
# dpkg-scanpackages
# dpkg-scansources
# dpkg-shlibdeps
# dpkg-source
# dpkg-split
# dpkg-statoverride
# dpkg-trigger
# dpkg-vendor
# dpl4hydra
# dropdb
# droplang
# dropuser
# dsymutil-9
# du
# dumpcap
# dump_fmap
# dump_kernel_config
# dumpkeys
# dumpmscat
# dumpRSAPublicKey
# dupemap
# dwp
# echo
# edgepaint
# edit
# editcap
# editor
# editres
# efibootdump
# efibootmgr
# egrep
# eject
# elfedit
# enable_dev_usb_boot
# enc2xs
# encguess
# enchant-2
# enchant-lsmod-2
# encode_keychange
# engrampa
# enum4linux
# env
# envsubst
# eqn
# erb
# erb2.7
# ettercap
# ettercap-pkexec
# etterfilter
# etterlog
# ex
# exe2hex
# exifautotran
# exiv2
# exo-csource
# exo-desktop-item-edit
# exo-open
# exo-preferred-applications
# expand
# expect
# expect_autoexpect
# expect_autopasswd
# expect_cryptdir
# expect_decryptdir
# expect_dislocate
# expect_ftp-rfc
# expect_kibitz
# expect_lpunlock
# expect_mkpasswd
# expect_multixterm
# expect_passmass
# expect_rftp
# expect_rlogin-cwd
# expect_timed-read
# expect_timed-run
# expect_tknewsbiff
# expect_tkpasswd
# expect_unbuffer
# expect_weather
# expect_xkibitz
# expect_xpstat
# expiry
# exploitdb
# expr
# f2py3
# f2py3.9
# f77
# f95
# fab-cewl
# factor
# faillog
# fallocate
# false
# faraday
# faraday-client
# faraday-manage
# faraday-plugins
# faraday-searcher
# faraday-server
# fastjar
# fcat
# fc-cache
# fc-cat
# fc-conflist
# fcgistarter
# fc-list
# fc-match
# fc-pattern
# fc-query
# fc-scan
# fc-validate
# fdp
# fern-wifi-cracker
# ffind
# fgconsole
# fgrep
# fidentify
# fierce
# figlet
# figlet-figlet
# figlist
# filan
# file
# FileCheck-9
# fincore
# find
# findmnt
# findsmb
# finger
# firefox
# firefox-esr
# fiwalk
# fixproc
# flac
# flask
# flock
# fls
# fmt
# fold
# fonttosfnt
# fping
# fping6
# fplugin
# free
# fsstat
# ftp
# ftp-rfc
# funzip
# fuser
# fusermount
# fusermount3
# futility
# futurize
# g++
# g++-10
# galera_new_cluster
# galera_recovery
# gamma4scanimage
# gapplication
# gatttool
# gawk
# gbb_utility
# gc
# gcc
# gcc-10
# gcc-9
# gcc-ar
# gcc-ar-10
# gcc-ar-9
# gcc-nm
# gcc-nm-10
# gcc-nm-9
# gcc-ranlib
# gcc-ranlib-10
# gcc-ranlib-9
# gcore
# gcov
# gcov-10
# gcov-9
# gcov-dump
# gcov-dump-10
# gcov-dump-9
# gcov-tool
# gcov-tool-10
# gcov-tool-9
# gcr-viewer
# gdb
# gdb-add-index
# gdbserver
# gdbtui
# gdbus
# gdialog
# gdk-pixbuf-csource
# gdk-pixbuf-pixdata
# gdk-pixbuf-thumbnailer
# gdnc
# gdomap
# gem
# gem2.7
# genbrk
# gencat
# gencfu
# gencnval
# gendict
# generic_chunked
# generic_listen_tcp
# generic_send_tcp
# generic_send_udp
# generic_web_server_fuzz
# generic_web_server_fuzz2
# genrb
# geod
# geqn
# GET
# getcifsacl
# getconf
# get-edid
# getent
# getfacl
# getfattr
# getkeycodes
# getopt
# getS4U2proxy
# gettext
# gettext.sh
# getTGS
# getTGT
# gfortran
# gfortran-10
# gfortran-9
# gie
# gio
# gio-querymodules
# g-ir-annotation-tool
# g-ir-compiler
# g-ir-doc-tool
# g-ir-generate
# g-ir-inspect
# g-ir-scanner
# git
# git-receive-pack
# git-shell
# git-upload-archive
# git-upload-pack
# glib-compile-schemas
# gmake
# gml2gv
# gnome-keyring
# gnome-keyring-3
# gnome-keyring-daemon
# gnome-www-browser
# gold
# gopherd
# gpasswd
# gpg
# gpg-agent
# gpgcompose
# gpgconf
# gpg-connect-agent
# gpgparsemail
# gpgsm
# gpgsplit
# gpgtar
# gpgv
# gpg-wks-server
# gpg-zip
# gpic
# gpp-decrypt
# gprof
# graphml2gv
# grep
# grepjar
# gresource
# groff
# grog
# grops
# grotty
# groups
# grub-editenv
# grub-file
# grub-fstest
# grub-glue-efi
# grub-kbdcomp
# grub-menulst2cfg
# grub-mkfont
# grub-mkimage
# grub-mklayout
# grub-mknetdir
# grub-mkpasswd-pbkdf2
# grub-mkrelpath
# grub-mkrescue
# grub-mkstandalone
# grub-mount
# grub-render-label
# grub-script-check
# grub-syslinux2cfg
# gsettings
# gspath
# gtbl
# gtf
# gtk-builder-tool
# gtk-encode-symbolic-svg
# gtk-launch
# gtk-query-settings
# gtk-update-icon-cache
# gts2dxf
# gts2oogl
# gts2stl
# gts2xyz
# gtscheck
# gtscompare
# gts-config
# gtstemplate
# gunzip
# guymager
# gv2gml
# gv2gxl
# gvcolor
# gvgen
# gvmap
# gvmap.sh
# gvpack
# gvpr
# gxl2dot
# gxl2gv
# gzexe
# gzip
# h2ph
# h2xs
# halflife
# hashcat
# hashdeep
# hashid
# hash-identifier
# hciattach
# hciconfig
# hcidump
# hcitool
# hd
# head
# HEAD
# helpztags
# hex2hcd
# hexdump
# hexeditor
# hfind
# host
# hostid
# hostname
# hostnamectl
# hotpatcher
# htcacheclean
# htdbm
# htdigest
# html2dic
# html2markdown
# html2markdown.py3
# HTMLLinker
# htpasswd
# hupper3
# hwloc-annotate
# hwloc-bind
# hwloc-calc
# hwloc-compress-dir
# hwloc-diff
# hwloc-distrib
# hwloc-gather-cpuid
# hwloc-gather-topology
# hwloc-info
# hwloc-ls
# hwloc-patch
# hwloc-ps
# hydra
# hydra-wizard
# i386
# icalendar
# icat
# iceauth
# ico
# iconv
# icuinfo
# id
# ifind
# ifnames
# ike-scan
# ils
# img_cat
# img_stat
# impacket-addcomputer
# impacket-atexec
# impacket-dcomexec
# impacket-dpapi
# impacket-esentutl
# impacket-exchanger
# impacket-findDelegation
# impacket-GetADUsers
# impacket-getArch
# impacket-GetNPUsers
# impacket-getPac
# impacket-getST
# impacket-getTGT
# impacket-GetUserSPNs
# impacket-goldenPac
# impacket-karmaSMB
# impacket-kintercept
# impacket-lookupsid
# impacket-mimikatz
# impacket-mqtt_check
# impacket-mssqlclient
# impacket-mssqlinstance
# impacket-netview
# impacket-nmapAnswerMachine
# impacket-ntfs-read
# impacket-ntlmrelayx
# impacket-ping
# impacket-ping6
# impacket-psexec
# impacket-raiseChild
# impacket-rdp_check
# impacket-reg
# impacket-registry-read
# impacket-rpcdump
# impacket-rpcmap
# impacket-sambaPipe
# impacket-samrdump
# impacket-secretsdump
# impacket-services
# impacket-smbclient
# impacket-smbexec
# impacket-smbrelayx
# impacket-smbserver
# impacket-sniff
# impacket-sniffer
# impacket-split
# impacket-ticketConverter
# impacket-ticketer
# impacket-wmiexec
# impacket-wmipersist
# impacket-wmiquery
# inetsim
# infocmp
# infotocap
# innochecksum
# innotop
# inspect
# install
# instmodsh
# inv
# invgeod
# invoke
# invproj
# ionice
# iostat
# ip
# ipcmk
# ipcrm
# ipcs
# iptables-xml
# ipwhois_cli.py
# ipwhois_utils_cli.py
# ipython3
# irb
# irb2.7
# ischroot
# ispell-wrapper
# istat
# ivstools
# jar
# jardetector
# jarwrapper
# java
# jcat
# jexec
# jfr
# jjs
# jls
# join
# journalctl
# jpegexiforient
# jpeg_extract
# jpegtran
# json_pp
# jsonschema
# jupyter
# jupyter-bundlerextension
# jupyter-console
# jupyter-kernel
# jupyter-kernelspec
# jupyter-migrate
# jupyter-nbconvert
# jupyter-nbextension
# jupyter-notebook
# jupyter-run
# jupyter-serverextension
# jupyter-troubleshoot
# jupyter-trust
# kali-hidpi-mode
# kali-motd
# kali-setup
# kali-treecd
# kali-undercover
# kali-winexec
# kazam
# kbdinfo
# kbd_mode
# kbxutil
# kernel-install
# keyctl
# keytool
# kibitz
# kill
# killall
# kirbi2ccache
# kismet
# kismet_cap_freaklabs_zigbee
# kismet_cap_kismetdb
# kismet_cap_linux_bluetooth
# kismet_cap_linux_wifi
# kismet_cap_nrf_51822
# kismet_cap_nrf_mousejack
# kismet_cap_nxp_kw41z
# kismet_cap_pcapfile
# kismet_cap_sdr_rtl433
# kismet_cap_sdr_rtladsb
# kismet_cap_sdr_rtlamr
# kismet_cap_ti_cc_2531
# kismet_cap_ti_cc_2540
# kismet_cap_ubertooth_one
# kismetdb_clean
# kismetdb_dump_devices
# kismetdb_statistics
# kismetdb_strip_packets
# kismetdb_to_gpx
# kismetdb_to_kml
# kismetdb_to_pcap
# kismetdb_to_wiglecsv
# kismet_server
# kmod
# kstats
# l2ping
# l2test
# laptop-detect
# last
# lastb
# lastlog
# lbd
# lcf
# lconvert
# ld
# ldapadd
# ldapcompare
# ldapdelete
# ldapdomaindump
# ldapexop
# ldapmodify
# ldapmodrdn
# ldappasswd
# ldapsearch
# ldapurl
# ldapwhoami
# ld.bfd
# ldd
# ldd2bloodhound
# ldd2pretty
# ld.gold
# ldrdf
# lefty
# legion
# less
# lessecho
# lessfile
# lesskey
# lesspipe
# lexgrog
# libnetcfg
# libtoolize
# libwacom-list-local-devices
# lightdm-gtk-greeter-settings
# lightdm-gtk-greeter-settings-pkexec
# light-locker
# light-locker-command
# line_send_tcp
# linguist
# link
# linux32
# linux64
# linux-boot-prober
# linux-check-removal
# linux-update-symlinks
# linux-version
# listres
# llc-9
# lli-9
# lli-child-target-9
# llvm-addr2line-9
# llvm-ar-9
# llvm-as-9
# llvm-bcanalyzer-9
# llvm-cat-9
# llvm-cfi-verify-9
# llvm-config-9
# llvm-cov-9
# llvm-c-test-9
# llvm-cvtres-9
# llvm-cxxdump-9
# llvm-cxxfilt-9
# llvm-cxxmap-9
# llvm-diff-9
# llvm-dis-9
# llvm-dlltool-9
# llvm-dwarfdump-9
# llvm-dwp-9
# llvm-elfabi-9
# llvm-exegesis-9
# llvm-extract-9
# llvm-jitlink-9
# llvm-lib-9
# llvm-link-9
# llvm-lipo-9
# llvm-lto2-9
# llvm-lto-9
# llvm-mc-9
# llvm-mca-9
# llvm-modextract-9
# llvm-mt-9
# llvm-nm-9
# llvm-objcopy-9
# llvm-objdump-9
# llvm-opt-report-9
# llvm-pdbutil-9
# llvm-PerfectShuffle-9
# llvm-profdata-9
# llvm-ranlib-9
# llvm-rc-9
# llvm-readelf-9
# llvm-readobj-9
# llvm-rtdyld-9
# llvm-size-9
# llvm-split-9
# llvm-stress-9
# llvm-strings-9
# llvm-strip-9
# llvm-symbolizer-9
# llvm-tblgen-9
# llvm-undname-9
# llvm-xray-9
# ln
# lneato
# lnstat
# loadkeys
# loadunimap
# locale
# localectl
# localedef
# locate
# logger
# login
# loginctl
# logname
# logresolve
# look
# lowntfs-3g
# lpunlock
# lrelease
# ls
# lsar
# lsassy
# lsattr
# lsblk
# lsb_release
# lscpu
# lsinitramfs
# lsipc
# lslocks
# lslogins
# lsmem
# lsmod
# lsns
# lsof
# lspci
# lspgpot
# lstopo
# lstopo-no-graphics
# lsusb
# lto-dump-10
# luit
# lupdate
# lwp-download
# lwp-dump
# lwp-mirror
# lwp-request
# lzcat
# lzcmp
# lzdiff
# lzegrep
# lzfgrep
# lzgrep
# lzless
# lzma
# lzmainfo
# lzmore
# m4
# mac2unix
# macchanger
# mactime
# magicrescue
# magicsort
# mailmail3
# make
# makeconv
# make-first-existing-target
# makeivs-ng
# make_strings
# mako-render
# maltego
# man
# mandb
# manpath
# man-recode
# mapscrn
# mariadb
# mariadb-check
# mariadb-service-convert
# markdown_py
# masscan
# mate-calc
# mate-calc-cmd
# mate-calculator
# mate-terminal
# mate-terminal.wrapper
# mawk
# mcookie
# md5deep
# md5sum
# md5sum.textutils
# mdig
# mdsearch
# mech-dump
# medusa
# mergecap
# mesa-overlay-control.py
# mesg
# metaflac
# mibdump
# migrate-pubring-from-classic-gpg
# mimikatz
# mingle
# minicom
# minidump
# mitmdump
# mitmproxy
# mitmweb
# mkdir
# mkfifo
# mkfontdir
# mkfontscale
# mk_modmap
# mknod
# mkpasswd
# mksquashfs
# mktemp
# mlocate
# mm2gv
# mmcat
# mmcli
# mmdbresolve
# mmls
# mmstat
# moc
# monitor-sensor
# more
# mount
# mountpoint
# mousepad
# mp32
# mp3-decoder
# mp64
# mpg123
# mpg123-alsa
# mpg123.bin
# mpg123-id3dump
# mpg123-jack
# mpg123-nas
# mpg123-openal
# mpg123-oss
# mpg123-portaudio
# mpg123-pulse
# mpg123-strip
# mpic++
# mpicc
# mpiCC
# mpicc.openmpi
# mpiCC.openmpi
# mpic++.openmpi
# mpicxx
# mpicxx.openmpi
# mpiexec
# mpiexec.openmpi
# mpif77
# mpif77.openmpi
# mpif90
# mpif90.openmpi
# mpifort
# mpifort.openmpi
# mpijavac
# mpirun
# mpirun.openmpi
# mpris-proxy
# mpstat
# msfconsole
# msfd
# msfdb
# msf-egghunter
# msf-exe2vba
# msf-exe2vbs
# msf-find_badchars
# msf-halflm_second
# msf-hmac_sha1_crack
# msf-java_deserializer
# msf-jsobfu
# msf-makeiplist
# msf-md5_lookup
# msf-metasm_shell
# msf-msf_irb_shell
# msf-nasm_shell
# msf-pattern_create
# msf-pattern_offset
# msfpc
# msf-pdf2xdp
# msfrpc
# msfrpcd
# msfupdate
# msfvenom
# msf-virustotal
# msldap
# msql2mysql
# msrpcfuzz
# msrpcfuzz_udp
# mt
# mt-gnu
# mtrace
# multimac
# multixterm
# mv
# mvxattr
# myisamchk
# myisam_ftdump
# myisamlog
# myisampack
# my_print_defaults
# mysql
# mysqlaccess
# mysqladmin
# mysqlanalyze
# mysqlbinlog
# mysqlcheck
# mysql_convert_table_format
# mysqld_multi
# mysqld_safe
# mysqld_safe_helper
# mysqldump
# mysqldumpslow
# mysql_embedded
# mysql_find_rows
# mysql_fix_extensions
# mysqlhotcopy
# mysqlimport
# mysql_install_db
# mysqloptimize
# mysql_plugin
# mysqlrepair
# mysqlreport
# mysql_secure_installation
# mysql_setpermission
# mysqlshow
# mysqlslap
# mysql_tzinfo_to_sql
# mysql_upgrade
# mysql_waitpid
# mytop
# namei
# nano
# nasm
# nawk
# nbtscan
# nc
# ncal
# ncrack
# nc.traditional
# ncurses5-config
# ncurses6-config
# ncursesw5-config
# ncursesw6-config
# ndisasm
# neato
# neqn
# net
# netaddr
# netcat
# netkit-ftp
# netmask
# netsed
# net-server
# net-snmp-create-v3-user
# netstat
# networkctl
# newgrp
# ngettext
# ngrep
# nice
# nikto
# nisdomainname
# nl
# nm
# nmap
# nm-applet
# nmblookup
# nmcli
# nm-connection-editor
# nm-online
# nmtui
# nmtui-connect
# nmtui-edit
# nmtui-hostname
# nohup
# nokogiri
# nop
# not-9
# notify-send
# nping
# nproc
# nroff
# nsenter
# nslookup
# nstat
# nsupdate
# ntfs-3g
# ntfs-3g.probe
# ntfscat
# ntfscluster
# ntfscmp
# ntfsdecrypt
# ntfsfallocate
# ntfsfix
# ntfsinfo
# ntfsls
# ntfsmove
# ntfsrecover
# ntfssecaudit
# ntfstruncate
# ntfsusermap
# ntfswipe
# ntlm2
# ntlm_brute
# ntpdc
# ntpq
# ntpsweep
# ntptrace
# numfmt
# obexctl
# obj2yaml-9
# objcopy
# objdump
# oclock
# od
# odbcinst
# oLschema2ldif
# ompi-clean
# ompi_info
# ompi-server
# on_ac_power
# onesixtyone
# opalc++
# opalcc
# opal_wrapper
# openapp
# openfortivpn
# openssl
# opentool
# openvt
# ophcrack
# ophcrack-cli
# opt-9
# ortecc
# orte-clean
# orted
# orte-info
# orterun
# orte-server
# osage
# oshc++
# oshcc
# oshCC
# oshcxx
# oshfort
# oshmem_info
# oshrun
# os-prober
# out123
# owasp-zap
# p11-kit
# p7zip
# pacat
# pack200
# packetforge-ng
# pacmd
# pactl
# padsp
# pager
# pa-info
# pamon
# pandoc
# paperconf
# paplay
# parec
# parecord
# parole
# parse-edid
# partx
# passmass
# passwd
# paste
# paster3
# pasteurize
# pasuspender
# patator
# patch
# patchwork
# pathchk
# pathoc
# pathod
# pavucontrol
# pax11publish
# pcf2vpnc
# pcreate3
# pdb2
# pdb2.7
# pdb3
# pdb3.8
# pdb3.9
# pdbedit
# pdfid
# pdf-parser
# pdistreport3
# peekfd
# perf
# perl
# perl5.30.3
# perl5.30-x86_64-linux-gnu
# perlbug
# perldoc
# perlivp
# perlthanks
# perror
# pfc
# pftp
# pg_archivecleanup
# pg_basebackup
# pgbench
# pg_buildext
# pgcli
# pg_config
# pg_conftool
# pg_createcluster
# pg_ctlcluster
# pg_dropcluster
# pg_dump
# pg_dumpall
# pg_isready
# pg_lsclusters
# pg_receivewal
# pg_receivexlog
# pg_recvlogical
# pg_renamecluster
# pgrep
# pg_restore
# pg_upgradecluster
# pg_virtualenv
# phar
# phar7.4
# phar7.4.phar
# phar.phar
# phar.phar7.4
# photorec
# php
# php7.4
# pic
# pico
# piconv
# pidof
# pidstat
# pinentry
# pinentry-curses
# pinentry-gnome3
# pinentry-x11
# ping
# ping4
# ping6
# pinky
# pip
# pip3
# pipal
# pixeltool
# pixiewps
# pkaction
# pkcheck
# pkexec
# pkgdata
# pkill
# pkttyagent
# pl2link
# pl2pm
# pldd
# pldes
# plget
# plio
# plmerge
# plog
# plparse
# plser
# plugin_test
# plymouth
# pmap
# pmspike
# pod2html
# pod2man
# pod2text
# pod2usage
# podchecker
# podselect
# poff
# polenum
# pon
# POST
# post_fuzz
# post_spike
# powersploit
# pr
# precat
# preconv
# prequest3
# preunzip
# prezip
# prezip-bin
# print
# printenv
# printf
# prlimit
# procan
# profile2mat.pl
# profiles
# proj
# projinfo
# projsync
# proutes3
# prove
# proxychains
# proxychains4
# proxytunnel
# prtstat
# prune
# ps
# pserve3
# psfaddtable
# psfgettable
# psfstriptable
# psfxtable
# pshell3
# psk-crack
# pslog
# psql
# pstat
# pstree
# pstree.x11
# pt2to3
# ptar
# ptardiff
# ptargrep
# ptdump
# pth-curl
# pth-net
# pth-rpcclient
# pth-smbclient
# pth-smbget
# pth-sqsh
# pth-winexe
# pth-wmic
# pth-wmis
# ptrepack
# pttree
# ptweens3
# ptx
# pulseaudio
# pviews3
# pwd
# pwdx
# pwgen
# pw-inspector
# pwnat
# py3clean
# py3compile
# py3versions
# pybabel
# pybabel-python3
# pydoc2
# pydoc2.7
# pydoc3
# pydoc3.8
# pydoc3.9
# pyfiglet
# pygettext2
# pygettext2.7
# pygettext3
# pygettext3.8
# pygettext3.9
# pygmentize
# pyhtmlizer3
# pylupdate5
# pyppeteer-install
# pyproj
# pypykatz
# pyrcc5
# pyserial-miniterm
# pyserial-ports
# py.test-3
# pytest-3
# python
# python2
# python2.7
# python3
# python3.8
# python3.8-config
# python3.9
# python3.9-config
# python3-config
# python3-futurize
# python3-pasteurize
# python3-qr
# python3-tor-prompt
# python3-wsdump
# python-faraday
# pyuic5
# pyversions
# pywerview
# qcollectiongenerator
# qdbus
# qdbuscpp2xml
# qdbusviewer
# qdbusxml2cpp
# qdoc
# qdoc3
# qgltf
# qhelpconverter
# qhelpgenerator
# qlalr
# qmake
# qml
# qml1plugindump
# qmlbundle
# qmlcachegen
# qmleasing
# qmlimportscanner
# qmljs
# qmllint
# qmlmin
# qmlplugindump
# qmlprofiler
# qmlscene
# qmltestrunner
# qmlviewer
# qr
# qsslcaudit
# qt5ct
# qtattributionsscanner
# qtchooser
# qtconfig
# qtdiag
# qterminal
# qtpaths
# qtplugininfo
# quake
# quakeserver
# quickbook
# qvkgen
# r2
# r2agent
# r2pm
# rabin2
# racc2.7
# racc2y2.7
# radare2
# radiff2
# rafind2
# ragg2
# rahash2
# rake
# randpkt
# ranlib
# rarun2
# rasm2
# rawshark
# rax2
# rb
# rbash
# rcc
# rcp
# rctest
# rdesktop
# rdf2bin
# rdf2com
# rdf2ihx
# rdf2ith
# rdf2srec
# rdfdump
# rdflib
# rdjpgcom
# rdma
# rdoc
# rdoc2.7
# rdx
# readelf
# readlink
# realpath
# rearj
# reaver
# recon-cli
# recon-ng
# recon-web
# recordmydesktop
# reindexdb
# rendercheck
# renice
# reordercap
# repc
# replace
# replay.pl
# reset
# resizecons
# resizepart
# resolvectl
# resolveip
# resolve_stack_dump
# responder-BrowserListener
# responder-DHCP
# responder-FindSMB2UPTime
# responder-FindSQLSrv
# responder-Icmp-Redirect
# responder-MultiRelay
# responder-RunFinger
# rev
# rfcomm
# rgrep
# ri
# ri2.7
# ristretto
# rlogin
# rlogin-cwd
# rm
# rmdir
# rmid
# rmiregistry
# rnano
# ropper
# rotatelogs
# routef
# routel
# rpcclient
# rpcgen
# rpcinfo
# rq
# rqinfo
# rqworker
# rrsync
# rsh
# rsmangler
# rstart
# rstartd
# rsync
# rsync-ssl
# rtstat
# ruby
# ruby2.7
# runcon
# run-mailcap
# run-parts
# runscript
# run-with-aspell
# runxlrd
# ruptime
# rview
# rvim
# rwho
# rx
# rz
# rzsh
# sadf
# sakis3g
# samba-regedit
# samba-tool
# samdump2
# sane-find-scanner
# sanstats-9
# sar
# sar.sysstat
# savelog
# sb
# sbd
# scalpel
# scanimage
# scapy
# scapy3
# sccmap
# scp
# screen
# screendump
# script
# scriptlive
# scriptreplay
# sdiff
# sdptool
# searchsploit
# sed
# see
# select-default-iwrap
# select-editor
# sendemail
# sendEmail
# sendmsrpc
# sensible-browser
# sensible-editor
# sensible-pager
# seq
# sessreg
# setarch
# setcifsacl
# setfacl
# setfattr
# setfont
# setkeycodes
# setleds
# setlogcons
# setmetamode
# se-toolkit
# setoolkit
# setpci
# setpriv
# setsid
# setterm
# setupcon
# setvtrgb
# setxkbmap
# sfdp
# sfparse
# sftp
# sg
# sh
# sha1deep
# sha1sum
# sha224sum
# sha256deep
# sha256sum
# sha384sum
# sha512sum
# sharesec
# sharkd
# shasum
# shmemc++
# shmemcc
# shmemCC
# shmemcxx
# shmemfort
# shmemrun
# shodan
# showconsolefont
# showfigfonts
# showkey
# showrgb
# shred
# shuf
# sigfind
# size
# skill
# skipfish
# slabtop
# sleep
# slogin
# smb2-quota
# smbcacls
# smbclient
# smbcontrol
# smbcquotas
# smbget
# smbinfo
# smbmap
# smbpasswd
# smbspool
# smbstatus
# smbtar
# smbtree
# smproxy
# snice
# snmp-bridge-mib
# snmpbulkget
# snmpbulkwalk
# snmp-check
# snmpcheck
# snmpconf
# snmpdelta
# snmpdf
# snmpget
# snmpgetnext
# snmpinform
# snmpkey
# snmpnetstat
# snmpping
# snmpset
# snmpstatus
# snmptable
# snmptest
# snmptls
# snmptranslate
# snmptrap
# snmpusm
# snmpvacm
# snmpwalk
# socat
# soelim
# sort
# sorter
# sotruss
# sp32
# sp64
# spiderfoot
# spiderfoot-cli
# splain
# split
# splitfont
# spooftooph
# sprof
# sqldiff
# sqlite3
# sqlitebrowser
# sqlmap
# sqlmapapi
# sqsh
# srch_strings
# ss
# ssh
# ssh-add
# ssh-agent
# ssh-argv0
# ssh-copy-id
# ssh-keygen
# ssh-keyscan
# sslscan
# sslsplit
# sslyze
# ss_spike
# start-pulseaudio-x11
# startx
# startxfce4
# stat
# statd_spike
# stdbuf
# stl2gts
# strings
# strip
# stty
# stunnel
# stunnel3
# stunnel4
# su
# sudo
# sudoedit
# sudoreplay
# sum
# sunrpcfuzz
# svn
# svnadmin
# svnauthz
# svnauthz-validate
# svnbench
# svndumpfilter
# svnfsfs
# svnlook
# svnmucc
# svnrdump
# svnserve
# svnsync
# svnversion
# swaks
# swfparser
# sx
# symcryptrun
# sync
# systemctl
# systemd
# systemd-analyze
# systemd-ask-password
# systemd-cat
# systemd-cgls
# systemd-cgtop
# systemd-delta
# systemd-detect-virt
# systemd-escape
# systemd-hwdb
# systemd-id128
# systemd-inhibit
# systemd-machine-id-setup
# systemd-mount
# systemd-notify
# systemd-path
# systemd-resolve
# systemd-run
# systemd-socket-activate
# systemd-stdio-bridge
# systemd-sysusers
# systemd-tmpfiles
# systemd-tty-ask-password-agent
# systemd-umount
# sz
# tabs
# tabulate
# tac
# tail
# tapestat
# tar
# tasksel
# taskset
# tbl
# tclsh8.6
# tcpbridge
# tcpcapinfo
# tcpliveplay
# tcpprep
# tcpreplay
# tcpreplay-edit
# tcprewrite
# tdbbackup
# tdbbackup.tdbtools
# tdbdump
# tdbrestore
# tdbtool
# tee
# tempfile
# teredo-mire
# test
# testdisk
# testparm
# text2pcap
# tftp
# thc-pptp-bruter
# theharvester
# theHarvester
# thor
# thunar
# Thunar
# thunar-settings
# thunar-volman
# thunar-volman-settings
# tic
# tigerdeep
# tightvncconnect
# tightvncpasswd
# tightvncserver
# timedatectl
# timed-read
# timed-run
# timeout
# tjbench
# tkconch3
# tknewsbiff
# tkpasswd
# tload
# tmux
# toe
# top
# tor-prompt
# touch
# tpmc
# tpm-nvsize
# tput
# tqdm
# tr
# transform
# transset
# tred
# trial3
# troff
# true
# truncate
# trust
# tset
# tshark
# tsk_comparedir
# tsk_gettimes
# tsk_loaddb
# tsk_recover
# tsort
# tty
# twist3
# twistd3
# twopi
# tzselect
# ucf
# ucfq
# ucfr
# uconv
# ucs2any
# udevadm
# udisksctl
# udptunnel
# uic
# uic3
# ul
# umax_pp
# umount
# uname
# unar
# unbuffer
# uncompress
# uncompress.real
# unexpand
# unflatten
# unicode_start
# unicode_stop
# uniq
# unix2dos
# unix2mac
# unix-privesc-check
# unlink
# unlzma
# unmkinitramfs
# unpack200
# unshare
# unsquashfs
# unxz
# unzip
# unzipsfx
# update-alternatives
# updatedb
# updatedb.mlocate
# update-desktop-database
# update-leap
# update-mime-database
# upower
# uptime
# upx
# upx-ucl
# usb-devices
# usbhid-dump
# usbreset
# users
# usnjls
# utmpdump
# vacuumdb
# vacuumlo
# vbutil_firmware
# vbutil_kernel
# vbutil_key
# vbutil_keyblock
# vdir
# verify-uselistorder-9
# VGAuthService
# vi
# view
# viewres
# vim
# vim.basic
# vimdiff
# vimdot
# vim.tiny
# vimtutor
# vmhgfs-fuse
# vmstat
# vm-support
# vmtoolsd
# vmware-checkvm
# vmwarectrl
# vmware-hgfsclient
# vmware-namespace-cmd
# vmware-rpctool
# vmware-toolbox-cmd
# vmware-user
# vmware-user-suid-wrapper
# vmware-vgauth-cmd
# vmware-vgauth-smoketest
# vmware-vmblock-fuse
# vmware-xferlogs
# vncconnect
# vncpasswd
# vncserver
# vncviewer
# voiphopper
# w
# wafw00f
# wall
# wapiti
# wapiti-getcookie
# wash
# watch
# watchgnupg
# wc
# wce
# wdctl
# webfuzz
# webshells
# weevely
# wfuzz
# wget
# whatis
# whatweb
# whereis
# which
# whiptail
# whirlpooldeep
# who
# whoami
# whois
# windows-binaries
# windows-resources
# winexe
# wireshark
# word-list-compress
# wordlists
# wpaclean
# wpa_passphrase
# w.procps
# wpscan
# write
# write.ul
# wrjpgcom
# wsdump
# wsrep_sst_common
# wsrep_sst_mariabackup
# wsrep_sst_mysqldump
# wsrep_sst_rsync
# wsrep_sst_rsync_wan
# X
# X11
# x11perf
# x11perfcomp
# x11_spike
# x86_64
# x86_64-linux-gnu-addr2line
# x86_64-linux-gnu-ar
# x86_64-linux-gnu-as
# x86_64-linux-gnu-c++filt
# x86_64-linux-gnu-cpp
# x86_64-linux-gnu-cpp-10
# x86_64-linux-gnu-cpp-9
# x86_64-linux-gnu-dwp
# x86_64-linux-gnu-elfedit
# x86_64-linux-gnu-g++
# x86_64-linux-gnu-g++-10
# x86_64-linux-gnu-gcc
# x86_64-linux-gnu-gcc-10
# x86_64-linux-gnu-gcc-9
# x86_64-linux-gnu-gcc-ar
# x86_64-linux-gnu-gcc-ar-10
# x86_64-linux-gnu-gcc-ar-9
# x86_64-linux-gnu-gcc-nm
# x86_64-linux-gnu-gcc-nm-10
# x86_64-linux-gnu-gcc-nm-9
# x86_64-linux-gnu-gcc-ranlib
# x86_64-linux-gnu-gcc-ranlib-10
# x86_64-linux-gnu-gcc-ranlib-9
# x86_64-linux-gnu-gcov
# x86_64-linux-gnu-gcov-10
# x86_64-linux-gnu-gcov-9
# x86_64-linux-gnu-gcov-dump
# x86_64-linux-gnu-gcov-dump-10
# x86_64-linux-gnu-gcov-dump-9
# x86_64-linux-gnu-gcov-tool
# x86_64-linux-gnu-gcov-tool-10
# x86_64-linux-gnu-gcov-tool-9
# x86_64-linux-gnu-gfortran
# x86_64-linux-gnu-gfortran-10
# x86_64-linux-gnu-gfortran-9
# x86_64-linux-gnu-gold
# x86_64-linux-gnu-gprof
# x86_64-linux-gnu-ld
# x86_64-linux-gnu-ld.bfd
# x86_64-linux-gnu-ld.gold
# x86_64-linux-gnu-lto-dump-10
# x86_64-linux-gnu-nm
# x86_64-linux-gnu-objcopy
# x86_64-linux-gnu-objdump
# x86_64-linux-gnu-python3.8-config
# x86_64-linux-gnu-python3.9-config
# x86_64-linux-gnu-python3-config
# x86_64-linux-gnu-ranlib
# x86_64-linux-gnu-readelf
# x86_64-linux-gnu-size
# x86_64-linux-gnu-strings
# x86_64-linux-gnu-strip
# xargs
# xauth
# xbiff
# xcalc
# xcape
# xclipboard
# xclock
# xcmsdb
# xconsole
# xcursorgen
# xcutsel
# xdg-dbus-proxy
# xdg-desktop-icon
# xdg-desktop-menu
# xdg-email
# xdg-icon-resource
# xdg-mime
# xdg-open
# xdg-screensaver
# xdg-settings
# xdg-user-dir
# xdg-user-dirs-gtk-update
# xdg-user-dirs-update
# xditview
# xdotool
# xdpyinfo
# xdriinfo
# xedit
# xev
# xeyes
# xfce4-about
# xfce4-accessibility-settings
# xfce4-appearance-settings
# xfce4-appfinder
# xfce4-clipman
# xfce4-clipman-history
# xfce4-clipman-settings
# xfce4-color-settings
# xfce4-display-settings
# xfce4-find-cursor
# xfce4-keyboard-settings
# xfce4-mime-settings
# xfce4-mouse-settings
# xfce4-notifyd-config
# xfce4-panel
# xfce4-popup-applicationsmenu
# xfce4-popup-clipman
# xfce4-popup-clipman-actions
# xfce4-popup-directorymenu
# xfce4-popup-places
# xfce4-popup-whiskermenu
# xfce4-popup-windowmenu
# xfce4-power-manager
# xfce4-power-manager-settings
# xfce4-screenshooter
# xfce4-sensors
# xfce4-session
# xfce4-session-logout
# xfce4-session-settings
# xfce4-settings-editor
# xfce4-settings-manager
# xfce4-taskmanager
# xfconf-query
# xfd
# xfdesktop
# xfdesktop-settings
# xfhelp4
# xflock4
# xfontsel
# xfreerdp
# xfrun4
# xfsettingsd
# xfwm4
# xfwm4-settings
# xfwm4-tweaks-settings
# xfwm4-workspace-settings
# xgamma
# xgc
# xhost
# xhydra
# xiccd
# xinit
# xkbbell
# xkbcomp
# xkbevd
# xkbprint
# xkbvleds
# xkbwatch
# xkeystone
# xkibitz
# xkill
# xload
# xlogo
# xlsatoms
# xlsclients
# xlsfonts
# xmag
# xman
# xmessage
# xminicom
# xmlcatalog
# xmllint
# xmlparse
# xmlpatterns
# xmlpatternsvalidator
# xmodmap
# xmore
# Xorg
# xprop
# xpstat
# xrandr
# xrdb
# xrefresh
# x-session-manager
# xset
# xsetmode
# xsetpointer
# xsetroot
# xsltproc
# xsm
# xstdcmap
# xsubpp
# x-terminal-emulator
# Xtightvnc
# xtightvncviewer
# Xvfb
# xvfb-run
# xvidtune
# xvinfo
# Xvnc
# xvncviewer
# xwd
# x-window-manager
# xwininfo
# xwud
# x-www-browser
# xxd
# xz
# xzcat
# xzcmp
# xzdiff
# xzegrep
# xzfgrep
# xzgrep
# xzless
# xzmore
# y2racc2.7
# yaml2obj-9
# yaml-bench-9
# yes
# ypdomainname
# zaproxy
# zcat
# zcmp
# zdiff
# zdump
# zegrep
# zenity
# zfgrep
# zforce
# zgrep
# zip
# zipcloak
# zipdetails
# zipgrep
# zipinfo
# zipnote
# zipsplit
# zless
# zmore
# znew
# zsh
# zsh5

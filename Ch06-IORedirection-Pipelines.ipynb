# %% [markdown]
# # I/O Redirection and Pipelines
#
# ## Standard Output Redirection
# - \> : redirect commands output to files
#     - create an output file if not exists
# - \>> : append to a file

# %%
! ls
# Out:
# Ch01-LearningShell.ipynb
# Ch02-NavigationExploration.ipynb
# Ch03-ManipulatingFilesAndDirectories.ipynb
# Ch04-FilesAndPermissions.ipynb
# Ch05-UserManagementEnvVariables.ipynb
# IORedirection-Pipelines.ipynb
# README.md
# resources

# %%
# redirect ls commands ouptut to ls.txt
! ls > ls.txt

# %%
# see the new file created
ls -l ls.txt
# Out:
# -rw-r--r-- 1 root root 227 Jan 26 20:26 ls.txt

# %%
# type the contents of the new file
! cat ls.txt
# Out:
# Ch01-LearningShell.ipynb
# Ch02-NavigationExploration.ipynb
# Ch03-ManipulatingFilesAndDirectories.ipynb
# Ch04-FilesAndPermissions.ipynb
# Ch05-UserManagementEnvVariables.ipynb
# IORedirection-Pipelines.ipynb
# ls.txt
# README.md
# resources

# %%
# append the results to ls.txt
! ls -al >> ls.txt

# %%
! cat ls.txt
# Out:
# Ch01-LearningShell.ipynb
# Ch02-NavigationExploration.ipynb
# Ch03-ManipulatingFilesAndDirectories.ipynb
# Ch04-FilesAndPermissions.ipynb
# Ch05-UserManagementEnvVariables.ipynb
# IORedirection-Pipelines.ipynb
# ls.txt
# README.md
# resources
# total 192
# drwxr-xr-x 5 root root  4096 Jan 26 20:28 .
# drwxr-xr-x 3 root root  4096 Jan 25 18:32 ..
# -rw-r--r-- 1 root root  4660 Jan 25 23:29 Ch01-LearningShell.ipynb
# -rw-r--r-- 1 root root 90097 Jan 25 20:17 Ch02-NavigationExploration.ipynb
# -rw-r--r-- 1 root root 20095 Jan 25 23:44 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 root root 17481 Jan 25 22:57 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 root root 19599 Jan 25 23:50 Ch05-UserManagementEnvVariables.ipynb
# drwxr-xr-x 8 root root  4096 Jan 26 00:15 .git
# -rw-r--r-- 1 root root    20 Jan 25 23:39 .gitignore
# -rw-r--r-- 1 root root  2394 Jan 26 20:28 IORedirection-Pipelines.ipynb
# drwxr-xr-x 2 root root  4096 Jan 26 20:25 .ipynb_checkpoints
# -rw-r--r-- 1 root root   227 Jan 26 20:26 ls.txt
# -rw-r--r-- 1 root root   544 Jan 26 00:14 README.md
# drwxr-xr-x 2 root root  4096 Jan 25 21:44 resources

# %% [markdown]
# ## Standard Input
# - \< : read from a text file

# %%
! sort < ls.txt
# Out:
# Ch01-LearningShell.ipynb
# Ch02-NavigationExploration.ipynb
# Ch03-ManipulatingFilesAndDirectories.ipynb
# Ch04-FilesAndPermissions.ipynb
# Ch05-UserManagementEnvVariables.ipynb
# drwxr-xr-x 2 root root  4096 Jan 25 21:44 resources
# drwxr-xr-x 2 root root  4096 Jan 26 20:25 .ipynb_checkpoints
# drwxr-xr-x 3 root root  4096 Jan 25 18:32 ..
# drwxr-xr-x 5 root root  4096 Jan 26 20:28 .
# drwxr-xr-x 8 root root  4096 Jan 26 00:15 .git
# IORedirection-Pipelines.ipynb
# ls.txt
# README.md
# resources
# -rw-r--r-- 1 root root 17481 Jan 25 22:57 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 root root 19599 Jan 25 23:50 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 root root 20095 Jan 25 23:44 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 root root    20 Jan 25 23:39 .gitignore
# -rw-r--r-- 1 root root   227 Jan 26 20:26 ls.txt
# -rw-r--r-- 1 root root  2394 Jan 26 20:28 IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 root root  4660 Jan 25 23:29 Ch01-LearningShell.ipynb
# -rw-r--r-- 1 root root   544 Jan 26 00:14 README.md
# -rw-r--r-- 1 root root 90097 Jan 25 20:17 Ch02-NavigationExploration.ipynb
# total 192

# %%
! sort < ls.txt > sortedls.txt

# %%
! cat sortedls.txt
# Out:
# [
# 2to3-2.7
# 7z
# 7za
# 7zr
# aa-enabled
# aa-exec
# ab
# acyclic
# add-apt-repository
# addpart
# addr2line
# aircrack-ng
# airdecap-ng
# airdecloak-ng
# airolib-ng
# alembic
# apg
# apgbfm
# appres
# appstreamcli
# apropos
# apt
# apt-add-repository
# apt-cache
# apt-cdrom
# apt-config
# apt-extracttemplates
# apt-ftparchive
# apt-get
# apt-key
# apt-listchanges
# apt-mark
# apt-sortpkgs
# ar
# arch
# aria_chk
# aria_dump_log
# aria_ftdump
# aria_pack
# aria_read_log
# arj
# arjdisp
# arj-register
# as
# as10k1
# asan_symbolize
# asan_symbolize-6.0
# asan_symbolize-7
# ascii-xfr
# aspell
# aspell-import
# assistant
# atk6-address6
# atk6-alive6
# atk6-connect6
# atk6-connsplit6
# atk6-covert_send6
# atk6-covert_send6d
# atk6-denial6
# atk6-detect-new-ip6
# atk6-detect_sniffer6
# atk6-dnsdict6
# atk6-dnsrevenum6
# atk6-dnssecwalk
# atk6-dos-new-ip6
# atk6-dump_dhcp6
# atk6-dump_router6
# atk6-exploit6
# atk6-extract_hosts6
# atk6-extract_networks6
# atk6-fake_advertise6
# atk6-fake_dhcps6
# atk6-fake_dns6d
# atk6-fake_dnsupdate6
# atk6-fake_mipv6
# atk6-fake_mld26
# atk6-fake_mld6
# atk6-fake_mldrouter6
# atk6-fake_pim6
# atk6-fake_router26
# atk6-fake_router6
# atk6-fake_solicitate6
# atk6-firewall6
# atk6-flood_advertise6
# atk6-flood_dhcpc6
# atk6-flood_mld26
# atk6-flood_mld6
# atk6-flood_mldrouter6
# atk6-flood_redir6
# atk6-flood_router26
# atk6-flood_router6
# atk6-flood_rs6
# atk6-flood_solicitate6
# atk6-flood_unreach6
# atk6-four2six
# atk6-fragmentation6
# atk6-fragrouter6
# atk6-fuzz_dhcpc6
# atk6-fuzz_dhcps6
# atk6-fuzz_ip6
# atk6-implementation6
# atk6-implementation6d
# atk6-inject_alive6
# atk6-inverse_lookup6
# atk6-kill_router6
# atk6-ndpexhaust26
# atk6-ndpexhaust6
# atk6-node_query6
# atk6-parasite6
# atk6-passive_discovery6
# atk6-randicmp6
# atk6-redir6
# atk6-redirsniff6
# atk6-rsmurf6
# atk6-sendpees6
# atk6-sendpeesmp6
# atk6-smurf6
# atk6-thcping6
# atk6-thcsyn6
# atk6-toobig6
# atk6-toobigsniff6
# atk6-trace6
# atobm
# attr
# autoexpect
# automat-visualize
# autopasswd
# autopsy
# awk
# axel
# b2sum
# b43-fwcutter
# baobab
# base32
# base64
# basename
# bash
# bashbug
# bccmd
# bcomps
# bdb_extend
# bdftopcf
# bdftruncate
# besside-ng-crawler
# binwalk
# bitmap
# blkcalc
# blkcat
# blkls
# blkstat
# bluemoon
# bluetoothctl
# bluetooth-sendto
# bmpblk_font
# bmpblk_utility
# bmtoa
# boltctl
# bootctl
# broadwayd
# bsd-from
# bsd-write
# btattach
# btmgmt
# btmon
# buddy-ng
# bugpoint-6.0
# bugpoint-7
# bulk_extractor
# bully
# bundle
# bundler
# bunzip2
# burpsuite
# busctl
# busybox
# bwrap
# bzcat
# bzcmp
# bzdiff
# bzegrep
# bzexe
# bzfgrep
# bzgrep
# bzip2
# bzip2recover
# bzless
# bzmore
# c++
# c89
# c89-gcc
# c99
# c99-gcc
# cachedump
# cadaver
# cal
# calc_tickadj
# calendar
# cancel
# capinfos
# captoinfo
# captype
# cardos-tool
# caribou-preferences
# cat
# catchsegv
# catman
# cc
# ccomps
# cd-create-profile
# cd-fix-profile
# cd-iccdump
# cd-it8
# cewl
# c++filt
# cgpt
# chacl
# chage
# chardet
# chardet3
# chardetect
# chardetect3
# chattr
# chcon
# checkgid
# cherrytree
# chfn
# chgrp
# chmod
# choom
# chown
# chromedriver
# chrome-gnome-shell
# chromeos-tpm-recovery
# chromium
# chrt
# chsh
# chvt
# cifscreds
# cifsdd
# cifsiostat
# ciptool
# circo
# cisco-decrypt
# citrix
# cjpeg
# ckbcomp
# ckeygen
# cksum
# clang
# clang++
# clang++-6.0
# clang-6.0
# clang++-7
# clang-7
# clang-cpp-6.0
# clang-cpp-7
# clear
# clear_console
# clhsdb
# closed_source_web_server_fuzz
# cluster
# clusterd
# clusterdb
# cmp
# code
# codepage
# col
# colcrt
# colormgr
# colrm
# column
# comm
# commix
# compose
# compress
# conch
# conchftp
# corelist
# cp
# cpan
# cpan5.28-i386-linux-gnu
# cpio
# cpp
# cpp-8
# cramfsswap
# createdb
# createlang
# createuser
# c_rehash
# crontab
# crossystem
# crossystem_s
# crunch
# cryptcat
# cryptdir
# cryptoflex-tool
# csplit
# ctstat
# cupstestdsc
# cupstestppd
# curl
# curlftpfs
# cut
# cutycapt
# cvt
# cvtsudoers
# cygdb
# cython
# dash
# date
# dave
# davtest
# dbd
# dbilogstrip
# dbiprof
# dbiproxy
# dbus-cleanup-sockets
# dbus-daemon
# dbus-launch
# dbus-monitor
# dbus-run-session
# dbus-send
# dbus-update-activation-environment
# dbus-uuidgen
# dbwrap_tool
# dccleancrw
# dceoversmb
# dcfujigreen
# dcfujiturn
# dcfujiturn16
# dconf
# dcparse
# dcraw
# dd
# ddcmon
# deallocvt
# debconf
# debconf-apt-progress
# debconf-communicate
# debconf-copydb
# debconf-escape
# debconf-set-selections
# debconf-show
# debianbts
# deb-systemd-helper
# deb-systemd-invoke
# debtags
# decode-dimms
# decode-edid
# decode-vaio
# decryptdir
# delaunay
# delpart
# delv
# designer
# desktop-file-edit
# desktop-file-install
# desktop-file-validate
# dev_debug_vboot
# dev_make_keypair
# df
# dfu-tool
# dh_bash-completion
# dh_numpy
# dh_numpy3
# dh_perl_dbi
# dh_perl_openssl
# dh_pypy
# dh_python2
# dh_python3
# dh_python3-ply
# diff
# diff3
# diffimg
# dig
# dijkstra
# dir
# dirb
# dirb-gendict
# dirbuster
# dircolors
# dirmngr
# dirmngr-client
# dirname
# dislocate
# django-admin
# djpeg
# dltest
# dmesg
# dmitry
# dnie-tool
# dns2tcpc
# dns2tcpd
# dnschef
# dnsdomainname
# dnsenum
# dns-rebind
# dnsrecon
# dnstap-read
# domainname
# do_post
# dos2unix
# dot
# dot2gxl
# dot_builtins
# dotlock
# dotlockfile
# dotlock.mailutils
# dotty
# dpkg
# dpkg-architecture
# dpkg-buildflags
# dpkg-buildpackage
# dpkg-checkbuilddeps
# dpkg-deb
# dpkg-distaddfile
# dpkg-divert
# dpkg-genbuildinfo
# dpkg-genchanges
# dpkg-gencontrol
# dpkg-gensymbols
# dpkg-maintscript-helper
# dpkg-mergechangelogs
# dpkg-name
# dpkg-parsechangelog
# dpkg-query
# dpkg-scanpackages
# dpkg-scansources
# dpkg-shlibdeps
# dpkg-source
# dpkg-split
# dpkg-statoverride
# dpkg-trigger
# dpkg-vendor
# dpl4hydra
# dropdb
# droplang
# dropuser
# dsymutil-7
# du
# dumpcap
# dump_fmap
# dump_kernel_config
# dumpkeys
# dumpRSAPublicKey
# dupemap
# dwp
# eatmydata
# echo
# edgepaint
# edit
# editcap
# editor
# editres
# eficompress
# efidecompress
# egk-tool
# egrep
# eidenv
# eject
# elfedit
# email_validator
# enable_dev_usb_boot
# enc2xs
# encguess
# enchant
# enchant-lsmod
# encode_keychange
# enum4linux
# env
# envsubst
# eog
# eqn
# erb
# erb2.5
# ettercap
# ettercap-pkexec
# etterfilter
# etterlog
# evince
# evince-previewer
# evince-thumbnailer
# ex
# exe2hex
# exifautotran
# exiv2
# expand
# expect
# expect_autoexpect
# expect_autopasswd
# expect_cryptdir
# expect_decryptdir
# expect_dislocate
# expect_ftp-rfc
# expect_kibitz
# expect_lpunlock
# expect_mkpasswd
# expect_multixterm
# expect_passmass
# expect_rftp
# expect_rlogin-cwd
# expect_timed-read
# expect_timed-run
# expect_tknewsbiff
# expect_tkpasswd
# expect_unbuffer
# expect_weather
# expect_xkibitz
# expect_xpstat
# expiry
# expr
# f2py
# f2py2.7
# f2py3
# f2py3.7
# fab-cewl
# factor
# faillog
# faked-sysv
# faked-tcp
# fakeroot
# fakeroot-sysv
# fakeroot-tcp
# fallocate
# false
# faraday
# faraday-client
# faraday-manage
# faraday-server
# fastjar
# fcat
# fc-cache
# fc-cat
# fc-conflist
# fcgistarter
# fc-list
# fc-match
# fc-pattern
# fc-query
# fc-scan
# fc-validate
# fdp
# fern-wifi-cracker
# ffind
# fgconsole
# fgrep
# fidentify
# fierce
# filan
# file
# file-roller
# fincore
# find
# findmnt
# findmyhash
# findsmb
# finger
# firefox
# firefox-esr
# fiwalk
# fixproc
# flac
# flask
# flock
# florence
# fls
# fmt
# fold
# fonttosfnt
# fping
# fping6
# fplugin
# free
# frm
# frm.mailutils
# from
# from.mailutils
# fsstat
# ftp
# ftp-rfc
# funzip
# fuser
# fusermount
# futility
# futility_s
# futurize
# fwupdmgr
# g++
# g++-8
# galera_new_cluster
# galera_recovery
# gamma4scanimage
# gapplication
# gatttool
# gawk
# gbb_utility
# gc
# gcalccmd
# gcc
# gcc-8
# gcc-ar
# gcc-ar-8
# gcc-nm
# gcc-nm-8
# gcc-ranlib
# gcc-ranlib-8
# gcov
# gcov-8
# gcov-dump
# gcov-dump-8
# gcov-tool
# gcov-tool-8
# gcr-viewer
# gdbus
# gdialog
# gdk-pixbuf-csource
# gdk-pixbuf-pixdata
# gdk-pixbuf-thumbnailer
# gdmflexiserver
# gdm-screenshot
# gedit
# gem
# gem2.5
# gencat
# generic_chunked
# generic_listen_tcp
# generic_send_tcp
# generic_send_udp
# generic_web_server_fuzz
# generic_web_server_fuzz2
# geqn
# GET
# getcifsacl
# getconf
# get-edid
# getent
# getfacl
# getfattr
# getkeycodes
# getopt
# gettext
# gettext.sh
# ghost-phisher
# gids-tool
# gio
# gio-querymodules
# git
# git-receive-pack
# git-shell
# git-upload-archive
# git-upload-pack
# gjs
# gjs-console
# gkbd-keyboard-display
# glib-compile-schemas
# gml2gv
# gnome-calculator
# gnome-characters
# gnome-contacts
# gnome-control-center
# gnome-disk-image-mounter
# gnome-disks
# gnome-font-viewer
# gnome-help
# gnome-keyring
# gnome-keyring-3
# gnome-keyring-daemon
# gnome-logs
# gnome-session
# gnome-session-classic
# gnome-session-custom-session
# gnome-session-inhibit
# gnome-session-quit
# gnome-shell
# gnome-shell-extension-prefs
# gnome-shell-extension-tool
# gnome-shell-perf-tool
# gnome-software
# gnome-software-editor
# gnome-system-monitor
# gnome-terminal
# gnome-terminal.wrapper
# gnome-text-editor
# gnome-thumbnail-font
# gnome-tweaks
# gnome-www-browser
# gold
# gopherd
# gpasswd
# gpg
# gpg-agent
# gpgcompose
# gpgconf
# gpg-connect-agent
# gpgparsemail
# gpgsm
# gpgsplit
# gpgtar
# gpgv
# gpg-wks-server
# gpg-zip
# gpic
# gpp-decrypt
# gprof
# graphml2gv
# grep
# grepjar
# gresource
# groff
# grog
# grops
# grotty
# groups
# grub-editenv
# grub-file
# grub-fstest
# grub-glue-efi
# grub-kbdcomp
# grub-menulst2cfg
# grub-mkfont
# grub-mkimage
# grub-mklayout
# grub-mknetdir
# grub-mkpasswd-pbkdf2
# grub-mkrelpath
# grub-mkrescue
# grub-mkstandalone
# grub-mount
# grub-ntldr-img
# grub-render-label
# grub-script-check
# grub-syslinux2cfg
# gsettings
# gstreamer-codec-install
# gtbl
# gtf
# gtk-builder-tool
# gtk-launch
# gtk-query-settings
# gtk-update-icon-cache
# gts2dxf
# gts2oogl
# gts2stl
# gts2xyz
# gtscheck
# gtscompare
# gts-config
# gtstemplate
# gunzip
# guymager
# gv2gml
# gv2gxl
# gvcolor
# gvgen
# gvmap
# gvmap.sh
# gvpack
# gvpr
# gxl2dot
# gxl2gv
# gzexe
# gzip
# h2ph
# h2xs
# halflife
# hashcat
# hashdeep
# hashid
# hash-identifier
# hciattach
# hciconfig
# hcidump
# hcitool
# hd
# hdajacksensetest
# hda-verb
# head
# HEAD
# helpztags
# hex2hcd
# hexdump
# hexeditor
# hexorbase
# hfind
# host
# hostid
# hostname
# hostnamectl
# hotpatcher
# hsdb
# htcacheclean
# htdbm
# htdigest
# html2dic
# htpasswd
# hupper
# hwloc-annotate
# hwloc-assembler
# hwloc-assembler-remote
# hwloc-bind
# hwloc-calc
# hwloc-compress-dir
# hwloc-diff
# hwloc-distances
# hwloc-distrib
# hwloc-gather-topology
# hwloc-info
# hwloc-ls
# hwloc-patch
# hwloc-ps
# hydra
# hydra-wizard
# i386
# i386-linux-gnu-python2.7-config
# i386-linux-gnu-python2-config
# i386-linux-gnu-python3.7-config
# i386-linux-gnu-python3.7m-config
# i386-linux-gnu-python3-config
# i386-linux-gnu-python3m-config
# i386-linux-gnu-python-config
# i586-linux-gnu-cpp
# i586-linux-gnu-g++
# i586-linux-gnu-gcc
# i586-linux-gnu-gcc-ar
# i586-linux-gnu-gcc-nm
# i586-linux-gnu-gcc-ranlib
# i586-linux-gnu-gcov
# i586-linux-gnu-gcov-dump
# i586-linux-gnu-gcov-tool
# i686-linux-gnu-addr2line
# i686-linux-gnu-ar
# i686-linux-gnu-as
# i686-linux-gnu-c++filt
# i686-linux-gnu-cpp
# i686-linux-gnu-cpp-8
# i686-linux-gnu-dwp
# i686-linux-gnu-elfedit
# i686-linux-gnu-g++
# i686-linux-gnu-g++-8
# i686-linux-gnu-gcc
# i686-linux-gnu-gcc-8
# i686-linux-gnu-gcc-ar
# i686-linux-gnu-gcc-ar-8
# i686-linux-gnu-gcc-nm
# i686-linux-gnu-gcc-nm-8
# i686-linux-gnu-gcc-ranlib
# i686-linux-gnu-gcc-ranlib-8
# i686-linux-gnu-gcov
# i686-linux-gnu-gcov-8
# i686-linux-gnu-gcov-dump
# i686-linux-gnu-gcov-dump-8
# i686-linux-gnu-gcov-tool
# i686-linux-gnu-gcov-tool-8
# i686-linux-gnu-gold
# i686-linux-gnu-gprof
# i686-linux-gnu-ld
# i686-linux-gnu-ld.bfd
# i686-linux-gnu-ld.gold
# i686-linux-gnu-nm
# i686-linux-gnu-objcopy
# i686-linux-gnu-objdump
# i686-linux-gnu-python2.7-config
# i686-linux-gnu-python2-config
# i686-linux-gnu-python3.7-config
# i686-linux-gnu-python3.7m-config
# i686-linux-gnu-python3-config
# i686-linux-gnu-python3m-config
# i686-linux-gnu-python-config
# i686-linux-gnu-ranlib
# i686-linux-gnu-readelf
# i686-linux-gnu-size
# i686-linux-gnu-strings
# i686-linux-gnu-strip
# iasecc-tool
# icalendar
# icat
# iceauth
# ico
# iconv
# id
# ifind
# ike-scan
# ils
# img_cat
# img_stat
# impacket-GetUserSPNs
# impacket-netview
# impacket-ntlmrelayx
# impacket-rpcdump
# impacket-samrdump
# impacket-secretsdump
# impacket-smbserver
# impacket-wmiexec
# inetsim
# infocmp
# infotocap
# innochecksum
# innotop
# install
# install-printerdriver
# instmodsh
# intel-virtual-output
# ionice
# iostat
# ip
# ipcmk
# ipcrm
# ipcs
# iptables-xml
# irb
# irb2.5
# ischroot
# isdv4-serial-debugger
# isdv4-serial-inputattach
# ispell-wrapper
# istat
# ivstools
# jar
# jardetector
# jarwrapper
# java
# jcat
# jexec
# jjs
# jls
# join
# journalctl
# jpegexiforient
# jpeg_extract
# jpegtran
# json_pp
# jsonschema
# kali-setup
# kali-treecd
# kali-winexec
# kbdinfo
# kbd_mode
# kbxutil
# kernel-install
# keyctl
# keyring
# keytool
# kibitz
# kill
# killall
# kismet
# kismet_cap_freaklabs_zigbee
# kismet_cap_kismetdb
# kismet_cap_linux_bluetooth
# kismet_cap_linux_wifi
# kismet_cap_nrf_mousejack
# kismet_cap_pcapfile
# kismet_cap_sdr_rtl433
# kismet_cap_sdr_rtl433_mqtt
# kismet_cap_sdr_rtladsb
# kismet_cap_sdr_rtladsb_mqtt
# kismet_cap_sdr_rtlamr
# kismet_cap_sdr_rtlamr_mqtt
# kismetdb_dump_devices
# kismetdb_statistics
# kismetdb_strip_packets
# kismetdb_to_kml
# kismetdb_to_wiglecsv
# kismet_server
# kmod
# koi8rxterm
# kstats
# l2ping
# l2test
# last
# lastb
# lastlog
# lbd
# lcf
# lconvert
# ld
# ldapadd
# ldapcompare
# ldapdelete
# ldapexop
# ldapmodify
# ldapmodrdn
# ldappasswd
# ldapsearch
# ldapurl
# ldapwhoami
# ld.bfd
# ldd
# ld.gold
# ldrdf
# leafpad
# lefty
# less
# lessecho
# lessfile
# lesskey
# lesspipe
# lexgrog
# lft
# lft.db
# libnetcfg
# libwacom-list-local-devices
# line_send_tcp
# linguist
# link
# linux32
# linux64
# linux-boot-prober
# linux-check-removal
# linux-update-symlinks
# linux-version
# listres
# llc-6.0
# llc-7
# lli-6.0
# lli-7
# lli-child-target-6.0
# lli-child-target-7
# llvm-ar-6.0
# llvm-ar-7
# llvm-as-6.0
# llvm-as-7
# llvm-bcanalyzer-6.0
# llvm-bcanalyzer-7
# llvm-cat-6.0
# llvm-cat-7
# llvm-cfi-verify-6.0
# llvm-cfi-verify-7
# llvm-config-6.0
# llvm-config-7
# llvm-cov-6.0
# llvm-cov-7
# llvm-c-test-6.0
# llvm-c-test-7
# llvm-cvtres-6.0
# llvm-cvtres-7
# llvm-cxxdump-6.0
# llvm-cxxdump-7
# llvm-cxxfilt-6.0
# llvm-cxxfilt-7
# llvm-diff-6.0
# llvm-diff-7
# llvm-dis-6.0
# llvm-dis-7
# llvm-dlltool-6.0
# llvm-dlltool-7
# llvm-dsymutil-6.0
# llvm-dwarfdump-6.0
# llvm-dwarfdump-7
# llvm-dwp-6.0
# llvm-dwp-7
# llvm-exegesis-7
# llvm-extract-6.0
# llvm-extract-7
# llvm-lib-6.0
# llvm-lib-7
# llvm-link-6.0
# llvm-link-7
# llvm-lto2-6.0
# llvm-lto2-7
# llvm-lto-6.0
# llvm-lto-7
# llvm-mc-6.0
# llvm-mc-7
# llvm-mca-7
# llvm-mcmarkup-6.0
# llvm-modextract-6.0
# llvm-modextract-7
# llvm-mt-6.0
# llvm-mt-7
# llvm-nm-6.0
# llvm-nm-7
# llvm-objcopy-6.0
# llvm-objcopy-7
# llvm-objdump-6.0
# llvm-objdump-7
# llvm-opt-report-6.0
# llvm-opt-report-7
# llvm-pdbutil-6.0
# llvm-pdbutil-7
# llvm-PerfectShuffle-6.0
# llvm-PerfectShuffle-7
# llvm-profdata-6.0
# llvm-profdata-7
# llvm-ranlib-6.0
# llvm-ranlib-7
# llvm-rc-6.0
# llvm-rc-7
# llvm-readelf-6.0
# llvm-readelf-7
# llvm-readobj-6.0
# llvm-readobj-7
# llvm-rtdyld-6.0
# llvm-rtdyld-7
# llvm-size-6.0
# llvm-size-7
# llvm-split-6.0
# llvm-split-7
# llvm-stress-6.0
# llvm-stress-7
# llvm-strings-6.0
# llvm-strings-7
# llvm-strip-7
# llvm-symbolizer-6.0
# llvm-symbolizer-7
# llvm-tblgen-6.0
# llvm-tblgen-7
# llvm-undname-7
# llvm-xray-6.0
# llvm-xray-7
# ln
# lneato
# lnstat
# load_kernel_test
# loadkeys
# loadunimap
# locale
# localectl
# localedef
# locate
# logger
# login
# loginctl
# logname
# logresolve
# look
# lorder
# lowntfs-3g
# lp
# lpoptions
# lpq
# lpr
# lprm
# lpstat
# lpunlock
# lrelease
# ls
# lsadump
# lsattr
# lsblk
# lsb_release
# lscpu
# lsinitramfs
# lsipc
# lslocks
# lslogins
# lsmem
# lsmod
# lsns
# lsof
# lspci
# lspgpot
# lstopo
# lstopo-no-graphics
# lsusb
# luit
# lupdate
# lwp-download
# lwp-dump
# lwp-mirror
# lwp-request
# lxterm
# lzcat
# lzcmp
# lzdiff
# lzegrep
# lzfgrep
# lzgrep
# lzless
# lzma
# lzmainfo
# lzmore
# mac2unix
# macchanger
# mactime
# magicrescue
# magicsort
# mail
# mailmail
# mail.mailutils
# mailq
# mailx
# make
# make-cadir
# make-first-existing-target
# makeivs-ng
# mako-render
# maltego
# man
# mandb
# manpath
# mapscrn
# mariadb
# mariadbcheck
# mariadb-service-convert
# masscan
# mawk
# mcookie
# md5deep
# md5sum
# md5sum.textutils
# mdig
# mergecap
# mesg
# messages
# messages.mailutils
# metaflac
# mibdump
# migrate-pubring-from-classic-gpg
# mimeopen
# mimetype
# mimeview
# mimikatz
# minicom
# miniterm
# miranda
# mitmdump
# mitmproxy
# mitmweb
# mkdir
# mkfifo
# mkfontdir
# mkfontscale
# mk_modmap
# mknod
# mkpasswd
# mksquashfs
# mktemp
# mlocate
# mm2gv
# mmcat
# mmcli
# mmdbresolve
# mmls
# mmstat
# moc
# monitor-sensor
# more
# mount
# mountpoint
# mousetweaks
# movemail
# movemail.mailutils
# mp32
# mp3-decoder
# mp64
# mpg123
# mpg123-alsa
# mpg123.bin
# mpg123-id3dump
# mpg123-jack
# mpg123-nas
# mpg123-openal
# mpg123-oss
# mpg123-portaudio
# mpg123-pulse
# mpg123-strip
# mpris-proxy
# mpstat
# msfconsole
# msfd
# msfdb
# msf-egghunter
# msf-exe2vba
# msf-exe2vbs
# msf-find_badchars
# msf-halflm_second
# msf-hmac_sha1_crack
# msf-java_deserializer
# msf-jsobfu
# msf-makeiplist
# msf-md5_lookup
# msf-metasm_shell
# msf-msf_irb_shell
# msf-nasm_shell
# msf-pattern_create
# msf-pattern_offset
# msfpc
# msf-pdf2xdp
# msfrpc
# msfrpcd
# msfupdate
# msfvenom
# msf-virustotal
# msql2mysql
# msrpcfuzz
# msrpcfuzz_udp
# mt
# mt-gnu
# mtrace
# multimac
# multixterm
# mutter
# mv
# mvxattr
# myisamchk
# myisam_ftdump
# myisamlog
# myisampack
# my_print_defaults
# mysql
# mysqlaccess
# mysqladmin
# mysqlanalyze
# mysqlbinlog
# mysqlcheck
# mysql_convert_table_format
# mysqld_multi
# mysqld_safe
# mysqld_safe_helper
# mysqldump
# mysqldumpslow
# mysql_embedded
# mysql_find_rows
# mysql_fix_extensions
# mysqlhotcopy
# mysqlimport
# mysql_install_db
# mysqloptimize
# mysql_plugin
# mysqlrepair
# mysqlreport
# mysql_secure_installation
# mysql_setpermission
# mysqlshow
# mysqlslap
# mysql_tzinfo_to_sql
# mysql_upgrade
# mysql_waitpid
# mytop
# namei
# nano
# nasm
# nautilus
# nautilus-autorun-software
# nawk
# nbtscan
# nc
# ncal
# ncrack
# nc.traditional
# ncurses5-config
# ncurses6-config
# ncursesw5-config
# ncursesw6-config
# ndiff
# ndisasm
# neato
# neqn
# net
# netaddr
# netcat
# netkey-tool
# netkit-ftp
# netmask
# netsed
# net-server
# netstat
# networkctl
# newaliases
# newgrp
# nfspy
# nfspysh
# ngettext
# ngrep
# nice
# nikto
# nisdomainname
# nl
# nm
# nmap
# nmapfe
# nm-applet
# nmblookup
# nmcli
# nm-connection-editor
# nm-online
# nmtui
# nmtui-connect
# nmtui-edit
# nmtui-hostname
# nohup
# nokogiri
# nop
# npa-tool
# nping
# nproc
# nroff
# nsenter
# nslookup
# nstat
# nsupdate
# ntfs-3g
# ntfs-3g.probe
# ntfscat
# ntfscluster
# ntfscmp
# ntfsdecrypt
# ntfsfallocate
# ntfsfix
# ntfsinfo
# ntfsls
# ntfsmove
# ntfsrecover
# ntfssecaudit
# ntfstruncate
# ntfsusermap
# ntfswipe
# ntlm2
# ntlm_brute
# ntpdc
# ntpq
# ntpsweep
# ntptrace
# numfmt
# obexctl
# obj2yaml-6.0
# obj2yaml-7
# objcopy
# objdump
# oclock
# od
# oLschema2ldif
# on_ac_power
# onesixtyone
# openpgp-tool
# opensc-asn1
# opensc-explorer
# opensc-notify
# opensc-tool
# openssl
# openvt
# ophcrack
# ophcrack-cli
# opt-6.0
# opt-7
# orbd
# orca
# orca-dm-wrapper
# osage
# os-prober
# out123
# p11-kit
# p7zip
# pacat
# pack200
# packetforge-ng
# pacmd
# pactl
# pad_digest_utility
# padsp
# pager
# pamon
# paperconf
# paplay
# parec
# parecord
# parse-edid
# partx
# passmass
# passwd
# paste
# paster
# pasteurize
# pasuspender
# patator
# patch
# patchwork
# pathchk
# pathoc
# pathod
# pax11publish
# pcf2vpnc
# pcreate
# pdb
# pdb2
# pdb2.7
# pdb3
# pdb3.7
# pdbedit
# pdfdetach
# pdffonts
# pdfid
# pdfimages
# pdfinfo
# pdf-parser
# pdfseparate
# pdfsig
# pdftocairo
# pdftohtml
# pdftoppm
# pdftops
# pdftotext
# pdfunite
# pdistreport
# peekfd
# peepdf
# perf
# perl
# perl5.28.1
# perl5.28-i386-linux-gnu
# perlbug
# perldoc
# perli11ndoc
# perlivp
# perlthanks
# perror
# pftp
# pg_archivecleanup
# pg_basebackup
# pgbench
# pg_buildext
# pg_config
# pg_conftool
# pg_createcluster
# pg_ctlcluster
# pg_dropcluster
# pg_dump
# pg_dumpall
# pg_isready
# pg_lsclusters
# pg_receivewal
# pg_receivexlog
# pg_recvlogical
# pg_renamecluster
# pgrep
# pg_restore
# pg_upgradecluster
# pg_virtualenv
# phar
# phar7.3
# phar.phar
# phar.phar7.3
# photorec
# php
# php7.3
# pic
# pico
# piconv
# pidof
# pidstat
# pigz
# pinentry
# pinentry-gnome3
# pinentry-x11
# ping
# ping4
# ping6
# pinky
# pip3
# pipal
# piv-tool
# pixeltool
# pixiewps
# pkaction
# pkcheck
# pkcon
# pkcs11-tool
# pkcs15-crypt
# pkcs15-init
# pkcs15-tool
# pkexec
# pkill
# pkmon
# pkttyagent
# pl2pm
# pldd
# plog
# plugin_test
# plymouth
# pmap
# pmspike
# pod2html
# pod2man
# pod2text
# pod2usage
# podchecker
# podselect
# poff
# polenum
# policytool
# pon
# POST
# post_fuzz
# post_spike
# powersploit
# pr
# precat
# preconv
# prequest
# preunzip
# prezip
# prezip-bin
# print
# printenv
# printerbanner
# printf
# prlimit
# procan
# profiles
# proutes
# prove
# proxychains
# proxychains3
# proxytunnel
# prtstat
# prune
# ps
# pserve
# psfaddtable
# psfgettable
# psfstriptable
# psfxtable
# pshell
# psk-crack
# pslog
# psql
# pstree
# pstree.x11
# ptar
# ptardiff
# ptargrep
# pth-curl
# pth-net
# pth-rpcclient
# pth-smbclient
# pth-smbget
# pth-sqsh
# pth-winexe
# pth-wmic
# pth-wmis
# ptweens
# ptx
# pulseaudio
# pviews
# pwd
# pwdump
# pwdx
# pwgen
# pw-inspector
# pwnat
# py3clean
# py3compile
# py3versions
# pybabel
# pybabel-python2
# pybuild
# pyclean
# pycompile
# pydoc
# pydoc2
# pydoc2.7
# pydoc3
# pydoc3.7
# pygettext
# pygettext2
# pygettext2.7
# pygettext3
# pygettext3.7
# pygmentize
# pyhtmlizer
# python
# python2
# python2.7
# python2.7-config
# python2-config
# python2-futurize
# python2-pasteurize
# python2-qr
# python2-wsdump
# python3
# python3.7
# python3.7-config
# python3.7m
# python3.7m-config
# python3-config
# python3-futurize
# python3-jsonschema
# python3m
# python3m-config
# python3-pasteurize
# python3-wsdump
# python-config
# python-faraday
# pyversions
# qcollectiongenerator
# qdbus
# qdbuscpp2xml
# qdbusviewer
# qdbusxml2cpp
# qdoc
# qdoc3
# qgltf
# qhelpconverter
# qhelpgenerator
# qlalr
# qmake
# qml
# qml1plugindump
# qmlbundle
# qmlcachegen
# qmleasing
# qmlimportscanner
# qmljs
# qmllint
# qmlmin
# qmlplugindump
# qmlprofiler
# qmlscene
# qmltestrunner
# qmlviewer
# qr
# qtattributionsscanner
# qtchooser
# qtconfig
# qtdiag
# qtpaths
# qtplugininfo
# quake
# quakeserver
# querybts
# qvkgen
# r2
# r2agent
# r2pm
# rabin2
# radare2
# radiff2
# rafind2
# ragg2
# rahash2
# rake
# randpkt
# ranlib
# rarun2
# rasm2
# rawshark
# rax2
# rb
# rbash
# rcc
# rcp
# rctest
# rdesktop
# rdf2bin
# rdf2com
# rdf2ihx
# rdf2ith
# rdf2srec
# rdfdump
# rdflib
# rdjpgcom
# rdma
# rdoc
# rdoc2.5
# rdx
# readelf
# readlink
# readmsg
# readmsg.mailutils
# realpath
# rearj
# reaver
# recon-cli
# recon-ng
# recon-web
# recordmydesktop
# reindexdb
# rename.ul
# rendercheck
# renice
# reordercap
# repc
# replace
# replay.pl
# reportbug
# reset
# resize
# resizecons
# resizepart
# resolvectl
# resolveip
# resolve_stack_dump
# responder-BrowserListener
# responder-DHCP
# responder-FindSMB2UPTime
# responder-FindSQLSrv
# responder-Icmp-Redirect
# responder-MultiRelay
# responder-RunFinger
# rev
# rfcomm
# rgrep
# ri
# ri2.5
# rlogin
# rlogin-cwd
# rm
# rmdir
# rmid
# rmiregistry
# rnano
# rotatelogs
# routef
# routel
# rpcclient
# rpcgen
# rpcinfo
# rsh
# rsmangler
# rsync
# rtstat
# ruby
# ruby2.5
# runcon
# run-mailcap
# run-parts
# runscript
# run-with-aspell
# ruptime
# rview
# rvim
# rwho
# rx
# rygel
# rz
# rzsh
# sadf
# sakis3g
# samba-regedit
# samba-tool
# samdump2
# sane-find-scanner
# sanstats-6.0
# sanstats-7
# sar
# sar.sysstat
# savelog
# sb
# sbd
# sbiload
# scalpel
# scanimage
# scapy
# sccmap
# sc-hsm-tool
# scp
# scp-dbus-service
# scprofiler
# screen
# screendump
# script
# scriptreplay
# sctest
# sdiff
# sdmem
# sdptool
# searchsploit
# sed
# see
# select-default-iwrap
# select-editor
# sendemail
# sendEmail
# sendmsrpc
# sensible-browser
# sensible-editor
# sensible-pager
# seq
# servertool
# sessreg
# setarch
# setcifsacl
# setfacl
# setfattr
# setfont
# setkeycodes
# setleds
# setlogcons
# setmetamode
# se-toolkit
# setoolkit
# setpci
# setpriv
# setsid
# setterm
# setupcon
# setvtrgb
# setxkbmap
# sfdp
# sfill
# sftp
# sg
# sh
# sha1deep
# sha1sum
# sha224sum
# sha256deep
# sha256sum
# sha384sum
# sha512sum
# sharesec
# shasum
# showconsolefont
# showkey
# showrgb
# shred
# shuf
# sieve
# sigfind
# signature_digest_utility
# size
# skill
# skipfish
# slabtop
# sleep
# slogin
# smbcacls
# smbclient
# smbcontrol
# smbcquotas
# smbget
# smbmap
# smbpasswd
# smbspool
# smbstatus
# smbtar
# smbtree
# snice
# snmp-bridge-mib
# snmpbulkget
# snmpbulkwalk
# snmp-check
# snmpcheck
# snmpconf
# snmpdelta
# snmpdf
# snmpget
# snmpgetnext
# snmpinform
# snmpkey
# snmpnetstat
# snmpset
# snmpstatus
# snmptable
# snmptest
# snmptranslate
# snmptrap
# snmpusm
# snmpvacm
# snmpwalk
# sntp
# socat
# soelim
# software-properties-gtk
# sort
# sorter
# sotruss
# sp32
# sp64
# sparta
# spd-conf
# spd-say
# speech-dispatcher
# splain
# split
# splitfont
# spooftooph
# sprof
# sqldiff
# sqlite3
# sqlitebrowser
# sqlmap
# sqlmapapi
# sqsh
# srch_strings
# srm
# ss
# ssh
# ssh-add
# ssh-agent
# ssh-argv0
# ssh-copy-id
# ssh-keygen
# ssh-keyscan
# sslcaudit
# sslscan
# sslsplit
# sslstrip
# sslyze
# ss_spike
# sswap
# start-pulseaudio-x11
# stat
# statd_spike
# stdbuf
# stl2gts
# strings
# strip
# stty
# stunnel
# stunnel3
# stunnel4
# su
# sudo
# sudoedit
# sudoreplay
# sum
# sunrpcfuzz
# sushi
# svn
# svnadmin
# svnauthz
# svnauthz-validate
# svnbench
# svndumpfilter
# svnfsfs
# svnlook
# svnmucc
# svnrdump
# svnserve
# svnsync
# svnversion
# swaks
# sx
# symcryptrun
# sync
# system-config-printer
# system-config-printer-applet
# systemctl
# systemd
# systemd-analyze
# systemd-ask-password
# systemd-cat
# systemd-cgls
# systemd-cgtop
# systemd-delta
# systemd-detect-virt
# systemd-escape
# systemd-hwdb
# systemd-id128
# systemd-inhibit
# systemd-machine-id-setup
# systemd-mount
# systemd-notify
# systemd-path
# systemd-resolve
# systemd-run
# systemd-socket-activate
# systemd-stdio-bridge
# systemd-sysusers
# systemd-tmpfiles
# systemd-tty-ask-password-agent
# systemd-umount
# sz
# tabs
# tac
# tail
# tapestat
# tar
# tasksel
# taskset
# tbl
# tclsh8.6
# tcpbridge
# tcpcapinfo
# tcpliveplay
# tcpprep
# tcpreplay
# tcpreplay-edit
# tcprewrite
# tdbbackup
# tdbbackup.tdbtools
# tdbdump
# tdbrestore
# tdbtool
# tee
# telnet
# telnet.netkit
# tempfile
# teredo-mire
# terminator
# test
# testdisk
# testparm
# text2pcap
# tftp
# thc-pptp-bruter
# theharvester
# thor
# tic
# tigerdeep
# tightvncconnect
# tightvncpasswd
# tightvncserver
# timedatectl
# timed-read
# timed-run
# timeout
# tjbench
# tkconch
# tknewsbiff
# tkpasswd
# tload
# tmux
# tnameserv
# toe
# top
# totem
# totem-video-thumbnailer
# touch
# tpm2_activatecredential
# tpm2_certify
# tpm2_create
# tpm2_createpolicy
# tpm2_createprimary
# tpm2_dictionarylockout
# tpm2_encryptdecrypt
# tpm2_evictcontrol
# tpm2_getcap
# tpm2_getmanufec
# tpm2_getpubak
# tpm2_getpubek
# tpm2_getrandom
# tpm2_hash
# tpm2_hmac
# tpm2_listpersistent
# tpm2_load
# tpm2_loadexternal
# tpm2_makecredential
# tpm2_nvdefine
# tpm2_nvlist
# tpm2_nvread
# tpm2_nvreadlock
# tpm2_nvrelease
# tpm2_nvwrite
# tpm2_pcrevent
# tpm2_pcrextend
# tpm2_pcrlist
# tpm2_quote
# tpm2_rc_decode
# tpm2_readpublic
# tpm2_rsadecrypt
# tpm2_rsaencrypt
# tpm2_send
# tpm2_sign
# tpm2_startup
# tpm2_takeownership
# tpm2_unseal
# tpm2_verifysignature
# tpmc
# tpm_init_temp_fix
# tpm-nvsize
# tput
# tr
# traceproto
# traceproto.db
# traceroute
# traceroute6
# traceroute6.db
# traceroute.db
# traceroute-nanog
# tracker
# transform
# transset
# tred
# trial
# troff
# true
# truncate
# trust
# tset
# tshark
# tsk_comparedir
# tsk_gettimes
# tsk_loaddb
# tsk_recover
# tsort
# tty
# twist
# twistd
# twopi
# tzselect
# ucf
# ucfq
# ucfr
# ucs2any
# udevadm
# udisksctl
# udptunnel
# uic
# uic3
# ul
# ulockmgr_server
# umax_pp
# umount
# uname
# unattended-upgrade
# unattended-upgrades
# unbuffer
# uncompress
# uncompress.real
# unexpand
# unflatten
# unicode_start
# unicode_stop
# uniq
# unix2dos
# unix2mac
# unix-privesc-check
# unlink
# unlzma
# unmkinitramfs
# unpack200
# unpigz
# unrar
# unrar-nonfree
# unshare
# unsquashfs
# unxz
# unzip
# unzipsfx
# update-alternatives
# updatedb
# updatedb.mlocate
# update-desktop-database
# update-leap
# update-mime-database
# upower
# uptime
# upx
# upx-ucl
# us428control
# usb-devices
# usbhid-dump
# usbreset
# users
# usnjls
# utmpdump
# uuidgen
# uuidparse
# uxterm
# vacuumdb
# vacuumlo
# vbutil_firmware
# vbutil_kernel
# vbutil_key
# vbutil_keyblock
# vbutil_what_keys
# vdir
# verify_data
# verify-uselistorder-6.0
# verify-uselistorder-7
# VGAuthService
# vi
# view
# viewres
# vim
# vim.basic
# vimdiff
# vimdot
# vim.tiny
# vimtutor
# vmhgfs-fuse
# vmstat
# vmtoolsd
# vmware-checkvm
# vmwarectrl
# vmware-guestproxycerttool
# vmware-hgfsclient
# vmware-namespace-cmd
# vmware-rpctool
# vmware-toolbox-cmd
# vmware-user
# vmware-user-suid-wrapper
# vmware-vgauth-cmd
# vmware-vgauth-smoketest
# vmware-vmblock-fuse
# vmware-xferlogs
# vncconnect
# vncpasswd
# vncserver
# vncviewer
# voiphopper
# volname
# w
# wafw00f
# waitress-serve
# waitress-serve-python2
# wall
# wash
# watch
# watchgnupg
# wc
# wdctl
# webfuzz
# webshells
# weevely
# westcos-tool
# wfuzz
# wget
# whatis
# whatweb
# whereis
# which
# whiptail
# whirlpooldeep
# who
# whoami
# whois
# windows-binaries
# windows-resources
# winexe
# wireshark
# word-list-compress
# wordlists
# wpaclean
# wpa_passphrase
# w.procps
# wpscan
# write
# wrjpgcom
# wsdump
# wsrep_sst_common
# wsrep_sst_mariabackup
# wsrep_sst_mysqldump
# wsrep_sst_rsync
# wsrep_sst_rsync_wan
# X
# X11
# x11perf
# x11perfcomp
# x11_spike
# xargs
# xauth
# xbiff
# xbrlapi
# xcalc
# xclipboard
# xclock
# xcmsdb
# xconsole
# xcursorgen
# xcutsel
# xdg-desktop-icon
# xdg-desktop-menu
# xdg-email
# xdg-icon-resource
# xdg-mime
# xdg-open
# xdg-screensaver
# xdg-settings
# xdg-user-dir
# xdg-user-dirs-update
# xditview
# xdpyinfo
# xdriinfo
# xedit
# Xephyr
# xev
# xeyes
# xfd
# xfontsel
# xfreerdp
# xgamma
# xgc
# xhost
# xhydra
# xkbbell
# xkbcomp
# xkbevd
# xkbprint
# xkbvleds
# xkbwatch
# xkeystone
# xkibitz
# xkill
# xload
# xlogo
# xlsatoms
# xlsclients
# xlsfonts
# xmag
# xman
# xmessage
# xminicom
# xmlcatalog
# xmllint
# xmlpatterns
# xmlpatternsvalidator
# xmodmap
# xmore
# xnmap
# Xorg
# xpdf
# xpdf.real
# xprop
# xpstat
# xrandr
# xrdb
# xrefresh
# x-session-manager
# xset
# xsetmode
# xsetpointer
# xsetroot
# xsetwacom
# xsltproc
# xstdcmap
# xsubpp
# xterm
# x-terminal-emulator
# Xtightvnc
# xtightvncviewer
# xvidtune
# xvinfo
# Xvnc
# xvncviewer
# Xwayland
# xwd
# x-window-manager
# xwininfo
# xwud
# x-www-browser
# xxd
# xz
# xzcat
# xzcmp
# xzdiff
# xzegrep
# xzfgrep
# xzgrep
# xzless
# xzmore
# yaml2obj-6.0
# yaml2obj-7
# yaml-bench-6.0
# yaml-bench-7
# yelp
# yes
# ypdomainname
# zcat
# zcmp
# zdiff
# zdump
# zegrep
# zenity
# zenmap
# zfgrep
# zforce
# zgrep
# zip
# zipcloak
# zipdetails
# zipgrep
# zipinfo
# zipnote
# zipsplit
# zless
# zmore
# znew
# zsh
# zsh5

# %% [markdown]
# ## Pipelines
# - connect multiple commands together
# - feed output from one command as an input to another command

# %%
# sort based on 5th column in reverse order
! ls -l | sort -k5nr > sortedls.txt

# %%
! cat sortedls.txt
# Out:
# -rw-r--r-- 1 root root 90097 Jan 25 20:17 Ch02-NavigationExploration.ipynb
# -rw-r--r-- 1 root root 20095 Jan 25 23:44 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 root root 19599 Jan 25 23:50 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 root root 17481 Jan 25 22:57 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 root root  9193 Jan 26 20:34 IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 root root  4660 Jan 25 23:29 Ch01-LearningShell.ipynb
# drwxr-xr-x 2 root root  4096 Jan 25 21:44 resources
# -rw-r--r-- 1 root root  1092 Jan 26 20:28 ls.txt
# -rw-r--r-- 1 root root  1092 Jan 26 20:30 sorted.txt
# -rw-r--r-- 1 root root   544 Jan 26 00:14 README.md
# -rw-r--r-- 1 root root     0 Jan 26 20:36 sortedls.txt
# total 184

# %%
# find total number of files in the current directory and all of its sub directories
! find . -type f | wc -l
# Out:
# 63

# %% [markdown]
# ## Filters
# - piplines are often used to perform complex operations on data
# - commands used with pipelines are referred to as **filters**
# - filters take input, change it somehow and then output it
#
# ### sort
# - sort text files; can sort based on columns if file contains tabular data

# %% [markdown]
# ### uniq
# - report or omit repeated lines; used in conjunction with sort to remove duplicate lines

# %%
! ls /bin /usr/bin | sort | uniq | less
# Out:
# 7=
# [
# 2to3-2.7
# 7z
# 7za
# 7zr
# aa-enabled
# aa-exec
# ab
# acyclic
# add-apt-repository
# addpart
# addr2line
# aircrack-ng
# airdecap-ng
# airdecloak-ng
# airolib-ng
# alembic
# apg
# apgbfm
# appres
# appstreamcli
# apropos
# :

# %% [markdown]
# ### wc
# - word count command is used to display the number of lines, words, and bytes contained in files

# %%
! wc sortedls.txt
# Out:
#  12 101 723 sortedls.txt

# %%
# count lines
! wc -l sortedls.txt
# Out:
# 12 sortedls.txt

# %%
# count words
! wc -w sortedls.txt
# Out:
# 101 sortedls.txt

# %%
# count bytes/characters
! wc -c sortedls.txt
# Out:
# 723 sortedls.txt

# %% [markdown]
# ### head/tail
# - print first/last 10 lines of files

# %%
! head sortedls.txt
# Out:
# -rw-r--r-- 1 root root 90097 Jan 25 20:17 Ch02-NavigationExploration.ipynb
# -rw-r--r-- 1 root root 20095 Jan 25 23:44 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 root root 19599 Jan 25 23:50 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 root root 17481 Jan 25 22:57 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 root root  9193 Jan 26 20:34 IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 root root  4660 Jan 25 23:29 Ch01-LearningShell.ipynb
# drwxr-xr-x 2 root root  4096 Jan 25 21:44 resources
# -rw-r--r-- 1 root root  1092 Jan 26 20:28 ls.txt
# -rw-r--r-- 1 root root  1092 Jan 26 20:30 sorted.txt
# -rw-r--r-- 1 root root   544 Jan 26 00:14 README.md

# %%
! tail sortedls.txt
# Out:
# -rw-r--r-- 1 root root 19599 Jan 25 23:50 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 root root 17481 Jan 25 22:57 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 root root  9193 Jan 26 20:34 IORedirection-Pipelines.ipynb
# -rw-r--r-- 1 root root  4660 Jan 25 23:29 Ch01-LearningShell.ipynb
# drwxr-xr-x 2 root root  4096 Jan 25 21:44 resources
# -rw-r--r-- 1 root root  1092 Jan 26 20:28 ls.txt
# -rw-r--r-- 1 root root  1092 Jan 26 20:30 sorted.txt
# -rw-r--r-- 1 root root   544 Jan 26 00:14 README.md
# -rw-r--r-- 1 root root     0 Jan 26 20:36 sortedls.txt
# total 184

# %%
# use -n n to display n lines
! head -n 5 sortedls.txt
# Out:
# -rw-r--r-- 1 root root 90097 Jan 25 20:17 Ch02-NavigationExploration.ipynb
# -rw-r--r-- 1 root root 20095 Jan 25 23:44 Ch03-ManipulatingFilesAndDirectories.ipynb
# -rw-r--r-- 1 root root 19599 Jan 25 23:50 Ch05-UserManagementEnvVariables.ipynb
# -rw-r--r-- 1 root root 17481 Jan 25 22:57 Ch04-FilesAndPermissions.ipynb
# -rw-r--r-- 1 root root  9193 Jan 26 20:34 IORedirection-Pipelines.ipynb

# %%
! tail -n 5 sortedls.txt
# Out:
# -rw-r--r-- 1 root root  1092 Jan 26 20:28 ls.txt
# -rw-r--r-- 1 root root  1092 Jan 26 20:30 sorted.txt
# -rw-r--r-- 1 root root   544 Jan 26 00:14 README.md
# -rw-r--r-- 1 root root     0 Jan 26 20:36 sortedls.txt
# total 184

# %%
! ls /usr/bin | tail -n 5
# Out:
# zless
# zmore
# znew
# zsh
# zsh5

# %%
# monitor a file with -f option
# when new messages/lines appened to a file being monitored they immidiately appear on the display
# contines until you enter Ctrl-c
! tail -f /var/log/messages
# Out:
# Jan 26 20:22:25 kali kernel: [182486.253261] usb 1-2.1: SerialNumber: 000650268328
# Jan 26 20:22:27 kali gsd-color[1416]: unable to get EDID for xrandr-Virtual1: unable to get EDID for output
# Jan 26 20:22:27 kali gsd-color[1416]: unable to get EDID for xrandr-Virtual1: unable to get EDID for output
# Jan 26 20:22:27 kali gsd-color[1416]: unable to get EDID for xrandr-Virtual1: unable to get EDID for output
# Jan 26 20:23:51 kali /usr/lib/gdm3/gdm-x-session[1202]: (!!) vmware(0): New layout.
# Jan 26 20:23:51 kali /usr/lib/gdm3/gdm-x-session[1202]: (!!) vmware(0): 0: 0 0 1432 942
# Jan 26 20:23:51 kali /usr/lib/gdm3/gdm-x-session[1202]: (!!) vmware(0):
# Jan 26 20:23:52 kali gsd-color[1416]: unable to get EDID for xrandr-Virtual1: unable to get EDID for output
# Jan 26 20:23:52 kali gsd-color[1416]: unable to get EDID for xrandr-Virtual1: unable to get EDID for output
# Jan 26 20:23:52 kali gsd-color[1416]: unable to get EDID for xrandr-Virtual1: unable to get EDID for output
# ^C

# %% [markdown]
# ### tee
# - read from stdin and output to stdout and files
# - similar to "T" fitting on pipes (plumbing)

# %%
! ls /usr/bin | tee ls.txt | grep zip
# Out:
# bunzip2
# bzip2
# bzip2recover
# funzip
# gpg-zip
# gunzip
# gzip
# p7zip
# preunzip
# prezip
# prezip-bin
# unzip
# unzipsfx
# zip
# zipcloak
# zipdetails
# zipgrep
# zipinfo
# zipnote
# zipsplit

# %%
! cat ls.txt
# Out:
# [
# 2to3-2.7
# 7z
# 7za
# 7zr
# aa-enabled
# aa-exec
# ab
# acyclic
# add-apt-repository
# addpart
# addr2line
# aircrack-ng
# airdecap-ng
# airdecloak-ng
# airolib-ng
# alembic
# apg
# apgbfm
# appres
# appstreamcli
# apropos
# apt
# apt-add-repository
# apt-cache
# apt-cdrom
# apt-config
# apt-extracttemplates
# apt-ftparchive
# apt-get
# apt-key
# apt-listchanges
# apt-mark
# apt-sortpkgs
# ar
# arch
# aria_chk
# aria_dump_log
# aria_ftdump
# aria_pack
# aria_read_log
# arj
# arjdisp
# arj-register
# as
# as10k1
# asan_symbolize
# asan_symbolize-6.0
# asan_symbolize-7
# ascii-xfr
# aspell
# aspell-import
# assistant
# atk6-address6
# atk6-alive6
# atk6-connect6
# atk6-connsplit6
# atk6-covert_send6
# atk6-covert_send6d
# atk6-denial6
# atk6-detect-new-ip6
# atk6-detect_sniffer6
# atk6-dnsdict6
# atk6-dnsrevenum6
# atk6-dnssecwalk
# atk6-dos-new-ip6
# atk6-dump_dhcp6
# atk6-dump_router6
# atk6-exploit6
# atk6-extract_hosts6
# atk6-extract_networks6
# atk6-fake_advertise6
# atk6-fake_dhcps6
# atk6-fake_dns6d
# atk6-fake_dnsupdate6
# atk6-fake_mipv6
# atk6-fake_mld26
# atk6-fake_mld6
# atk6-fake_mldrouter6
# atk6-fake_pim6
# atk6-fake_router26
# atk6-fake_router6
# atk6-fake_solicitate6
# atk6-firewall6
# atk6-flood_advertise6
# atk6-flood_dhcpc6
# atk6-flood_mld26
# atk6-flood_mld6
# atk6-flood_mldrouter6
# atk6-flood_redir6
# atk6-flood_router26
# atk6-flood_router6
# atk6-flood_rs6
# atk6-flood_solicitate6
# atk6-flood_unreach6
# atk6-four2six
# atk6-fragmentation6
# atk6-fragrouter6
# atk6-fuzz_dhcpc6
# atk6-fuzz_dhcps6
# atk6-fuzz_ip6
# atk6-implementation6
# atk6-implementation6d
# atk6-inject_alive6
# atk6-inverse_lookup6
# atk6-kill_router6
# atk6-ndpexhaust26
# atk6-ndpexhaust6
# atk6-node_query6
# atk6-parasite6
# atk6-passive_discovery6
# atk6-randicmp6
# atk6-redir6
# atk6-redirsniff6
# atk6-rsmurf6
# atk6-sendpees6
# atk6-sendpeesmp6
# atk6-smurf6
# atk6-thcping6
# atk6-thcsyn6
# atk6-toobig6
# atk6-toobigsniff6
# atk6-trace6
# atobm
# attr
# autoexpect
# automat-visualize
# autopasswd
# autopsy
# awk
# axel
# b2sum
# b43-fwcutter
# baobab
# base32
# base64
# basename
# bash
# bashbug
# bccmd
# bcomps
# bdb_extend
# bdftopcf
# bdftruncate
# besside-ng-crawler
# binwalk
# bitmap
# blkcalc
# blkcat
# blkls
# blkstat
# bluemoon
# bluetoothctl
# bluetooth-sendto
# bmpblk_font
# bmpblk_utility
# bmtoa
# boltctl
# bootctl
# broadwayd
# bsd-from
# bsd-write
# btattach
# btmgmt
# btmon
# buddy-ng
# bugpoint-6.0
# bugpoint-7
# bulk_extractor
# bully
# bundle
# bundler
# bunzip2
# burpsuite
# busctl
# busybox
# bwrap
# bzcat
# bzcmp
# bzdiff
# bzegrep
# bzexe
# bzfgrep
# bzgrep
# bzip2
# bzip2recover
# bzless
# bzmore
# c++
# c89
# c89-gcc
# c99
# c99-gcc
# cachedump
# cadaver
# cal
# calc_tickadj
# calendar
# cancel
# capinfos
# captoinfo
# captype
# cardos-tool
# caribou-preferences
# cat
# catchsegv
# catman
# cc
# ccomps
# cd-create-profile
# cd-fix-profile
# cd-iccdump
# cd-it8
# cewl
# c++filt
# cgpt
# chacl
# chage
# chardet
# chardet3
# chardetect
# chardetect3
# chattr
# chcon
# checkgid
# cherrytree
# chfn
# chgrp
# chmod
# choom
# chown
# chromedriver
# chrome-gnome-shell
# chromeos-tpm-recovery
# chromium
# chrt
# chsh
# chvt
# cifscreds
# cifsdd
# cifsiostat
# ciptool
# circo
# cisco-decrypt
# citrix
# cjpeg
# ckbcomp
# ckeygen
# cksum
# clang
# clang++
# clang++-6.0
# clang-6.0
# clang++-7
# clang-7
# clang-cpp-6.0
# clang-cpp-7
# clear
# clear_console
# clhsdb
# closed_source_web_server_fuzz
# cluster
# clusterd
# clusterdb
# cmp
# code
# codepage
# col
# colcrt
# colormgr
# colrm
# column
# comm
# commix
# compose
# compress
# conch
# conchftp
# corelist
# cp
# cpan
# cpan5.28-i386-linux-gnu
# cpio
# cpp
# cpp-8
# cramfsswap
# createdb
# createlang
# createuser
# c_rehash
# crontab
# crossystem
# crossystem_s
# crunch
# cryptcat
# cryptdir
# cryptoflex-tool
# csplit
# ctstat
# cupstestdsc
# cupstestppd
# curl
# curlftpfs
# cut
# cutycapt
# cvt
# cvtsudoers
# cygdb
# cython
# dash
# date
# dave
# davtest
# dbd
# dbilogstrip
# dbiprof
# dbiproxy
# dbus-cleanup-sockets
# dbus-daemon
# dbus-launch
# dbus-monitor
# dbus-run-session
# dbus-send
# dbus-update-activation-environment
# dbus-uuidgen
# dbwrap_tool
# dccleancrw
# dceoversmb
# dcfujigreen
# dcfujiturn
# dcfujiturn16
# dconf
# dcparse
# dcraw
# dd
# ddcmon
# deallocvt
# debconf
# debconf-apt-progress
# debconf-communicate
# debconf-copydb
# debconf-escape
# debconf-set-selections
# debconf-show
# debianbts
# deb-systemd-helper
# deb-systemd-invoke
# debtags
# decode-dimms
# decode-edid
# decode-vaio
# decryptdir
# delaunay
# delpart
# delv
# designer
# desktop-file-edit
# desktop-file-install
# desktop-file-validate
# dev_debug_vboot
# dev_make_keypair
# df
# dfu-tool
# dh_bash-completion
# dh_numpy
# dh_numpy3
# dh_perl_dbi
# dh_perl_openssl
# dh_pypy
# dh_python2
# dh_python3
# dh_python3-ply
# diff
# diff3
# diffimg
# dig
# dijkstra
# dir
# dirb
# dirb-gendict
# dirbuster
# dircolors
# dirmngr
# dirmngr-client
# dirname
# dislocate
# django-admin
# djpeg
# dltest
# dmesg
# dmitry
# dnie-tool
# dns2tcpc
# dns2tcpd
# dnschef
# dnsdomainname
# dnsenum
# dns-rebind
# dnsrecon
# dnstap-read
# domainname
# do_post
# dos2unix
# dot
# dot2gxl
# dot_builtins
# dotlock
# dotlockfile
# dotlock.mailutils
# dotty
# dpkg
# dpkg-architecture
# dpkg-buildflags
# dpkg-buildpackage
# dpkg-checkbuilddeps
# dpkg-deb
# dpkg-distaddfile
# dpkg-divert
# dpkg-genbuildinfo
# dpkg-genchanges
# dpkg-gencontrol
# dpkg-gensymbols
# dpkg-maintscript-helper
# dpkg-mergechangelogs
# dpkg-name
# dpkg-parsechangelog
# dpkg-query
# dpkg-scanpackages
# dpkg-scansources
# dpkg-shlibdeps
# dpkg-source
# dpkg-split
# dpkg-statoverride
# dpkg-trigger
# dpkg-vendor
# dpl4hydra
# dropdb
# droplang
# dropuser
# dsymutil-7
# du
# dumpcap
# dump_fmap
# dump_kernel_config
# dumpkeys
# dumpRSAPublicKey
# dupemap
# dwp
# eatmydata
# echo
# edgepaint
# edit
# editcap
# editor
# editres
# eficompress
# efidecompress
# egk-tool
# egrep
# eidenv
# eject
# elfedit
# email_validator
# enable_dev_usb_boot
# enc2xs
# encguess
# enchant
# enchant-lsmod
# encode_keychange
# enum4linux
# env
# envsubst
# eog
# eqn
# erb
# erb2.5
# ettercap
# ettercap-pkexec
# etterfilter
# etterlog
# evince
# evince-previewer
# evince-thumbnailer
# ex
# exe2hex
# exifautotran
# exiv2
# expand
# expect
# expect_autoexpect
# expect_autopasswd
# expect_cryptdir
# expect_decryptdir
# expect_dislocate
# expect_ftp-rfc
# expect_kibitz
# expect_lpunlock
# expect_mkpasswd
# expect_multixterm
# expect_passmass
# expect_rftp
# expect_rlogin-cwd
# expect_timed-read
# expect_timed-run
# expect_tknewsbiff
# expect_tkpasswd
# expect_unbuffer
# expect_weather
# expect_xkibitz
# expect_xpstat
# expiry
# expr
# f2py
# f2py2.7
# f2py3
# f2py3.7
# fab-cewl
# factor
# faillog
# faked-sysv
# faked-tcp
# fakeroot
# fakeroot-sysv
# fakeroot-tcp
# fallocate
# false
# faraday
# faraday-client
# faraday-manage
# faraday-server
# fastjar
# fcat
# fc-cache
# fc-cat
# fc-conflist
# fcgistarter
# fc-list
# fc-match
# fc-pattern
# fc-query
# fc-scan
# fc-validate
# fdp
# fern-wifi-cracker
# ffind
# fgconsole
# fgrep
# fidentify
# fierce
# filan
# file
# file-roller
# fincore
# find
# findmnt
# findmyhash
# findsmb
# finger
# firefox
# firefox-esr
# fiwalk
# fixproc
# flac
# flask
# flock
# florence
# fls
# fmt
# fold
# fonttosfnt
# fping
# fping6
# fplugin
# free
# frm
# frm.mailutils
# from
# from.mailutils
# fsstat
# ftp
# ftp-rfc
# funzip
# fuser
# fusermount
# futility
# futility_s
# futurize
# fwupdmgr
# g++
# g++-8
# galera_new_cluster
# galera_recovery
# gamma4scanimage
# gapplication
# gatttool
# gawk
# gbb_utility
# gc
# gcalccmd
# gcc
# gcc-8
# gcc-ar
# gcc-ar-8
# gcc-nm
# gcc-nm-8
# gcc-ranlib
# gcc-ranlib-8
# gcov
# gcov-8
# gcov-dump
# gcov-dump-8
# gcov-tool
# gcov-tool-8
# gcr-viewer
# gdbus
# gdialog
# gdk-pixbuf-csource
# gdk-pixbuf-pixdata
# gdk-pixbuf-thumbnailer
# gdmflexiserver
# gdm-screenshot
# gedit
# gem
# gem2.5
# gencat
# generic_chunked
# generic_listen_tcp
# generic_send_tcp
# generic_send_udp
# generic_web_server_fuzz
# generic_web_server_fuzz2
# geqn
# GET
# getcifsacl
# getconf
# get-edid
# getent
# getfacl
# getfattr
# getkeycodes
# getopt
# gettext
# gettext.sh
# ghost-phisher
# gids-tool
# gio
# gio-querymodules
# git
# git-receive-pack
# git-shell
# git-upload-archive
# git-upload-pack
# gjs
# gjs-console
# gkbd-keyboard-display
# glib-compile-schemas
# gml2gv
# gnome-calculator
# gnome-characters
# gnome-contacts
# gnome-control-center
# gnome-disk-image-mounter
# gnome-disks
# gnome-font-viewer
# gnome-help
# gnome-keyring
# gnome-keyring-3
# gnome-keyring-daemon
# gnome-logs
# gnome-session
# gnome-session-classic
# gnome-session-custom-session
# gnome-session-inhibit
# gnome-session-quit
# gnome-shell
# gnome-shell-extension-prefs
# gnome-shell-extension-tool
# gnome-shell-perf-tool
# gnome-software
# gnome-software-editor
# gnome-system-monitor
# gnome-terminal
# gnome-terminal.wrapper
# gnome-text-editor
# gnome-thumbnail-font
# gnome-tweaks
# gnome-www-browser
# gold
# gopherd
# gpasswd
# gpg
# gpg-agent
# gpgcompose
# gpgconf
# gpg-connect-agent
# gpgparsemail
# gpgsm
# gpgsplit
# gpgtar
# gpgv
# gpg-wks-server
# gpg-zip
# gpic
# gpp-decrypt
# gprof
# graphml2gv
# grep
# grepjar
# gresource
# groff
# grog
# grops
# grotty
# groups
# grub-editenv
# grub-file
# grub-fstest
# grub-glue-efi
# grub-kbdcomp
# grub-menulst2cfg
# grub-mkfont
# grub-mkimage
# grub-mklayout
# grub-mknetdir
# grub-mkpasswd-pbkdf2
# grub-mkrelpath
# grub-mkrescue
# grub-mkstandalone
# grub-mount
# grub-ntldr-img
# grub-render-label
# grub-script-check
# grub-syslinux2cfg
# gsettings
# gstreamer-codec-install
# gtbl
# gtf
# gtk-builder-tool
# gtk-launch
# gtk-query-settings
# gtk-update-icon-cache
# gts2dxf
# gts2oogl
# gts2stl
# gts2xyz
# gtscheck
# gtscompare
# gts-config
# gtstemplate
# gunzip
# guymager
# gv2gml
# gv2gxl
# gvcolor
# gvgen
# gvmap
# gvmap.sh
# gvpack
# gvpr
# gxl2dot
# gxl2gv
# gzexe
# gzip
# h2ph
# h2xs
# halflife
# hashcat
# hashdeep
# hashid
# hash-identifier
# hciattach
# hciconfig
# hcidump
# hcitool
# hd
# hdajacksensetest
# hda-verb
# head
# HEAD
# helpztags
# hex2hcd
# hexdump
# hexeditor
# hexorbase
# hfind
# host
# hostid
# hostname
# hostnamectl
# hotpatcher
# hsdb
# htcacheclean
# htdbm
# htdigest
# html2dic
# htpasswd
# hupper
# hwloc-annotate
# hwloc-assembler
# hwloc-assembler-remote
# hwloc-bind
# hwloc-calc
# hwloc-compress-dir
# hwloc-diff
# hwloc-distances
# hwloc-distrib
# hwloc-gather-topology
# hwloc-info
# hwloc-ls
# hwloc-patch
# hwloc-ps
# hydra
# hydra-wizard
# i386
# i386-linux-gnu-python2.7-config
# i386-linux-gnu-python2-config
# i386-linux-gnu-python3.7-config
# i386-linux-gnu-python3.7m-config
# i386-linux-gnu-python3-config
# i386-linux-gnu-python3m-config
# i386-linux-gnu-python-config
# i586-linux-gnu-cpp
# i586-linux-gnu-g++
# i586-linux-gnu-gcc
# i586-linux-gnu-gcc-ar
# i586-linux-gnu-gcc-nm
# i586-linux-gnu-gcc-ranlib
# i586-linux-gnu-gcov
# i586-linux-gnu-gcov-dump
# i586-linux-gnu-gcov-tool
# i686-linux-gnu-addr2line
# i686-linux-gnu-ar
# i686-linux-gnu-as
# i686-linux-gnu-c++filt
# i686-linux-gnu-cpp
# i686-linux-gnu-cpp-8
# i686-linux-gnu-dwp
# i686-linux-gnu-elfedit
# i686-linux-gnu-g++
# i686-linux-gnu-g++-8
# i686-linux-gnu-gcc
# i686-linux-gnu-gcc-8
# i686-linux-gnu-gcc-ar
# i686-linux-gnu-gcc-ar-8
# i686-linux-gnu-gcc-nm
# i686-linux-gnu-gcc-nm-8
# i686-linux-gnu-gcc-ranlib
# i686-linux-gnu-gcc-ranlib-8
# i686-linux-gnu-gcov
# i686-linux-gnu-gcov-8
# i686-linux-gnu-gcov-dump
# i686-linux-gnu-gcov-dump-8
# i686-linux-gnu-gcov-tool
# i686-linux-gnu-gcov-tool-8
# i686-linux-gnu-gold
# i686-linux-gnu-gprof
# i686-linux-gnu-ld
# i686-linux-gnu-ld.bfd
# i686-linux-gnu-ld.gold
# i686-linux-gnu-nm
# i686-linux-gnu-objcopy
# i686-linux-gnu-objdump
# i686-linux-gnu-python2.7-config
# i686-linux-gnu-python2-config
# i686-linux-gnu-python3.7-config
# i686-linux-gnu-python3.7m-config
# i686-linux-gnu-python3-config
# i686-linux-gnu-python3m-config
# i686-linux-gnu-python-config
# i686-linux-gnu-ranlib
# i686-linux-gnu-readelf
# i686-linux-gnu-size
# i686-linux-gnu-strings
# i686-linux-gnu-strip
# iasecc-tool
# icalendar
# icat
# iceauth
# ico
# iconv
# id
# ifind
# ike-scan
# ils
# img_cat
# img_stat
# impacket-GetUserSPNs
# impacket-netview
# impacket-ntlmrelayx
# impacket-rpcdump
# impacket-samrdump
# impacket-secretsdump
# impacket-smbserver
# impacket-wmiexec
# inetsim
# infocmp
# infotocap
# innochecksum
# innotop
# install
# install-printerdriver
# instmodsh
# intel-virtual-output
# ionice
# iostat
# ip
# ipcmk
# ipcrm
# ipcs
# iptables-xml
# irb
# irb2.5
# ischroot
# isdv4-serial-debugger
# isdv4-serial-inputattach
# ispell-wrapper
# istat
# ivstools
# jar
# jardetector
# jarwrapper
# java
# jcat
# jexec
# jjs
# jls
# join
# journalctl
# jpegexiforient
# jpeg_extract
# jpegtran
# json_pp
# jsonschema
# kali-setup
# kali-treecd
# kali-winexec
# kbdinfo
# kbd_mode
# kbxutil
# kernel-install
# keyctl
# keyring
# keytool
# kibitz
# kill
# killall
# kismet
# kismet_cap_freaklabs_zigbee
# kismet_cap_kismetdb
# kismet_cap_linux_bluetooth
# kismet_cap_linux_wifi
# kismet_cap_nrf_mousejack
# kismet_cap_pcapfile
# kismet_cap_sdr_rtl433
# kismet_cap_sdr_rtl433_mqtt
# kismet_cap_sdr_rtladsb
# kismet_cap_sdr_rtladsb_mqtt
# kismet_cap_sdr_rtlamr
# kismet_cap_sdr_rtlamr_mqtt
# kismetdb_dump_devices
# kismetdb_statistics
# kismetdb_strip_packets
# kismetdb_to_kml
# kismetdb_to_wiglecsv
# kismet_server
# kmod
# koi8rxterm
# kstats
# l2ping
# l2test
# last
# lastb
# lastlog
# lbd
# lcf
# lconvert
# ld
# ldapadd
# ldapcompare
# ldapdelete
# ldapexop
# ldapmodify
# ldapmodrdn
# ldappasswd
# ldapsearch
# ldapurl
# ldapwhoami
# ld.bfd
# ldd
# ld.gold
# ldrdf
# leafpad
# lefty
# less
# lessecho
# lessfile
# lesskey
# lesspipe
# lexgrog
# lft
# lft.db
# libnetcfg
# libwacom-list-local-devices
# line_send_tcp
# linguist
# link
# linux32
# linux64
# linux-boot-prober
# linux-check-removal
# linux-update-symlinks
# linux-version
# listres
# llc-6.0
# llc-7
# lli-6.0
# lli-7
# lli-child-target-6.0
# lli-child-target-7
# llvm-ar-6.0
# llvm-ar-7
# llvm-as-6.0
# llvm-as-7
# llvm-bcanalyzer-6.0
# llvm-bcanalyzer-7
# llvm-cat-6.0
# llvm-cat-7
# llvm-cfi-verify-6.0
# llvm-cfi-verify-7
# llvm-config-6.0
# llvm-config-7
# llvm-cov-6.0
# llvm-cov-7
# llvm-c-test-6.0
# llvm-c-test-7
# llvm-cvtres-6.0
# llvm-cvtres-7
# llvm-cxxdump-6.0
# llvm-cxxdump-7
# llvm-cxxfilt-6.0
# llvm-cxxfilt-7
# llvm-diff-6.0
# llvm-diff-7
# llvm-dis-6.0
# llvm-dis-7
# llvm-dlltool-6.0
# llvm-dlltool-7
# llvm-dsymutil-6.0
# llvm-dwarfdump-6.0
# llvm-dwarfdump-7
# llvm-dwp-6.0
# llvm-dwp-7
# llvm-exegesis-7
# llvm-extract-6.0
# llvm-extract-7
# llvm-lib-6.0
# llvm-lib-7
# llvm-link-6.0
# llvm-link-7
# llvm-lto2-6.0
# llvm-lto2-7
# llvm-lto-6.0
# llvm-lto-7
# llvm-mc-6.0
# llvm-mc-7
# llvm-mca-7
# llvm-mcmarkup-6.0
# llvm-modextract-6.0
# llvm-modextract-7
# llvm-mt-6.0
# llvm-mt-7
# llvm-nm-6.0
# llvm-nm-7
# llvm-objcopy-6.0
# llvm-objcopy-7
# llvm-objdump-6.0
# llvm-objdump-7
# llvm-opt-report-6.0
# llvm-opt-report-7
# llvm-pdbutil-6.0
# llvm-pdbutil-7
# llvm-PerfectShuffle-6.0
# llvm-PerfectShuffle-7
# llvm-profdata-6.0
# llvm-profdata-7
# llvm-ranlib-6.0
# llvm-ranlib-7
# llvm-rc-6.0
# llvm-rc-7
# llvm-readelf-6.0
# llvm-readelf-7
# llvm-readobj-6.0
# llvm-readobj-7
# llvm-rtdyld-6.0
# llvm-rtdyld-7
# llvm-size-6.0
# llvm-size-7
# llvm-split-6.0
# llvm-split-7
# llvm-stress-6.0
# llvm-stress-7
# llvm-strings-6.0
# llvm-strings-7
# llvm-strip-7
# llvm-symbolizer-6.0
# llvm-symbolizer-7
# llvm-tblgen-6.0
# llvm-tblgen-7
# llvm-undname-7
# llvm-xray-6.0
# llvm-xray-7
# ln
# lneato
# lnstat
# load_kernel_test
# loadkeys
# loadunimap
# locale
# localectl
# localedef
# locate
# logger
# login
# loginctl
# logname
# logresolve
# look
# lorder
# lowntfs-3g
# lp
# lpoptions
# lpq
# lpr
# lprm
# lpstat
# lpunlock
# lrelease
# ls
# lsadump
# lsattr
# lsblk
# lsb_release
# lscpu
# lsinitramfs
# lsipc
# lslocks
# lslogins
# lsmem
# lsmod
# lsns
# lsof
# lspci
# lspgpot
# lstopo
# lstopo-no-graphics
# lsusb
# luit
# lupdate
# lwp-download
# lwp-dump
# lwp-mirror
# lwp-request
# lxterm
# lzcat
# lzcmp
# lzdiff
# lzegrep
# lzfgrep
# lzgrep
# lzless
# lzma
# lzmainfo
# lzmore
# mac2unix
# macchanger
# mactime
# magicrescue
# magicsort
# mail
# mailmail
# mail.mailutils
# mailq
# mailx
# make
# make-cadir
# make-first-existing-target
# makeivs-ng
# mako-render
# maltego
# man
# mandb
# manpath
# mapscrn
# mariadb
# mariadbcheck
# mariadb-service-convert
# masscan
# mawk
# mcookie
# md5deep
# md5sum
# md5sum.textutils
# mdig
# mergecap
# mesg
# messages
# messages.mailutils
# metaflac
# mibdump
# migrate-pubring-from-classic-gpg
# mimeopen
# mimetype
# mimeview
# mimikatz
# minicom
# miniterm
# miranda
# mitmdump
# mitmproxy
# mitmweb
# mkdir
# mkfifo
# mkfontdir
# mkfontscale
# mk_modmap
# mknod
# mkpasswd
# mksquashfs
# mktemp
# mlocate
# mm2gv
# mmcat
# mmcli
# mmdbresolve
# mmls
# mmstat
# moc
# monitor-sensor
# more
# mount
# mountpoint
# mousetweaks
# movemail
# movemail.mailutils
# mp32
# mp3-decoder
# mp64
# mpg123
# mpg123-alsa
# mpg123.bin
# mpg123-id3dump
# mpg123-jack
# mpg123-nas
# mpg123-openal
# mpg123-oss
# mpg123-portaudio
# mpg123-pulse
# mpg123-strip
# mpris-proxy
# mpstat
# msfconsole
# msfd
# msfdb
# msf-egghunter
# msf-exe2vba
# msf-exe2vbs
# msf-find_badchars
# msf-halflm_second
# msf-hmac_sha1_crack
# msf-java_deserializer
# msf-jsobfu
# msf-makeiplist
# msf-md5_lookup
# msf-metasm_shell
# msf-msf_irb_shell
# msf-nasm_shell
# msf-pattern_create
# msf-pattern_offset
# msfpc
# msf-pdf2xdp
# msfrpc
# msfrpcd
# msfupdate
# msfvenom
# msf-virustotal
# msql2mysql
# msrpcfuzz
# msrpcfuzz_udp
# mt
# mt-gnu
# mtrace
# multimac
# multixterm
# mutter
# mv
# mvxattr
# myisamchk
# myisam_ftdump
# myisamlog
# myisampack
# my_print_defaults
# mysql
# mysqlaccess
# mysqladmin
# mysqlanalyze
# mysqlbinlog
# mysqlcheck
# mysql_convert_table_format
# mysqld_multi
# mysqld_safe
# mysqld_safe_helper
# mysqldump
# mysqldumpslow
# mysql_embedded
# mysql_find_rows
# mysql_fix_extensions
# mysqlhotcopy
# mysqlimport
# mysql_install_db
# mysqloptimize
# mysql_plugin
# mysqlrepair
# mysqlreport
# mysql_secure_installation
# mysql_setpermission
# mysqlshow
# mysqlslap
# mysql_tzinfo_to_sql
# mysql_upgrade
# mysql_waitpid
# mytop
# namei
# nano
# nasm
# nautilus
# nautilus-autorun-software
# nawk
# nbtscan
# nc
# ncal
# ncrack
# nc.traditional
# ncurses5-config
# ncurses6-config
# ncursesw5-config
# ncursesw6-config
# ndiff
# ndisasm
# neato
# neqn
# net
# netaddr
# netcat
# netkey-tool
# netkit-ftp
# netmask
# netsed
# net-server
# netstat
# networkctl
# newaliases
# newgrp
# nfspy
# nfspysh
# ngettext
# ngrep
# nice
# nikto
# nisdomainname
# nl
# nm
# nmap
# nmapfe
# nm-applet
# nmblookup
# nmcli
# nm-connection-editor
# nm-online
# nmtui
# nmtui-connect
# nmtui-edit
# nmtui-hostname
# nohup
# nokogiri
# nop
# npa-tool
# nping
# nproc
# nroff
# nsenter
# nslookup
# nstat
# nsupdate
# ntfs-3g
# ntfs-3g.probe
# ntfscat
# ntfscluster
# ntfscmp
# ntfsdecrypt
# ntfsfallocate
# ntfsfix
# ntfsinfo
# ntfsls
# ntfsmove
# ntfsrecover
# ntfssecaudit
# ntfstruncate
# ntfsusermap
# ntfswipe
# ntlm2
# ntlm_brute
# ntpdc
# ntpq
# ntpsweep
# ntptrace
# numfmt
# obexctl
# obj2yaml-6.0
# obj2yaml-7
# objcopy
# objdump
# oclock
# od
# oLschema2ldif
# on_ac_power
# onesixtyone
# openpgp-tool
# opensc-asn1
# opensc-explorer
# opensc-notify
# opensc-tool
# openssl
# openvt
# ophcrack
# ophcrack-cli
# opt-6.0
# opt-7
# orbd
# orca
# orca-dm-wrapper
# osage
# os-prober
# out123
# p11-kit
# p7zip
# pacat
# pack200
# packetforge-ng
# pacmd
# pactl
# pad_digest_utility
# padsp
# pager
# pamon
# paperconf
# paplay
# parec
# parecord
# parse-edid
# partx
# passmass
# passwd
# paste
# paster
# pasteurize
# pasuspender
# patator
# patch
# patchwork
# pathchk
# pathoc
# pathod
# pax11publish
# pcf2vpnc
# pcreate
# pdb
# pdb2
# pdb2.7
# pdb3
# pdb3.7
# pdbedit
# pdfdetach
# pdffonts
# pdfid
# pdfimages
# pdfinfo
# pdf-parser
# pdfseparate
# pdfsig
# pdftocairo
# pdftohtml
# pdftoppm
# pdftops
# pdftotext
# pdfunite
# pdistreport
# peekfd
# peepdf
# perf
# perl
# perl5.28.1
# perl5.28-i386-linux-gnu
# perlbug
# perldoc
# perli11ndoc
# perlivp
# perlthanks
# perror
# pftp
# pg_archivecleanup
# pg_basebackup
# pgbench
# pg_buildext
# pg_config
# pg_conftool
# pg_createcluster
# pg_ctlcluster
# pg_dropcluster
# pg_dump
# pg_dumpall
# pg_isready
# pg_lsclusters
# pg_receivewal
# pg_receivexlog
# pg_recvlogical
# pg_renamecluster
# pgrep
# pg_restore
# pg_upgradecluster
# pg_virtualenv
# phar
# phar7.3
# phar.phar
# phar.phar7.3
# photorec
# php
# php7.3
# pic
# pico
# piconv
# pidof
# pidstat
# pigz
# pinentry
# pinentry-gnome3
# pinentry-x11
# ping
# ping4
# ping6
# pinky
# pip3
# pipal
# piv-tool
# pixeltool
# pixiewps
# pkaction
# pkcheck
# pkcon
# pkcs11-tool
# pkcs15-crypt
# pkcs15-init
# pkcs15-tool
# pkexec
# pkill
# pkmon
# pkttyagent
# pl2pm
# pldd
# plog
# plugin_test
# plymouth
# pmap
# pmspike
# pod2html
# pod2man
# pod2text
# pod2usage
# podchecker
# podselect
# poff
# polenum
# policytool
# pon
# POST
# post_fuzz
# post_spike
# powersploit
# pr
# precat
# preconv
# prequest
# preunzip
# prezip
# prezip-bin
# print
# printenv
# printerbanner
# printf
# prlimit
# procan
# profiles
# proutes
# prove
# proxychains
# proxychains3
# proxytunnel
# prtstat
# prune
# ps
# pserve
# psfaddtable
# psfgettable
# psfstriptable
# psfxtable
# pshell
# psk-crack
# pslog
# psql
# pstree
# pstree.x11
# ptar
# ptardiff
# ptargrep
# pth-curl
# pth-net
# pth-rpcclient
# pth-smbclient
# pth-smbget
# pth-sqsh
# pth-winexe
# pth-wmic
# pth-wmis
# ptweens
# ptx
# pulseaudio
# pviews
# pwd
# pwdump
# pwdx
# pwgen
# pw-inspector
# pwnat
# py3clean
# py3compile
# py3versions
# pybabel
# pybabel-python2
# pybuild
# pyclean
# pycompile
# pydoc
# pydoc2
# pydoc2.7
# pydoc3
# pydoc3.7
# pygettext
# pygettext2
# pygettext2.7
# pygettext3
# pygettext3.7
# pygmentize
# pyhtmlizer
# python
# python2
# python2.7
# python2.7-config
# python2-config
# python2-futurize
# python2-pasteurize
# python2-qr
# python2-wsdump
# python3
# python3.7
# python3.7-config
# python3.7m
# python3.7m-config
# python3-config
# python3-futurize
# python3-jsonschema
# python3m
# python3m-config
# python3-pasteurize
# python3-wsdump
# python-config
# python-faraday
# pyversions
# qcollectiongenerator
# qdbus
# qdbuscpp2xml
# qdbusviewer
# qdbusxml2cpp
# qdoc
# qdoc3
# qgltf
# qhelpconverter
# qhelpgenerator
# qlalr
# qmake
# qml
# qml1plugindump
# qmlbundle
# qmlcachegen
# qmleasing
# qmlimportscanner
# qmljs
# qmllint
# qmlmin
# qmlplugindump
# qmlprofiler
# qmlscene
# qmltestrunner
# qmlviewer
# qr
# qtattributionsscanner
# qtchooser
# qtconfig
# qtdiag
# qtpaths
# qtplugininfo
# quake
# quakeserver
# querybts
# qvkgen
# r2
# r2agent
# r2pm
# rabin2
# radare2
# radiff2
# rafind2
# ragg2
# rahash2
# rake
# randpkt
# ranlib
# rarun2
# rasm2
# rawshark
# rax2
# rb
# rbash
# rcc
# rcp
# rctest
# rdesktop
# rdf2bin
# rdf2com
# rdf2ihx
# rdf2ith
# rdf2srec
# rdfdump
# rdflib
# rdjpgcom
# rdma
# rdoc
# rdoc2.5
# rdx
# readelf
# readlink
# readmsg
# readmsg.mailutils
# realpath
# rearj
# reaver
# recon-cli
# recon-ng
# recon-web
# recordmydesktop
# reindexdb
# rename.ul
# rendercheck
# renice
# reordercap
# repc
# replace
# replay.pl
# reportbug
# reset
# resize
# resizecons
# resizepart
# resolvectl
# resolveip
# resolve_stack_dump
# responder-BrowserListener
# responder-DHCP
# responder-FindSMB2UPTime
# responder-FindSQLSrv
# responder-Icmp-Redirect
# responder-MultiRelay
# responder-RunFinger
# rev
# rfcomm
# rgrep
# ri
# ri2.5
# rlogin
# rlogin-cwd
# rm
# rmdir
# rmid
# rmiregistry
# rnano
# rotatelogs
# routef
# routel
# rpcclient
# rpcgen
# rpcinfo
# rsh
# rsmangler
# rsync
# rtstat
# ruby
# ruby2.5
# runcon
# run-mailcap
# run-parts
# runscript
# run-with-aspell
# ruptime
# rview
# rvim
# rwho
# rx
# rygel
# rz
# rzsh
# sadf
# sakis3g
# samba-regedit
# samba-tool
# samdump2
# sane-find-scanner
# sanstats-6.0
# sanstats-7
# sar
# sar.sysstat
# savelog
# sb
# sbd
# sbiload
# scalpel
# scanimage
# scapy
# sccmap
# sc-hsm-tool
# scp
# scp-dbus-service
# scprofiler
# screen
# screendump
# script
# scriptreplay
# sctest
# sdiff
# sdmem
# sdptool
# searchsploit
# sed
# see
# select-default-iwrap
# select-editor
# sendemail
# sendEmail
# sendmsrpc
# sensible-browser
# sensible-editor
# sensible-pager
# seq
# servertool
# sessreg
# setarch
# setcifsacl
# setfacl
# setfattr
# setfont
# setkeycodes
# setleds
# setlogcons
# setmetamode
# se-toolkit
# setoolkit
# setpci
# setpriv
# setsid
# setterm
# setupcon
# setvtrgb
# setxkbmap
# sfdp
# sfill
# sftp
# sg
# sh
# sha1deep
# sha1sum
# sha224sum
# sha256deep
# sha256sum
# sha384sum
# sha512sum
# sharesec
# shasum
# showconsolefont
# showkey
# showrgb
# shred
# shuf
# sieve
# sigfind
# signature_digest_utility
# size
# skill
# skipfish
# slabtop
# sleep
# slogin
# smbcacls
# smbclient
# smbcontrol
# smbcquotas
# smbget
# smbmap
# smbpasswd
# smbspool
# smbstatus
# smbtar
# smbtree
# snice
# snmp-bridge-mib
# snmpbulkget
# snmpbulkwalk
# snmp-check
# snmpcheck
# snmpconf
# snmpdelta
# snmpdf
# snmpget
# snmpgetnext
# snmpinform
# snmpkey
# snmpnetstat
# snmpset
# snmpstatus
# snmptable
# snmptest
# snmptranslate
# snmptrap
# snmpusm
# snmpvacm
# snmpwalk
# sntp
# socat
# soelim
# software-properties-gtk
# sort
# sorter
# sotruss
# sp32
# sp64
# sparta
# spd-conf
# spd-say
# speech-dispatcher
# splain
# split
# splitfont
# spooftooph
# sprof
# sqldiff
# sqlite3
# sqlitebrowser
# sqlmap
# sqlmapapi
# sqsh
# srch_strings
# srm
# ss
# ssh
# ssh-add
# ssh-agent
# ssh-argv0
# ssh-copy-id
# ssh-keygen
# ssh-keyscan
# sslcaudit
# sslscan
# sslsplit
# sslstrip
# sslyze
# ss_spike
# sswap
# start-pulseaudio-x11
# stat
# statd_spike
# stdbuf
# stl2gts
# strings
# strip
# stty
# stunnel
# stunnel3
# stunnel4
# su
# sudo
# sudoedit
# sudoreplay
# sum
# sunrpcfuzz
# sushi
# svn
# svnadmin
# svnauthz
# svnauthz-validate
# svnbench
# svndumpfilter
# svnfsfs
# svnlook
# svnmucc
# svnrdump
# svnserve
# svnsync
# svnversion
# swaks
# sx
# symcryptrun
# sync
# system-config-printer
# system-config-printer-applet
# systemctl
# systemd
# systemd-analyze
# systemd-ask-password
# systemd-cat
# systemd-cgls
# systemd-cgtop
# systemd-delta
# systemd-detect-virt
# systemd-escape
# systemd-hwdb
# systemd-id128
# systemd-inhibit
# systemd-machine-id-setup
# systemd-mount
# systemd-notify
# systemd-path
# systemd-resolve
# systemd-run
# systemd-socket-activate
# systemd-stdio-bridge
# systemd-sysusers
# systemd-tmpfiles
# systemd-tty-ask-password-agent
# systemd-umount
# sz
# tabs
# tac
# tail
# tapestat
# tar
# tasksel
# taskset
# tbl
# tclsh8.6
# tcpbridge
# tcpcapinfo
# tcpliveplay
# tcpprep
# tcpreplay
# tcpreplay-edit
# tcprewrite
# tdbbackup
# tdbbackup.tdbtools
# tdbdump
# tdbrestore
# tdbtool
# tee
# telnet
# telnet.netkit
# tempfile
# teredo-mire
# terminator
# test
# testdisk
# testparm
# text2pcap
# tftp
# thc-pptp-bruter
# theharvester
# thor
# tic
# tigerdeep
# tightvncconnect
# tightvncpasswd
# tightvncserver
# timedatectl
# timed-read
# timed-run
# timeout
# tjbench
# tkconch
# tknewsbiff
# tkpasswd
# tload
# tmux
# tnameserv
# toe
# top
# totem
# totem-video-thumbnailer
# touch
# tpm2_activatecredential
# tpm2_certify
# tpm2_create
# tpm2_createpolicy
# tpm2_createprimary
# tpm2_dictionarylockout
# tpm2_encryptdecrypt
# tpm2_evictcontrol
# tpm2_getcap
# tpm2_getmanufec
# tpm2_getpubak
# tpm2_getpubek
# tpm2_getrandom
# tpm2_hash
# tpm2_hmac
# tpm2_listpersistent
# tpm2_load
# tpm2_loadexternal
# tpm2_makecredential
# tpm2_nvdefine
# tpm2_nvlist
# tpm2_nvread
# tpm2_nvreadlock
# tpm2_nvrelease
# tpm2_nvwrite
# tpm2_pcrevent
# tpm2_pcrextend
# tpm2_pcrlist
# tpm2_quote
# tpm2_rc_decode
# tpm2_readpublic
# tpm2_rsadecrypt
# tpm2_rsaencrypt
# tpm2_send
# tpm2_sign
# tpm2_startup
# tpm2_takeownership
# tpm2_unseal
# tpm2_verifysignature
# tpmc
# tpm_init_temp_fix
# tpm-nvsize
# tput
# tr
# traceproto
# traceproto.db
# traceroute
# traceroute6
# traceroute6.db
# traceroute.db
# traceroute-nanog
# tracker
# transform
# transset
# tred
# trial
# troff
# true
# truncate
# trust
# tset
# tshark
# tsk_comparedir
# tsk_gettimes
# tsk_loaddb
# tsk_recover
# tsort
# tty
# twist
# twistd
# twopi
# tzselect
# ucf
# ucfq
# ucfr
# ucs2any
# udevadm
# udisksctl
# udptunnel
# uic
# uic3
# ul
# ulockmgr_server
# umax_pp
# umount
# uname
# unattended-upgrade
# unattended-upgrades
# unbuffer
# uncompress
# uncompress.real
# unexpand
# unflatten
# unicode_start
# unicode_stop
# uniq
# unix2dos
# unix2mac
# unix-privesc-check
# unlink
# unlzma
# unmkinitramfs
# unpack200
# unpigz
# unrar
# unrar-nonfree
# unshare
# unsquashfs
# unxz
# unzip
# unzipsfx
# update-alternatives
# updatedb
# updatedb.mlocate
# update-desktop-database
# update-leap
# update-mime-database
# upower
# uptime
# upx
# upx-ucl
# us428control
# usb-devices
# usbhid-dump
# usbreset
# users
# usnjls
# utmpdump
# uuidgen
# uuidparse
# uxterm
# vacuumdb
# vacuumlo
# vbutil_firmware
# vbutil_kernel
# vbutil_key
# vbutil_keyblock
# vbutil_what_keys
# vdir
# verify_data
# verify-uselistorder-6.0
# verify-uselistorder-7
# VGAuthService
# vi
# view
# viewres
# vim
# vim.basic
# vimdiff
# vimdot
# vim.tiny
# vimtutor
# vmhgfs-fuse
# vmstat
# vmtoolsd
# vmware-checkvm
# vmwarectrl
# vmware-guestproxycerttool
# vmware-hgfsclient
# vmware-namespace-cmd
# vmware-rpctool
# vmware-toolbox-cmd
# vmware-user
# vmware-user-suid-wrapper
# vmware-vgauth-cmd
# vmware-vgauth-smoketest
# vmware-vmblock-fuse
# vmware-xferlogs
# vncconnect
# vncpasswd
# vncserver
# vncviewer
# voiphopper
# volname
# w
# wafw00f
# waitress-serve
# waitress-serve-python2
# wall
# wash
# watch
# watchgnupg
# wc
# wdctl
# webfuzz
# webshells
# weevely
# westcos-tool
# wfuzz
# wget
# whatis
# whatweb
# whereis
# which
# whiptail
# whirlpooldeep
# who
# whoami
# whois
# windows-binaries
# windows-resources
# winexe
# wireshark
# word-list-compress
# wordlists
# wpaclean
# wpa_passphrase
# w.procps
# wpscan
# write
# wrjpgcom
# wsdump
# wsrep_sst_common
# wsrep_sst_mariabackup
# wsrep_sst_mysqldump
# wsrep_sst_rsync
# wsrep_sst_rsync_wan
# X
# X11
# x11perf
# x11perfcomp
# x11_spike
# xargs
# xauth
# xbiff
# xbrlapi
# xcalc
# xclipboard
# xclock
# xcmsdb
# xconsole
# xcursorgen
# xcutsel
# xdg-desktop-icon
# xdg-desktop-menu
# xdg-email
# xdg-icon-resource
# xdg-mime
# xdg-open
# xdg-screensaver
# xdg-settings
# xdg-user-dir
# xdg-user-dirs-update
# xditview
# xdpyinfo
# xdriinfo
# xedit
# Xephyr
# xev
# xeyes
# xfd
# xfontsel
# xfreerdp
# xgamma
# xgc
# xhost
# xhydra
# xkbbell
# xkbcomp
# xkbevd
# xkbprint
# xkbvleds
# xkbwatch
# xkeystone
# xkibitz
# xkill
# xload
# xlogo
# xlsatoms
# xlsclients
# xlsfonts
# xmag
# xman
# xmessage
# xminicom
# xmlcatalog
# xmllint
# xmlpatterns
# xmlpatternsvalidator
# xmodmap
# xmore
# xnmap
# Xorg
# xpdf
# xpdf.real
# xprop
# xpstat
# xrandr
# xrdb
# xrefresh
# x-session-manager
# xset
# xsetmode
# xsetpointer
# xsetroot
# xsetwacom
# xsltproc
# xstdcmap
# xsubpp
# xterm
# x-terminal-emulator
# Xtightvnc
# xtightvncviewer
# xvidtune
# xvinfo
# Xvnc
# xvncviewer
# Xwayland
# xwd
# x-window-manager
# xwininfo
# xwud
# x-www-browser
# xxd
# xz
# xzcat
# xzcmp
# xzdiff
# xzegrep
# xzfgrep
# xzgrep
# xzless
# xzmore
# yaml2obj-6.0
# yaml2obj-7
# yaml-bench-6.0
# yaml-bench-7
# yelp
# yes
# ypdomainname
# zcat
# zcmp
# zdiff
# zdump
# zegrep
# zenity
# zenmap
# zfgrep
# zforce
# zgrep
# zip
# zipcloak
# zipdetails
# zipgrep
# zipinfo
# zipnote
# zipsplit
# zless
# zmore
# znew
# zsh
# zsh5
